# %% [markdown]
# *Trabajo de Fin de Máster. Ingeniería del Software: Cloud, Datos y Gestión TI*

# %% [markdown]
# ------

# %% [markdown]
# # Respuesta frente a la COVID-19: Un análisis de GitHub

# %% [markdown]
# ##### *Jacinto José Ruiz Díaz*

# %% [markdown]
# ## Capítulo 4.2. Búsqueda de repositorios

# %% [markdown]
# ------

# %%
import requests
import json
import pandas as pd 
import time
from datetime import timedelta, datetime
import sys
pd.options.mode.chained_assignment = None
from pandasgui import show

# %% [markdown]
# ### Creación de cabecera con token de identificación

# %%
token = "" # Rellenar con token generado en GitHub
header = {'Authorization': 'token %s' % token}

# %% [markdown]
# ### Límites de consultas

# %%
limits = requests.get('https://api.github.com/rate_limit')
print(json.dumps(limits.json(), indent=4, sort_keys=True))
# Out:
# {
#     "rate": {
#         "limit": 60,
#         "remaining": 60,
#         "reset": 1630632389,
#         "resource": "core",
#         "used": 0
#     },
#     "resources": {
#         "core": {
#             "limit": 60,
#             "remaining": 60,
#             "reset": 1630632389,
#             "resource": "core",
#             "used": 0
#         },
#         "graphql": {
#             "limit": 0,
#             "remaining": 0,
#             "reset": 1630632389,
#             "resource": "graphql",
#             "used": 0
#         },
#         "integration_manifest": {
#             "limit": 5000,
#             "remaining": 5000,
#             "reset": 1630632389,
#             "resource": "integration_manifest",
#             "used": 0
#         },
#         "search": {
#             "limit": 10,
#             "remaining": 10,
#             "reset": 1630628849,
#             "resource": "search",
#             "used": 0
#         }
#     }
# }

# %%
limits = requests.get('https://api.github.com/rate_limit', headers=header)
print(json.dumps(limits.json(), indent=4, sort_keys=True))
# Out:
# {
#     "rate": {
#         "limit": 5000,
#         "remaining": 5000,
#         "reset": 1630632398,
#         "used": 0
#     },
#     "resources": {
#         "code_scanning_upload": {
#             "limit": 500,
#             "remaining": 500,
#             "reset": 1630632398,
#             "used": 0
#         },
#         "core": {
#             "limit": 5000,
#             "remaining": 5000,
#             "reset": 1630632398,
#             "used": 0
#         },
#         "graphql": {
#             "limit": 5000,
#             "remaining": 5000,
#             "reset": 1630632398,
#             "used": 0
#         },
#         "integration_manifest": {
#             "limit": 5000,
#             "remaining": 5000,
#             "reset": 1630632398,
#             "used": 0
#         },
#         "search": {
#             "limit": 30,
#             "remaining": 30,
#             "reset": 1630628858,
#             "used": 0
#         },
#         "source_import": {
#             "limit": 100,
#             "remaining": 100,
#             "reset": 1630628858,
#             "used": 0
#         }
#     }
# }

# %% [markdown]
# ### Búsqueda de repositorios

# %%
used_cols = ["id", "name", "full_name", "description", "contributors_url", "archived", "disabled", "stargazers_count",
             "watchers_count", "forks_count", "has_downloads", "has_issues", "has_pages", "has_projects", "has_wiki", 
             "homepage", "html_url", "language", "created_at", "pushed_at", "updated_at", "svn_url", "owner.login"]

# %%
def get_df_from_github_calls(response):
    
    response_json = response.json()
    total_count = response_json["total_count"]
    
    print('Procesando URL: {}'.format(response.url))
    
    print('Número de resultados: {}'.format(total_count))
    
    print("Creando dataframe...")

    df = pd.json_normalize(response_json["items"])
    print("Tamaño actual dataframe: {}".format(df.shape[0]))

    while("next" in response.links):
        print("Esperando 7 segundos...")
        time.sleep(wait_time) #Espera de 7 segundos

        print('Procesando URL: {}'.format(response.links["next"]["url"]))
        response = requests.get(response.links["next"]["url"], headers=header)
        response_json = response.json()

        print("Actualizando dataframe...")
        df_next = pd.json_normalize(response_json["items"])
        df = df.append(df_next)
        print("Tamaño actual dataframe: {}".format(df.shape[0]))

    if(df.shape[0] != total_count):
        print("--- [ERROR] Se han almacenado menos resultados de lo esperado \n Número total: {} \n Resultados almacenados: {}"
                                                                                        .format(total_count, df.shape[0]))
        sys.exit(1)
    # Selección solo de las columnas que vamos a utilizar
    df_reducido = df[used_cols]
    
    return df_reducido

# %%
def get_df_from_split_calls(date):
    since_date1 = date
    until_date1 = date + timedelta(hours = 12)
    since_date2 = until_date1 + timedelta(seconds = 1)
    until_date2 = until_date1 + timedelta(hours = 11, minutes = 59, seconds = 59)
    
    res_dataframe = pd.DataFrame(columns=used_cols)
    
    query1 = "?per_page=100" + '&q=' + keyword + " created:" + since_date1.strftime("%Y-%m-%dT%H:%M:%S") \
                                                             + ".." + until_date1.strftime("%Y-%m-%dT%H:%M:%S") 
    query2 = "?per_page=100" + '&q=' + keyword + " created:" + since_date2.strftime("%Y-%m-%dT%H:%M:%S") \
                                                             + ".." + until_date2.strftime("%Y-%m-%dT%H:%M:%S") 
    queries = [query1, query2]
    
    for index, query in enumerate(queries, start=1):
        response = requests.get('https://api.github.com/search/repositories' + query, headers=header)
        response_json = response.json()
        
        total_count = response_json["total_count"]
        print("\n --- Tamaño llamada {}: {} ---".format(index, total_count))
        
        print('Procesando URL: {}'.format(response.url))
        print("Creando dataframe...")

        df = pd.json_normalize(response_json["items"])
        print("Tamaño actual dataframe: {}".format(df.shape[0]))

        while("next" in response.links):
            print("Esperando 7 segundos...")
            time.sleep(wait_time) #Espera de 7 segundos

            print('Procesando URL: {}'.format(response.links["next"]["url"]))
            response = requests.get(response.links["next"]["url"], headers=header)
            response_json = response.json()

            print("Actualizando dataframe...")
            df_next = pd.json_normalize(response_json["items"])
            df = df.append(df_next)
            print("Tamaño actual dataframe: {}".format(df.shape[0]))

        if(df.shape[0] != total_count):
            print("--- [ERROR] Se han almacenado menos resultados de lo esperado \n Número total: {} \n Resultados almacenados: {}"
                                                                                            .format(total_count, df.shape[0]))
            sys.exit(1)
        # Selección solo de las columnas que vamos a utilizar
        df_reducido = df[used_cols]

        res_dataframe = res_dataframe.append(df_reducido)
        
    return res_dataframe

# %%
keyword = "covid-19"

date = datetime(2020, 3, 2)

limit_date = datetime(2021, 7, 25)

i = 2
while(date <= limit_date):
    print("\n\n -- PROCESANDO FECHA {} --".format(date.strftime("%Y-%m-%d")))
    
    query = "?per_page=100" + '&q=' + keyword + " created:" + date.strftime("%Y-%m-%d")

    response = requests.get('https://api.github.com/search/repositories' + query, headers=header)
    response_json = response.json()
    
    total_count = response_json["total_count"]
    
    if(total_count > 1000):
        print("------- Tamaño mayor a 1000 ({}). Dividimos la llamada... -------".format(total_count))
        df = get_df_from_split_calls(date)
        
    else:
        print("Esperando 5 segundos...")
        time.sleep(5) #Espera de 5 segundos
        df = get_df_from_github_calls(response)

    df.to_csv(r''+keyword+'_'+ str(i) +'.csv', index = False, encoding="utf-8-sig")
        
    date += timedelta(days = 1)
    i += 1
# Out:
#  -- PROCESANDO FECHA 2021-01-04 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-04
# Número de resultados: 130
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-04&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 130
#
#
#  -- PROCESANDO FECHA 2021-01-05 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-05
# Número de resultados: 157
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-05&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 157
#
#
#  -- PROCESANDO FECHA 2021-01-06 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-06
# Número de resultados: 137
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-06&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 137
#
#
#  -- PROCESANDO FECHA 2021-01-07 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-07
# Número de resultados: 139
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-07&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 139
#
#
#  -- PROCESANDO FECHA 2021-01-08 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-08
# Número de resultados: 123
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-08&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 123
#
#
#  -- PROCESANDO FECHA 2021-01-09 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-09
# Número de resultados: 114
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-09&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 114
#
#
#  -- PROCESANDO FECHA 2021-01-10 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-10
# Número de resultados: 137
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-10&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 137
#
#
#  -- PROCESANDO FECHA 2021-01-11 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-11
# Número de resultados: 149
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-11&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 149
#
#
#  -- PROCESANDO FECHA 2021-01-12 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-12
# Número de resultados: 145
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-12&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 145
#
#
#  -- PROCESANDO FECHA 2021-01-13 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-13
# Número de resultados: 123
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-13&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 123
#
#
#  -- PROCESANDO FECHA 2021-01-14 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-14
# Número de resultados: 131
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-14&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 131
#
#
#  -- PROCESANDO FECHA 2021-01-15 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-15
# Número de resultados: 123
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-15&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 123
#
#
#  -- PROCESANDO FECHA 2021-01-16 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-16
# Número de resultados: 112
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-16&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 112
#
#
#  -- PROCESANDO FECHA 2021-01-17 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-17
# Número de resultados: 162
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-17&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 162
#
#
#  -- PROCESANDO FECHA 2021-01-18 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-18
# Número de resultados: 143
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-18&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 143
#
#
#  -- PROCESANDO FECHA 2021-01-19 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-19
# Número de resultados: 119
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-19&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 119
#
#
#  -- PROCESANDO FECHA 2021-01-20 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-20
# Número de resultados: 140
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-20&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 140
#
#
#  -- PROCESANDO FECHA 2021-01-21 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-21
# Número de resultados: 139
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-21&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 139
#
#
#  -- PROCESANDO FECHA 2021-01-22 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-22
# Número de resultados: 131
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-22&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 131
#
#
#  -- PROCESANDO FECHA 2021-01-23 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-23
# Número de resultados: 121
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-23&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 121
#
#
#  -- PROCESANDO FECHA 2021-01-24 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-24
# Número de resultados: 144
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-24&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 144
#
#
#  -- PROCESANDO FECHA 2021-01-25 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-25
# Número de resultados: 137
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-25&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 137
#
#
#  -- PROCESANDO FECHA 2021-01-26 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-26
# Número de resultados: 134
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-26&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 134
#
#
#  -- PROCESANDO FECHA 2021-01-27 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-27
# Número de resultados: 114
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-27&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 114
#
#
#  -- PROCESANDO FECHA 2021-01-28 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-28
# Número de resultados: 116
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-28&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 116
#
#
#  -- PROCESANDO FECHA 2021-01-29 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-29
# Número de resultados: 129
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-29&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 129
#
#
#  -- PROCESANDO FECHA 2021-01-30 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-30
# Número de resultados: 128
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-30&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 128
#
#
#  -- PROCESANDO FECHA 2021-01-31 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-01-31
# Número de resultados: 114
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-01-31&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 114
#
#
#  -- PROCESANDO FECHA 2021-02-01 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-01
# Número de resultados: 136
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-01&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 136
#
#
#  -- PROCESANDO FECHA 2021-02-02 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-02
# Número de resultados: 103
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-02&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 103
#
#
#  -- PROCESANDO FECHA 2021-02-03 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-03
# Número de resultados: 121
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-03&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 121
#
#
#  -- PROCESANDO FECHA 2021-02-04 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-04
# Número de resultados: 133
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-04&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 133
#
#
#  -- PROCESANDO FECHA 2021-02-05 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-05
# Número de resultados: 116
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-05&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 116
#
#
#  -- PROCESANDO FECHA 2021-02-06 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-06
# Número de resultados: 91
# Creando dataframe...
# Tamaño actual dataframe: 91
#
#
#  -- PROCESANDO FECHA 2021-02-07 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-07
# Número de resultados: 110
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-07&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 110
#
#
#  -- PROCESANDO FECHA 2021-02-08 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-08
# Número de resultados: 116
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-08&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 116
#
#
#  -- PROCESANDO FECHA 2021-02-09 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-09
# Número de resultados: 127
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-09&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 127
#
#
#  -- PROCESANDO FECHA 2021-02-10 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-10
# Número de resultados: 113
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-10&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 113
#
#
#  -- PROCESANDO FECHA 2021-02-11 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-11
# Número de resultados: 99
# Creando dataframe...
# Tamaño actual dataframe: 99
#
#
#  -- PROCESANDO FECHA 2021-02-12 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-12
# Número de resultados: 95
# Creando dataframe...
# Tamaño actual dataframe: 95
#
#
#  -- PROCESANDO FECHA 2021-02-13 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-13
# Número de resultados: 103
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-13&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 103
#
#
#  -- PROCESANDO FECHA 2021-02-14 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-14
# Número de resultados: 110
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-14&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 110
#
#
#  -- PROCESANDO FECHA 2021-02-15 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-15
# Número de resultados: 108
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-15&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 108
#
#
#  -- PROCESANDO FECHA 2021-02-16 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-16
# Número de resultados: 118
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-16&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 118
#
#
#  -- PROCESANDO FECHA 2021-02-17 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-17
# Número de resultados: 137
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-17&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 137
#
#
#  -- PROCESANDO FECHA 2021-02-18 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-18
# Número de resultados: 122
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-18&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 122
#
#
#  -- PROCESANDO FECHA 2021-02-19 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-19
# Número de resultados: 102
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-19&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 102
#
#
#  -- PROCESANDO FECHA 2021-02-20 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-20
# Número de resultados: 112
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-20&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 112
#
#
#  -- PROCESANDO FECHA 2021-02-21 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-21
# Número de resultados: 98
# Creando dataframe...
# Tamaño actual dataframe: 98
#
#
#  -- PROCESANDO FECHA 2021-02-22 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-22
# Número de resultados: 141
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-22&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 141
#
#
#  -- PROCESANDO FECHA 2021-02-23 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-23
# Número de resultados: 128
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-23&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 128
#
#
#  -- PROCESANDO FECHA 2021-02-24 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-24
# Número de resultados: 101
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-24&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 101
#
#
#  -- PROCESANDO FECHA 2021-02-25 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-25
# Número de resultados: 101
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-25&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 101
#
#
#  -- PROCESANDO FECHA 2021-02-26 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-26
# Número de resultados: 89
# Creando dataframe...
# Tamaño actual dataframe: 89
#
#
#  -- PROCESANDO FECHA 2021-02-27 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-27
# Número de resultados: 101
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-27&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 101
#
#
#  -- PROCESANDO FECHA 2021-02-28 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-02-28
# Número de resultados: 105
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-02-28&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 105
#
#
#  -- PROCESANDO FECHA 2021-03-01 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-01
# Número de resultados: 113
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-01&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 113
#
#
#  -- PROCESANDO FECHA 2021-03-02 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-02
# Número de resultados: 123
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-02&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 123
#
#
#  -- PROCESANDO FECHA 2021-03-03 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-03
# Número de resultados: 107
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-03&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 107
#
#
#  -- PROCESANDO FECHA 2021-03-04 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-04
# Número de resultados: 131
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-04&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 131
#
#
#  -- PROCESANDO FECHA 2021-03-05 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-05
# Número de resultados: 74
# Creando dataframe...
# Tamaño actual dataframe: 74
#
#
#  -- PROCESANDO FECHA 2021-03-06 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-06
# Número de resultados: 114
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-06&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 114
#
#
#  -- PROCESANDO FECHA 2021-03-07 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-07
# Número de resultados: 113
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-07&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 113
#
#
#  -- PROCESANDO FECHA 2021-03-08 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-08
# Número de resultados: 108
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-08&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 108
#
#
#  -- PROCESANDO FECHA 2021-03-09 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-09
# Número de resultados: 111
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-09&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 111
#
#
#  -- PROCESANDO FECHA 2021-03-10 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-10
# Número de resultados: 110
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-10&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 110
#
#
#  -- PROCESANDO FECHA 2021-03-11 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-11
# Número de resultados: 120
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-11&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 120
#
#
#  -- PROCESANDO FECHA 2021-03-12 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-12
# Número de resultados: 79
# Creando dataframe...
# Tamaño actual dataframe: 79
#
#
#  -- PROCESANDO FECHA 2021-03-13 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-13
# Número de resultados: 102
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-13&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 102
#
#
#  -- PROCESANDO FECHA 2021-03-14 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-14
# Número de resultados: 89
# Creando dataframe...
# Tamaño actual dataframe: 89
#
#
#  -- PROCESANDO FECHA 2021-03-15 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-15
# Número de resultados: 116
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-15&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 116
#
#
#  -- PROCESANDO FECHA 2021-03-16 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-16
# Número de resultados: 113
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-16&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 113
#
#
#  -- PROCESANDO FECHA 2021-03-17 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-17
# Número de resultados: 144
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-17&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 144
#
#
#  -- PROCESANDO FECHA 2021-03-18 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-18
# Número de resultados: 89
# Creando dataframe...
# Tamaño actual dataframe: 89
#
#
#  -- PROCESANDO FECHA 2021-03-19 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-19
# Número de resultados: 104
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-19&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 104
#
#
#  -- PROCESANDO FECHA 2021-03-20 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-20
# Número de resultados: 93
# Creando dataframe...
# Tamaño actual dataframe: 93
#
#
#  -- PROCESANDO FECHA 2021-03-21 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-21
# Número de resultados: 84
# Creando dataframe...
# Tamaño actual dataframe: 84
#
#
#  -- PROCESANDO FECHA 2021-03-22 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-22
# Número de resultados: 114
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-22&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 114
#
#
#  -- PROCESANDO FECHA 2021-03-23 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-23
# Número de resultados: 133
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-23&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 133
#
#
#  -- PROCESANDO FECHA 2021-03-24 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-24
# Número de resultados: 120
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-24&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 120
#
#
#  -- PROCESANDO FECHA 2021-03-25 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-25
# Número de resultados: 112
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-25&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 112
#
#
#  -- PROCESANDO FECHA 2021-03-26 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-26
# Número de resultados: 114
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-26&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 114
#
#
#  -- PROCESANDO FECHA 2021-03-27 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-27
# Número de resultados: 96
# Creando dataframe...
# Tamaño actual dataframe: 96
#
#
#  -- PROCESANDO FECHA 2021-03-28 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-28
# Número de resultados: 97
# Creando dataframe...
# Tamaño actual dataframe: 97
#
#
#  -- PROCESANDO FECHA 2021-03-29 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-29
# Número de resultados: 115
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-29&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 115
#
#
#  -- PROCESANDO FECHA 2021-03-30 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-30
# Número de resultados: 111
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-30&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 111
#
#
#  -- PROCESANDO FECHA 2021-03-31 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-03-31
# Número de resultados: 119
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-03-31&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 119
#
#
#  -- PROCESANDO FECHA 2021-04-01 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-01
# Número de resultados: 112
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-01&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 112
#
#
#  -- PROCESANDO FECHA 2021-04-02 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-02
# Número de resultados: 114
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-02&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 114
#
#
#  -- PROCESANDO FECHA 2021-04-03 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-03
# Número de resultados: 94
# Creando dataframe...
# Tamaño actual dataframe: 94
#
#
#  -- PROCESANDO FECHA 2021-04-04 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-04
# Número de resultados: 89
# Creando dataframe...
# Tamaño actual dataframe: 89
#
#
#  -- PROCESANDO FECHA 2021-04-05 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-05
# Número de resultados: 97
# Creando dataframe...
# Tamaño actual dataframe: 97
#
#
#  -- PROCESANDO FECHA 2021-04-06 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-06
# Número de resultados: 109
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-06&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 109
#
#
#  -- PROCESANDO FECHA 2021-04-07 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-07
# Número de resultados: 108
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-07&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 108
#
#
#  -- PROCESANDO FECHA 2021-04-08 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-08
# Número de resultados: 103
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-08&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 103
#
#
#  -- PROCESANDO FECHA 2021-04-09 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-09
# Número de resultados: 126
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-09&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 126
#
#
#  -- PROCESANDO FECHA 2021-04-10 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-10
# Número de resultados: 101
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-10&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 101
#
#
#  -- PROCESANDO FECHA 2021-04-11 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-11
# Número de resultados: 148
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-11&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 148
#
#
#  -- PROCESANDO FECHA 2021-04-12 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-12
# Número de resultados: 135
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-12&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 135
#
#
#  -- PROCESANDO FECHA 2021-04-13 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-13
# Número de resultados: 116
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-13&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 116
#
#
#  -- PROCESANDO FECHA 2021-04-14 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-14
# Número de resultados: 121
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-14&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 121
#
#
#  -- PROCESANDO FECHA 2021-04-15 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-15
# Número de resultados: 124
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-15&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 124
#
#
#  -- PROCESANDO FECHA 2021-04-16 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-16
# Número de resultados: 115
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-16&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 115
#
#
#  -- PROCESANDO FECHA 2021-04-17 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-17
# Número de resultados: 100
# Creando dataframe...
# Tamaño actual dataframe: 100
#
#
#  -- PROCESANDO FECHA 2021-04-18 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-18
# Número de resultados: 123
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-18&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 123
#
#
#  -- PROCESANDO FECHA 2021-04-19 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-19
# Número de resultados: 128
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-19&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 128
#
#
#  -- PROCESANDO FECHA 2021-04-20 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-20
# Número de resultados: 147
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-20&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 147
#
#
#  -- PROCESANDO FECHA 2021-04-21 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-21
# Número de resultados: 146
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-21&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 146
#
#
#  -- PROCESANDO FECHA 2021-04-22 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-22
# Número de resultados: 120
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-22&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 120
#
#
#  -- PROCESANDO FECHA 2021-04-23 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-23
# Número de resultados: 154
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-23&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 154
#
#
#  -- PROCESANDO FECHA 2021-04-24 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-24
# Número de resultados: 166
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-24&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 166
#
#
#  -- PROCESANDO FECHA 2021-04-25 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-25
# Número de resultados: 144
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-25&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 144
#
#
#  -- PROCESANDO FECHA 2021-04-26 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-26
# Número de resultados: 171
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-26&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 171
#
#
#  -- PROCESANDO FECHA 2021-04-27 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-27
# Número de resultados: 185
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-27&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 185
#
#
#  -- PROCESANDO FECHA 2021-04-28 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-28
# Número de resultados: 134
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-28&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 134
#
#
#  -- PROCESANDO FECHA 2021-04-29 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-29
# Número de resultados: 157
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-29&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 157
#
#
#  -- PROCESANDO FECHA 2021-04-30 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-04-30
# Número de resultados: 153
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-04-30&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 153
#
#
#  -- PROCESANDO FECHA 2021-05-01 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-05-01
# Número de resultados: 144
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-05-01&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 144
#
#
#  -- PROCESANDO FECHA 2021-05-02 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-05-02
# Número de resultados: 139
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-05-02&page=2
# Actualizando dataframe...
# ...
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-06-18&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 123
#
#
#  -- PROCESANDO FECHA 2021-06-19 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-06-19
# Número de resultados: 106
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-06-19&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 106
#
#
#  -- PROCESANDO FECHA 2021-06-20 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-06-20
# Número de resultados: 125
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-06-20&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 125
#
#
#  -- PROCESANDO FECHA 2021-06-21 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-06-21
# Número de resultados: 142
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-06-21&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 142
#
#
#  -- PROCESANDO FECHA 2021-06-22 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-06-22
# Número de resultados: 126
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-06-22&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 126
#
#
#  -- PROCESANDO FECHA 2021-06-23 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-06-23
# Número de resultados: 141
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-06-23&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 141
#
#
#  -- PROCESANDO FECHA 2021-06-24 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-06-24
# Número de resultados: 145
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-06-24&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 145
#
#
#  -- PROCESANDO FECHA 2021-06-25 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-06-25
# Número de resultados: 128
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-06-25&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 128
#
#
#  -- PROCESANDO FECHA 2021-06-26 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-06-26
# Número de resultados: 125
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-06-26&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 125
#
#
#  -- PROCESANDO FECHA 2021-06-27 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-06-27
# Número de resultados: 116
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-06-27&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 116
#
#
#  -- PROCESANDO FECHA 2021-06-28 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-06-28
# Número de resultados: 123
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-06-28&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 123
#
#
#  -- PROCESANDO FECHA 2021-06-29 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-06-29
# Número de resultados: 130
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-06-29&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 130
#
#
#  -- PROCESANDO FECHA 2021-06-30 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-06-30
# Número de resultados: 133
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-06-30&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 133
#
#
#  -- PROCESANDO FECHA 2021-07-01 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-01
# Número de resultados: 131
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-01&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 131
#
#
#  -- PROCESANDO FECHA 2021-07-02 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-02
# Número de resultados: 107
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-02&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 107
#
#
#  -- PROCESANDO FECHA 2021-07-03 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-03
# Número de resultados: 121
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-03&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 121
#
#
#  -- PROCESANDO FECHA 2021-07-04 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-04
# Número de resultados: 126
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-04&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 126
#
#
#  -- PROCESANDO FECHA 2021-07-05 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-05
# Número de resultados: 111
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-05&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 111
#
#
#  -- PROCESANDO FECHA 2021-07-06 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-06
# Número de resultados: 128
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-06&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 128
#
#
#  -- PROCESANDO FECHA 2021-07-07 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-07
# Número de resultados: 146
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-07&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 146
#
#
#  -- PROCESANDO FECHA 2021-07-08 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-08
# Número de resultados: 136
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-08&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 136
#
#
#  -- PROCESANDO FECHA 2021-07-09 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-09
# Número de resultados: 131
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-09&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 131
#
#
#  -- PROCESANDO FECHA 2021-07-10 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-10
# Número de resultados: 119
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-10&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 119
#
#
#  -- PROCESANDO FECHA 2021-07-11 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-11
# Número de resultados: 99
# Creando dataframe...
# Tamaño actual dataframe: 99
#
#
#  -- PROCESANDO FECHA 2021-07-12 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-12
# Número de resultados: 149
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-12&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 149
#
#
#  -- PROCESANDO FECHA 2021-07-13 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-13
# Número de resultados: 127
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-13&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 127
#
#
#  -- PROCESANDO FECHA 2021-07-14 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-14
# Número de resultados: 146
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-14&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 146
#
#
#  -- PROCESANDO FECHA 2021-07-15 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-15
# Número de resultados: 134
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-15&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 134
#
#
#  -- PROCESANDO FECHA 2021-07-16 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-16
# Número de resultados: 156
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-16&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 156
#
#
#  -- PROCESANDO FECHA 2021-07-17 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-17
# Número de resultados: 121
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-17&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 121
#
#
#  -- PROCESANDO FECHA 2021-07-18 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-18
# Número de resultados: 110
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-18&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 110
#
#
#  -- PROCESANDO FECHA 2021-07-19 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-19
# Número de resultados: 108
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-19&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 108
#
#
#  -- PROCESANDO FECHA 2021-07-20 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-20
# Número de resultados: 140
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-20&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 140
#
#
#  -- PROCESANDO FECHA 2021-07-21 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-21
# Número de resultados: 109
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-21&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 109
#
#
#  -- PROCESANDO FECHA 2021-07-22 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-22
# Número de resultados: 109
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-22&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 109
#
#
#  -- PROCESANDO FECHA 2021-07-23 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-23
# Número de resultados: 112
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-23&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 112
#
#
#  -- PROCESANDO FECHA 2021-07-24 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-24
# Número de resultados: 124
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-24&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 124
#
#
#  -- PROCESANDO FECHA 2021-07-25 --
# Esperando 5 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19%20created:2021-07-25
# Número de resultados: 119
# Creando dataframe...
# Tamaño actual dataframe: 100
# Esperando 7 segundos...
# Procesando URL: https://api.github.com/search/repositories?per_page=100&q=covid-19+created%3A2021-07-25&page=2
# Actualizando dataframe...
# Tamaño actual dataframe: 119

# %% [markdown]
# ----

# %% [markdown]
# ### Unión de ficheros CSV

# %%
import os
from glob import glob
import pandas as pd

path = "/coronavirus/"

# %%
files = glob("coronavirus/coronavirus_*.csv")
files
# Out:
# ['coronavirus\\coronavirus_1.csv',
#  'coronavirus\\coronavirus_10.csv',
#  'coronavirus\\coronavirus_100.csv',
#  'coronavirus\\coronavirus_101.csv',
#  'coronavirus\\coronavirus_102.csv',
#  'coronavirus\\coronavirus_103.csv',
#  'coronavirus\\coronavirus_104.csv',
#  'coronavirus\\coronavirus_105.csv',
#  'coronavirus\\coronavirus_106.csv',
#  'coronavirus\\coronavirus_107.csv',
#  'coronavirus\\coronavirus_108.csv',
#  'coronavirus\\coronavirus_109.csv',
#  'coronavirus\\coronavirus_11.csv',
#  'coronavirus\\coronavirus_110.csv',
#  'coronavirus\\coronavirus_111.csv',
#  'coronavirus\\coronavirus_112.csv',
#  'coronavirus\\coronavirus_113.csv',
#  'coronavirus\\coronavirus_114.csv',
#  'coronavirus\\coronavirus_115.csv',
#  'coronavirus\\coronavirus_116.csv',
#  'coronavirus\\coronavirus_117.csv',
#  'coronavirus\\coronavirus_118.csv',
#  'coronavirus\\coronavirus_119.csv',
#  'coronavirus\\coronavirus_12.csv',
#  'coronavirus\\coronavirus_120.csv',
#  'coronavirus\\coronavirus_121.csv',
#  'coronavirus\\coronavirus_122.csv',
#  'coronavirus\\coronavirus_123.csv',
#  'coronavirus\\coronavirus_124.csv',
#  'coronavirus\\coronavirus_125.csv',
#  'coronavirus\\coronavirus_126.csv',
#  'coronavirus\\coronavirus_127.csv',
#  'coronavirus\\coronavirus_128.csv',
#  'coronavirus\\coronavirus_129.csv',
#  'coronavirus\\coronavirus_13.csv',
#  'coronavirus\\coronavirus_130.csv',
#  'coronavirus\\coronavirus_131.csv',
#  'coronavirus\\coronavirus_132.csv',
#  'coronavirus\\coronavirus_133.csv',
#  'coronavirus\\coronavirus_134.csv',
#  'coronavirus\\coronavirus_135.csv',
#  'coronavirus\\coronavirus_136.csv',
#  'coronavirus\\coronavirus_137.csv',
#  'coronavirus\\coronavirus_138.csv',
#  'coronavirus\\coronavirus_139.csv',
#  'coronavirus\\coronavirus_14.csv',
#  'coronavirus\\coronavirus_140.csv',
#  'coronavirus\\coronavirus_141.csv',
#  'coronavirus\\coronavirus_142.csv',
#  'coronavirus\\coronavirus_143.csv',
#  'coronavirus\\coronavirus_144.csv',
#  'coronavirus\\coronavirus_145.csv',
#  'coronavirus\\coronavirus_146.csv',
#  'coronavirus\\coronavirus_147.csv',
#  'coronavirus\\coronavirus_148.csv',
#  'coronavirus\\coronavirus_149.csv',
#  'coronavirus\\coronavirus_15.csv',
#  'coronavirus\\coronavirus_150.csv',
#  'coronavirus\\coronavirus_151.csv',
#  'coronavirus\\coronavirus_152.csv',
#  'coronavirus\\coronavirus_153.csv',
#  'coronavirus\\coronavirus_154.csv',
#  'coronavirus\\coronavirus_155.csv',
#  'coronavirus\\coronavirus_156.csv',
#  'coronavirus\\coronavirus_157.csv',
#  'coronavirus\\coronavirus_158.csv',
#  'coronavirus\\coronavirus_159.csv',
#  'coronavirus\\coronavirus_16.csv',
#  'coronavirus\\coronavirus_160.csv',
#  'coronavirus\\coronavirus_161.csv',
#  'coronavirus\\coronavirus_162.csv',
#  'coronavirus\\coronavirus_163.csv',
#  'coronavirus\\coronavirus_164.csv',
#  'coronavirus\\coronavirus_165.csv',
#  'coronavirus\\coronavirus_166.csv',
#  'coronavirus\\coronavirus_167.csv',
#  'coronavirus\\coronavirus_168.csv',
#  'coronavirus\\coronavirus_169.csv',
#  'coronavirus\\coronavirus_17.csv',
#  'coronavirus\\coronavirus_170.csv',
#  'coronavirus\\coronavirus_171.csv',
#  'coronavirus\\coronavirus_172.csv',
#  'coronavirus\\coronavirus_173.csv',
#  'coronavirus\\coronavirus_174.csv',
#  'coronavirus\\coronavirus_175.csv',
#  'coronavirus\\coronavirus_176.csv',
#  'coronavirus\\coronavirus_177.csv',
#  'coronavirus\\coronavirus_178.csv',
#  'coronavirus\\coronavirus_179.csv',
#  'coronavirus\\coronavirus_18.csv',
#  'coronavirus\\coronavirus_180.csv',
#  'coronavirus\\coronavirus_181.csv',
#  'coronavirus\\coronavirus_182.csv',
#  'coronavirus\\coronavirus_183.csv',
#  'coronavirus\\coronavirus_184.csv',
#  'coronavirus\\coronavirus_185.csv',
#  'coronavirus\\coronavirus_186.csv',
#  'coronavirus\\coronavirus_187.csv',
#  'coronavirus\\coronavirus_188.csv',
#  'coronavirus\\coronavirus_189.csv',
#  'coronavirus\\coronavirus_19.csv',
#  'coronavirus\\coronavirus_190.csv',
#  'coronavirus\\coronavirus_191.csv',
#  'coronavirus\\coronavirus_192.csv',
#  'coronavirus\\coronavirus_193.csv',
#  'coronavirus\\coronavirus_194.csv',
#  'coronavirus\\coronavirus_195.csv',
#  'coronavirus\\coronavirus_196.csv',
#  'coronavirus\\coronavirus_197.csv',
#  'coronavirus\\coronavirus_198.csv',
#  'coronavirus\\coronavirus_199.csv',
#  'coronavirus\\coronavirus_2.csv',
#  'coronavirus\\coronavirus_20.csv',
#  'coronavirus\\coronavirus_200.csv',
#  'coronavirus\\coronavirus_201.csv',
#  'coronavirus\\coronavirus_202.csv',
#  'coronavirus\\coronavirus_203.csv',
#  'coronavirus\\coronavirus_204.csv',
#  'coronavirus\\coronavirus_205.csv',
#  'coronavirus\\coronavirus_206.csv',
#  'coronavirus\\coronavirus_207.csv',
#  'coronavirus\\coronavirus_208.csv',
#  'coronavirus\\coronavirus_209.csv',
#  'coronavirus\\coronavirus_21.csv',
#  'coronavirus\\coronavirus_210.csv',
#  'coronavirus\\coronavirus_211.csv',
#  'coronavirus\\coronavirus_212.csv',
#  'coronavirus\\coronavirus_213.csv',
#  'coronavirus\\coronavirus_214.csv',
#  'coronavirus\\coronavirus_215.csv',
#  'coronavirus\\coronavirus_216.csv',
#  'coronavirus\\coronavirus_217.csv',
#  'coronavirus\\coronavirus_218.csv',
#  'coronavirus\\coronavirus_219.csv',
#  'coronavirus\\coronavirus_22.csv',
#  'coronavirus\\coronavirus_220.csv',
#  'coronavirus\\coronavirus_221.csv',
#  'coronavirus\\coronavirus_222.csv',
#  'coronavirus\\coronavirus_223.csv',
#  'coronavirus\\coronavirus_224.csv',
#  'coronavirus\\coronavirus_225.csv',
#  'coronavirus\\coronavirus_226.csv',
#  'coronavirus\\coronavirus_227.csv',
#  'coronavirus\\coronavirus_228.csv',
#  'coronavirus\\coronavirus_229.csv',
#  'coronavirus\\coronavirus_23.csv',
#  'coronavirus\\coronavirus_230.csv',
#  'coronavirus\\coronavirus_231.csv',
#  'coronavirus\\coronavirus_232.csv',
#  'coronavirus\\coronavirus_233.csv',
#  'coronavirus\\coronavirus_234.csv',
#  'coronavirus\\coronavirus_235.csv',
#  'coronavirus\\coronavirus_236.csv',
#  'coronavirus\\coronavirus_237.csv',
#  'coronavirus\\coronavirus_238.csv',
#  'coronavirus\\coronavirus_239.csv',
#  'coronavirus\\coronavirus_24.csv',
#  'coronavirus\\coronavirus_240.csv',
#  'coronavirus\\coronavirus_241.csv',
#  'coronavirus\\coronavirus_242.csv',
#  'coronavirus\\coronavirus_243.csv',
#  'coronavirus\\coronavirus_244.csv',
#  'coronavirus\\coronavirus_245.csv',
#  'coronavirus\\coronavirus_246.csv',
#  'coronavirus\\coronavirus_247.csv',
#  'coronavirus\\coronavirus_248.csv',
#  'coronavirus\\coronavirus_249.csv',
#  'coronavirus\\coronavirus_25.csv',
#  'coronavirus\\coronavirus_250.csv',
#  'coronavirus\\coronavirus_251.csv',
#  'coronavirus\\coronavirus_252.csv',
#  'coronavirus\\coronavirus_253.csv',
#  'coronavirus\\coronavirus_254.csv',
#  'coronavirus\\coronavirus_255.csv',
#  'coronavirus\\coronavirus_256.csv',
#  'coronavirus\\coronavirus_257.csv',
#  'coronavirus\\coronavirus_258.csv',
#  'coronavirus\\coronavirus_259.csv',
#  'coronavirus\\coronavirus_26.csv',
#  'coronavirus\\coronavirus_260.csv',
#  'coronavirus\\coronavirus_261.csv',
#  'coronavirus\\coronavirus_262.csv',
#  'coronavirus\\coronavirus_263.csv',
#  'coronavirus\\coronavirus_264.csv',
#  'coronavirus\\coronavirus_265.csv',
#  'coronavirus\\coronavirus_266.csv',
#  'coronavirus\\coronavirus_267.csv',
#  'coronavirus\\coronavirus_268.csv',
#  'coronavirus\\coronavirus_269.csv',
#  'coronavirus\\coronavirus_27.csv',
#  'coronavirus\\coronavirus_270.csv',
#  'coronavirus\\coronavirus_271.csv',
#  'coronavirus\\coronavirus_272.csv',
#  'coronavirus\\coronavirus_273.csv',
#  'coronavirus\\coronavirus_274.csv',
#  'coronavirus\\coronavirus_275.csv',
#  'coronavirus\\coronavirus_276.csv',
#  'coronavirus\\coronavirus_277.csv',
#  'coronavirus\\coronavirus_278.csv',
#  'coronavirus\\coronavirus_279.csv',
#  'coronavirus\\coronavirus_28.csv',
#  'coronavirus\\coronavirus_280.csv',
#  'coronavirus\\coronavirus_281.csv',
#  'coronavirus\\coronavirus_282.csv',
#  'coronavirus\\coronavirus_283.csv',
#  'coronavirus\\coronavirus_284.csv',
#  'coronavirus\\coronavirus_285.csv',
#  'coronavirus\\coronavirus_286.csv',
#  'coronavirus\\coronavirus_287.csv',
#  'coronavirus\\coronavirus_288.csv',
#  'coronavirus\\coronavirus_289.csv',
#  'coronavirus\\coronavirus_29.csv',
#  'coronavirus\\coronavirus_290.csv',
#  'coronavirus\\coronavirus_291.csv',
#  'coronavirus\\coronavirus_292.csv',
#  'coronavirus\\coronavirus_293.csv',
#  'coronavirus\\coronavirus_294.csv',
#  'coronavirus\\coronavirus_295.csv',
#  'coronavirus\\coronavirus_296.csv',
#  'coronavirus\\coronavirus_297.csv',
#  'coronavirus\\coronavirus_298.csv',
#  'coronavirus\\coronavirus_299.csv',
#  'coronavirus\\coronavirus_3.csv',
#  'coronavirus\\coronavirus_30.csv',
#  'coronavirus\\coronavirus_300.csv',
#  'coronavirus\\coronavirus_301.csv',
#  'coronavirus\\coronavirus_302.csv',
#  'coronavirus\\coronavirus_303.csv',
#  'coronavirus\\coronavirus_304.csv',
#  'coronavirus\\coronavirus_305.csv',
#  'coronavirus\\coronavirus_306.csv',
#  'coronavirus\\coronavirus_307.csv',
#  'coronavirus\\coronavirus_308.csv',
#  'coronavirus\\coronavirus_309.csv',
#  'coronavirus\\coronavirus_31.csv',
#  'coronavirus\\coronavirus_310.csv',
#  'coronavirus\\coronavirus_311.csv',
#  'coronavirus\\coronavirus_312.csv',
#  'coronavirus\\coronavirus_313.csv',
#  'coronavirus\\coronavirus_314.csv',
#  'coronavirus\\coronavirus_315.csv',
#  'coronavirus\\coronavirus_316.csv',
#  'coronavirus\\coronavirus_317.csv',
#  'coronavirus\\coronavirus_318.csv',
#  'coronavirus\\coronavirus_319.csv',
#  'coronavirus\\coronavirus_32.csv',
#  'coronavirus\\coronavirus_320.csv',
#  'coronavirus\\coronavirus_321.csv',
#  'coronavirus\\coronavirus_322.csv',
#  'coronavirus\\coronavirus_323.csv',
#  'coronavirus\\coronavirus_324.csv',
#  'coronavirus\\coronavirus_325.csv',
#  'coronavirus\\coronavirus_326.csv',
#  'coronavirus\\coronavirus_327.csv',
#  'coronavirus\\coronavirus_328.csv',
#  'coronavirus\\coronavirus_329.csv',
#  'coronavirus\\coronavirus_33.csv',
#  'coronavirus\\coronavirus_330.csv',
#  'coronavirus\\coronavirus_331.csv',
#  'coronavirus\\coronavirus_332.csv',
#  'coronavirus\\coronavirus_333.csv',
#  'coronavirus\\coronavirus_334.csv',
#  'coronavirus\\coronavirus_335.csv',
#  'coronavirus\\coronavirus_336.csv',
#  'coronavirus\\coronavirus_337.csv',
#  'coronavirus\\coronavirus_338.csv',
#  'coronavirus\\coronavirus_339.csv',
#  'coronavirus\\coronavirus_34.csv',
#  'coronavirus\\coronavirus_340.csv',
#  'coronavirus\\coronavirus_341.csv',
#  'coronavirus\\coronavirus_342.csv',
#  'coronavirus\\coronavirus_343.csv',
#  'coronavirus\\coronavirus_344.csv',
#  'coronavirus\\coronavirus_345.csv',
#  'coronavirus\\coronavirus_346.csv',
#  'coronavirus\\coronavirus_347.csv',
#  'coronavirus\\coronavirus_348.csv',
#  'coronavirus\\coronavirus_349.csv',
#  'coronavirus\\coronavirus_35.csv',
#  'coronavirus\\coronavirus_350.csv',
#  'coronavirus\\coronavirus_351.csv',
#  'coronavirus\\coronavirus_352.csv',
#  'coronavirus\\coronavirus_353.csv',
#  'coronavirus\\coronavirus_354.csv',
#  'coronavirus\\coronavirus_355.csv',
#  'coronavirus\\coronavirus_356.csv',
#  'coronavirus\\coronavirus_357.csv',
#  'coronavirus\\coronavirus_358.csv',
#  'coronavirus\\coronavirus_359.csv',
#  'coronavirus\\coronavirus_36.csv',
#  'coronavirus\\coronavirus_360.csv',
#  'coronavirus\\coronavirus_361.csv',
#  'coronavirus\\coronavirus_362.csv',
#  'coronavirus\\coronavirus_363.csv',
#  'coronavirus\\coronavirus_364.csv',
#  'coronavirus\\coronavirus_365.csv',
#  'coronavirus\\coronavirus_366.csv',
#  'coronavirus\\coronavirus_367.csv',
#  'coronavirus\\coronavirus_368.csv',
#  'coronavirus\\coronavirus_369.csv',
#  'coronavirus\\coronavirus_37.csv',
#  'coronavirus\\coronavirus_370.csv',
#  'coronavirus\\coronavirus_371.csv',
#  'coronavirus\\coronavirus_372.csv',
#  'coronavirus\\coronavirus_373.csv',
#  'coronavirus\\coronavirus_374.csv',
#  'coronavirus\\coronavirus_375.csv',
#  'coronavirus\\coronavirus_376.csv',
#  'coronavirus\\coronavirus_377.csv',
#  'coronavirus\\coronavirus_378.csv',
#  'coronavirus\\coronavirus_379.csv',
#  'coronavirus\\coronavirus_38.csv',
#  'coronavirus\\coronavirus_380.csv',
#  'coronavirus\\coronavirus_381.csv',
#  'coronavirus\\coronavirus_382.csv',
#  'coronavirus\\coronavirus_383.csv',
#  'coronavirus\\coronavirus_384.csv',
#  'coronavirus\\coronavirus_385.csv',
#  'coronavirus\\coronavirus_386.csv',
#  'coronavirus\\coronavirus_387.csv',
#  'coronavirus\\coronavirus_388.csv',
#  'coronavirus\\coronavirus_389.csv',
#  'coronavirus\\coronavirus_39.csv',
#  'coronavirus\\coronavirus_390.csv',
#  'coronavirus\\coronavirus_391.csv',
#  'coronavirus\\coronavirus_392.csv',
#  'coronavirus\\coronavirus_393.csv',
#  'coronavirus\\coronavirus_394.csv',
#  'coronavirus\\coronavirus_395.csv',
#  'coronavirus\\coronavirus_396.csv',
#  'coronavirus\\coronavirus_397.csv',
#  'coronavirus\\coronavirus_398.csv',
#  'coronavirus\\coronavirus_399.csv',
#  'coronavirus\\coronavirus_4.csv',
#  'coronavirus\\coronavirus_40.csv',
#  'coronavirus\\coronavirus_400.csv',
#  'coronavirus\\coronavirus_401.csv',
#  'coronavirus\\coronavirus_402.csv',
#  'coronavirus\\coronavirus_403.csv',
#  'coronavirus\\coronavirus_404.csv',
#  'coronavirus\\coronavirus_405.csv',
#  'coronavirus\\coronavirus_406.csv',
#  'coronavirus\\coronavirus_407.csv',
#  'coronavirus\\coronavirus_408.csv',
#  'coronavirus\\coronavirus_409.csv',
#  'coronavirus\\coronavirus_41.csv',
#  'coronavirus\\coronavirus_410.csv',
#  'coronavirus\\coronavirus_411.csv',
#  'coronavirus\\coronavirus_412.csv',
#  'coronavirus\\coronavirus_413.csv',
#  'coronavirus\\coronavirus_414.csv',
#  'coronavirus\\coronavirus_415.csv',
#  'coronavirus\\coronavirus_416.csv',
#  'coronavirus\\coronavirus_417.csv',
#  'coronavirus\\coronavirus_418.csv',
#  'coronavirus\\coronavirus_419.csv',
#  'coronavirus\\coronavirus_42.csv',
#  'coronavirus\\coronavirus_420.csv',
#  'coronavirus\\coronavirus_421.csv',
#  'coronavirus\\coronavirus_422.csv',
#  'coronavirus\\coronavirus_423.csv',
#  'coronavirus\\coronavirus_424.csv',
#  'coronavirus\\coronavirus_425.csv',
#  'coronavirus\\coronavirus_426.csv',
#  'coronavirus\\coronavirus_427.csv',
#  'coronavirus\\coronavirus_428.csv',
#  'coronavirus\\coronavirus_429.csv',
#  'coronavirus\\coronavirus_43.csv',
#  'coronavirus\\coronavirus_430.csv',
#  'coronavirus\\coronavirus_431.csv',
#  'coronavirus\\coronavirus_432.csv',
#  'coronavirus\\coronavirus_433.csv',
#  'coronavirus\\coronavirus_434.csv',
#  'coronavirus\\coronavirus_435.csv',
#  'coronavirus\\coronavirus_436.csv',
#  'coronavirus\\coronavirus_437.csv',
#  'coronavirus\\coronavirus_438.csv',
#  'coronavirus\\coronavirus_439.csv',
#  'coronavirus\\coronavirus_44.csv',
#  'coronavirus\\coronavirus_440.csv',
#  'coronavirus\\coronavirus_441.csv',
#  'coronavirus\\coronavirus_442.csv',
#  'coronavirus\\coronavirus_443.csv',
#  'coronavirus\\coronavirus_444.csv',
#  'coronavirus\\coronavirus_445.csv',
#  'coronavirus\\coronavirus_446.csv',
#  'coronavirus\\coronavirus_447.csv',
#  'coronavirus\\coronavirus_448.csv',
#  'coronavirus\\coronavirus_449.csv',
#  'coronavirus\\coronavirus_45.csv',
#  'coronavirus\\coronavirus_450.csv',
#  'coronavirus\\coronavirus_451.csv',
#  'coronavirus\\coronavirus_452.csv',
#  'coronavirus\\coronavirus_453.csv',
#  'coronavirus\\coronavirus_454.csv',
#  'coronavirus\\coronavirus_455.csv',
#  'coronavirus\\coronavirus_456.csv',
#  'coronavirus\\coronavirus_457.csv',
#  'coronavirus\\coronavirus_458.csv',
#  'coronavirus\\coronavirus_459.csv',
#  'coronavirus\\coronavirus_46.csv',
#  'coronavirus\\coronavirus_460.csv',
#  'coronavirus\\coronavirus_461.csv',
#  'coronavirus\\coronavirus_462.csv',
#  'coronavirus\\coronavirus_463.csv',
#  'coronavirus\\coronavirus_464.csv',
#  'coronavirus\\coronavirus_465.csv',
#  'coronavirus\\coronavirus_466.csv',
#  'coronavirus\\coronavirus_467.csv',
#  'coronavirus\\coronavirus_468.csv',
#  'coronavirus\\coronavirus_469.csv',
#  'coronavirus\\coronavirus_47.csv',
#  'coronavirus\\coronavirus_470.csv',
#  'coronavirus\\coronavirus_471.csv',
#  'coronavirus\\coronavirus_472.csv',
#  'coronavirus\\coronavirus_473.csv',
#  'coronavirus\\coronavirus_474.csv',
#  'coronavirus\\coronavirus_475.csv',
#  'coronavirus\\coronavirus_476.csv',
#  'coronavirus\\coronavirus_477.csv',
#  'coronavirus\\coronavirus_478.csv',
#  'coronavirus\\coronavirus_479.csv',
#  'coronavirus\\coronavirus_48.csv',
#  'coronavirus\\coronavirus_480.csv',
#  'coronavirus\\coronavirus_481.csv',
#  'coronavirus\\coronavirus_482.csv',
#  'coronavirus\\coronavirus_483.csv',
#  'coronavirus\\coronavirus_484.csv',
#  'coronavirus\\coronavirus_485.csv',
#  'coronavirus\\coronavirus_486.csv',
#  'coronavirus\\coronavirus_487.csv',
#  'coronavirus\\coronavirus_488.csv',
#  'coronavirus\\coronavirus_489.csv',
#  'coronavirus\\coronavirus_49.csv',
#  'coronavirus\\coronavirus_490.csv',
#  'coronavirus\\coronavirus_491.csv',
#  'coronavirus\\coronavirus_492.csv',
#  'coronavirus\\coronavirus_493.csv',
#  'coronavirus\\coronavirus_494.csv',
#  'coronavirus\\coronavirus_495.csv',
#  'coronavirus\\coronavirus_496.csv',
#  'coronavirus\\coronavirus_497.csv',
#  'coronavirus\\coronavirus_498.csv',
#  'coronavirus\\coronavirus_499.csv',
#  'coronavirus\\coronavirus_5.csv',
#  'coronavirus\\coronavirus_50.csv',
#  'coronavirus\\coronavirus_500.csv',
#  'coronavirus\\coronavirus_501.csv',
#  'coronavirus\\coronavirus_502.csv',
#  'coronavirus\\coronavirus_503.csv',
#  'coronavirus\\coronavirus_504.csv',
#  'coronavirus\\coronavirus_505.csv',
#  'coronavirus\\coronavirus_506.csv',
#  'coronavirus\\coronavirus_507.csv',
#  'coronavirus\\coronavirus_508.csv',
#  'coronavirus\\coronavirus_509.csv',
#  'coronavirus\\coronavirus_51.csv',
#  'coronavirus\\coronavirus_510.csv',
#  'coronavirus\\coronavirus_511.csv',
#  'coronavirus\\coronavirus_52.csv',
#  'coronavirus\\coronavirus_53.csv',
#  'coronavirus\\coronavirus_54.csv',
#  'coronavirus\\coronavirus_55.csv',
#  'coronavirus\\coronavirus_56.csv',
#  'coronavirus\\coronavirus_57.csv',
#  'coronavirus\\coronavirus_58.csv',
#  'coronavirus\\coronavirus_59.csv',
#  'coronavirus\\coronavirus_6.csv',
#  'coronavirus\\coronavirus_60.csv',
#  'coronavirus\\coronavirus_61.csv',
#  'coronavirus\\coronavirus_62.csv',
#  'coronavirus\\coronavirus_63.csv',
#  'coronavirus\\coronavirus_64.csv',
#  'coronavirus\\coronavirus_65.csv',
#  'coronavirus\\coronavirus_66.csv',
#  'coronavirus\\coronavirus_67.csv',
#  'coronavirus\\coronavirus_68.csv',
#  'coronavirus\\coronavirus_69.csv',
#  'coronavirus\\coronavirus_7.csv',
#  'coronavirus\\coronavirus_70.csv',
#  'coronavirus\\coronavirus_71.csv',
#  'coronavirus\\coronavirus_72.csv',
#  'coronavirus\\coronavirus_73.csv',
#  'coronavirus\\coronavirus_74.csv',
#  'coronavirus\\coronavirus_75.csv',
#  'coronavirus\\coronavirus_76.csv',
#  'coronavirus\\coronavirus_77.csv',
#  'coronavirus\\coronavirus_78.csv',
#  'coronavirus\\coronavirus_79.csv',
#  'coronavirus\\coronavirus_8.csv',
#  'coronavirus\\coronavirus_80.csv',
#  'coronavirus\\coronavirus_81.csv',
#  'coronavirus\\coronavirus_82.csv',
#  'coronavirus\\coronavirus_83.csv',
#  'coronavirus\\coronavirus_84.csv',
#  'coronavirus\\coronavirus_85.csv',
#  'coronavirus\\coronavirus_86.csv',
#  'coronavirus\\coronavirus_87.csv',
#  'coronavirus\\coronavirus_88.csv',
#  'coronavirus\\coronavirus_89.csv',
#  'coronavirus\\coronavirus_9.csv',
#  'coronavirus\\coronavirus_90.csv',
#  'coronavirus\\coronavirus_91.csv',
#  'coronavirus\\coronavirus_92.csv',
#  'coronavirus\\coronavirus_93.csv',
#  'coronavirus\\coronavirus_94.csv',
#  'coronavirus\\coronavirus_95.csv',
#  'coronavirus\\coronavirus_96.csv',
#  'coronavirus\\coronavirus_97.csv',
#  'coronavirus\\coronavirus_98.csv',
#  'coronavirus\\coronavirus_99.csv']

# %%
df = pd.concat(map(pd.read_csv, files), ignore_index=True)

# %%
df
# Out:
#               id                      name  \
# 0      238316428                  COVID-19
# 1      235374822                  COVID-19
# 2      239777191               coronavirus
# 3      237129709               coronavirus
# 4      234936988                      ncov
# ...          ...                       ...
# 15237  270364345      covid-berlin-scraper
# 15238  270337965                   Covid19
# 15239  270412711          CovidDataParsers
# 15240  270428942             COVID-Compare
# 15241  270194719  LUSIP-Sentiment-Analysis
#
#                                   full_name  \
# 0                   CSSEGISandData/COVID-19
# 1                    midas-network/COVID-19
# 2                   RamiKrispin/coronavirus
# 3                 FoldingAtHome/coronavirus
# 4                           nextstrain/ncov
# ...                                     ...
# 15237     jakubvalenta/covid-berlin-scraper
# 15238                   Fgazzelloni/Covid19
# 15239            tudorpop9/CovidDataParsers
# 15240             Ashwins9001/COVID-Compare
# 15241  tanmayvijay/LUSIP-Sentiment-Analysis
#
#                                              description  \
# 0      Novel Coronavirus (COVID-19) Cases, provided b...
# 1                      2019 novel coronavirus repository
# 2                                The coronavirus dataset
# 3                          Folding@home COVID-19 efforts
# 4      Nextstrain build for novel coronavirus SARS-CoV-2
# ...                                                  ...
# 15237  Download coronavirus data from the official pr...
# 15238          This repository is about Covid19 Outbreak
# 15239  Programs used to refine the raw data from http...
# 15240  Find keyword trends (Using k-means and gaussia...
# 15241  This repository contains all code and work fil...
#
#                                         contributors_url  archived  disabled  \
# 0      https://api.github.com/repos/CSSEGISandData/CO...     False     False
# 1      https://api.github.com/repos/midas-network/COV...     False     False
# 2      https://api.github.com/repos/RamiKrispin/coron...     False     False
# 3      https://api.github.com/repos/FoldingAtHome/cor...     False     False
# 4      https://api.github.com/repos/nextstrain/ncov/c...     False     False
# ...                                                  ...       ...       ...
# 15237  https://api.github.com/repos/jakubvalenta/covi...     False     False
# 15238  https://api.github.com/repos/Fgazzelloni/Covid...     False     False
# 15239  https://api.github.com/repos/tudorpop9/CovidDa...     False     False
# 15240  https://api.github.com/repos/Ashwins9001/COVID...     False     False
# 15241  https://api.github.com/repos/tanmayvijay/LUSIP...     False     False
#
#        stargazers_count  watchers_count  forks_count  ...  has_wiki  \
# 0                 27211           27211        17432  ...      True
# 1                   642             642          221  ...      True
# 2                   394             394          175  ...      True
# 3                  1115            1115           87  ...      True
# 4                  1208            1208          343  ...      True
# ...                 ...             ...          ...  ...       ...
# 15237                 1               1            0  ...      True
# 15238                 0               0            0  ...      True
# 15239                 0               0            0  ...      True
# 15240                 0               0            0  ...      True
# 15241                 0               0            1  ...      True
#
#                                                 homepage  \
# 0      https://systems.jhu.edu/research/public-health...
# 1                                                    NaN
# 2             https://ramikrispin.github.io/coronavirus/
# 3                              https://foldingathome.org
# 4                            https://nextstrain.org/ncov
# ...                                                  ...
# 15237                                                NaN
# 15238                                                NaN
# 15239                                                NaN
# 15240                                                NaN
# 15241                                                NaN
#
#                                                 html_url  license  \
# 0             https://github.com/CSSEGISandData/COVID-19      NaN
# 1              https://github.com/midas-network/COVID-19      NaN
# 2             https://github.com/RamiKrispin/coronavirus      NaN
# 3           https://github.com/FoldingAtHome/coronavirus      NaN
# 4                     https://github.com/nextstrain/ncov      NaN
# ...                                                  ...      ...
# 15237  https://github.com/jakubvalenta/covid-berlin-s...      NaN
# 15238             https://github.com/Fgazzelloni/Covid19      NaN
# 15239      https://github.com/tudorpop9/CovidDataParsers      NaN
# 15240       https://github.com/Ashwins9001/COVID-Compare      NaN
# 15241  https://github.com/tanmayvijay/LUSIP-Sentiment...      NaN
#
#                language            created_at             pushed_at  \
# 0                   NaN  2020-02-04T22:03:53Z  2021-08-14T11:35:08Z
# 1                   TeX  2020-01-21T15:27:23Z  2021-08-12T20:15:14Z
# 2                     R  2020-02-11T14:08:06Z  2021-08-14T08:19:49Z
# 3                Python  2020-01-30T03:12:19Z  2020-10-27T03:29:18Z
# 4                Python  2020-01-19T17:23:17Z  2021-08-13T12:36:06Z
# ...                 ...                   ...                   ...
# 15237              HTML  2020-06-07T16:26:05Z  2021-06-04T09:02:03Z
# 15238                 R  2020-06-07T14:53:09Z  2021-04-03T17:13:27Z
# 15239              Java  2020-06-07T19:39:56Z  2020-06-07T19:45:31Z
# 15240  Jupyter Notebook  2020-06-07T20:50:54Z  2020-06-07T21:06:09Z
# 15241  Jupyter Notebook  2020-06-07T04:45:10Z  2020-06-18T05:54:21Z
#
#                  updated_at  \
# 0      2021-08-14T11:56:01Z
# 1      2021-08-12T20:15:21Z
# 2      2021-08-14T08:19:52Z
# 3      2021-08-09T21:17:36Z
# 4      2021-08-13T12:36:10Z
# ...                     ...
# 15237  2021-06-04T09:01:29Z
# 15238  2021-04-03T17:13:29Z
# 15239  2020-06-07T19:45:36Z
# 15240  2020-08-03T20:18:37Z
# 15241  2020-09-13T05:24:08Z
#
#                                                  svn_url     owner.login
# 0             https://github.com/CSSEGISandData/COVID-19  CSSEGISandData
# 1              https://github.com/midas-network/COVID-19   midas-network
# 2             https://github.com/RamiKrispin/coronavirus     RamiKrispin
# 3           https://github.com/FoldingAtHome/coronavirus   FoldingAtHome
# 4                     https://github.com/nextstrain/ncov      nextstrain
# ...                                                  ...             ...
# 15237  https://github.com/jakubvalenta/covid-berlin-s...    jakubvalenta
# 15238             https://github.com/Fgazzelloni/Covid19     Fgazzelloni
# 15239      https://github.com/tudorpop9/CovidDataParsers       tudorpop9
# 15240       https://github.com/Ashwins9001/COVID-Compare     Ashwins9001
# 15241  https://github.com/tanmayvijay/LUSIP-Sentiment...     tanmayvijay
#
# [15242 rows x 24 columns]

# %%
df.to_csv(r'coronavirus_merged.csv', index = False, encoding="utf-8-sig")

# %% [markdown]
# ### Unión de los cuatro datasets

# %%
df_completo = pd.DataFrame(columns=used_cols)

coronavirus = pd.read_csv('coronavirus_merged.csv')
covid = pd.read_csv('covid_merged.csv')
covid19 = pd.read_csv('covid19_merged.csv')
covid_19 = pd.read_csv('covid-19_merged.csv')

dataframes = [coronavirus, covid, covid19, covid_19]

# %%
for df in dataframes:
    df_completo = df_completo.append(df)

# %%
df_completo
# Out:
#                id                          name  \
# 0       238316428                      COVID-19
# 1       235374822                      COVID-19
# 2       239777191                   coronavirus
# 3       237129709                   coronavirus
# 4       234936988                          ncov
# ...           ...                           ...
# 110986  270364345          covid-berlin-scraper
# 110987  270393880  PAP_V20_Covid_SocialAnalysis
# 110988  270466209                         ADLTS
# 110989  270379783                        covidn
# 110990  270443985                 Check-InToday
#
#                                            full_name  \
# 0                            CSSEGISandData/COVID-19
# 1                             midas-network/COVID-19
# 2                            RamiKrispin/coronavirus
# 3                          FoldingAtHome/coronavirus
# 4                                    nextstrain/ncov
# ...                                              ...
# 110986             jakubvalenta/covid-berlin-scraper
# 110987  AraceliCastillo/PAP_V20_Covid_SocialAnalysis
# 110988                         trevinofernando/ADLTS
# 110989                                  aiosk/covidn
# 110990                       BlueWing0/Check-InToday
#
#                                               description  \
# 0       Novel Coronavirus (COVID-19) Cases, provided b...
# 1                       2019 novel coronavirus repository
# 2                                 The coronavirus dataset
# 3                           Folding@home COVID-19 efforts
# 4       Nextstrain build for novel coronavirus SARS-CoV-2
# ...                                                   ...
# 110986  Download coronavirus data from the official pr...
# 110987  En este PAP, se busca desarrollar un dashboard...
# 110988  A Unity Simulation for the Automated Drone Las...
# 110989  covid19 cases both national and provinces in i...
# 110990  What's one thing we as a community miss during...
#
#                                          contributors_url archived disabled  \
# 0       https://api.github.com/repos/CSSEGISandData/CO...    False    False
# 1       https://api.github.com/repos/midas-network/COV...    False    False
# 2       https://api.github.com/repos/RamiKrispin/coron...    False    False
# 3       https://api.github.com/repos/FoldingAtHome/cor...    False    False
# 4       https://api.github.com/repos/nextstrain/ncov/c...    False    False
# ...                                                   ...      ...      ...
# 110986  https://api.github.com/repos/jakubvalenta/covi...    False    False
# 110987  https://api.github.com/repos/AraceliCastillo/P...    False    False
# 110988  https://api.github.com/repos/trevinofernando/A...    False    False
# 110989  https://api.github.com/repos/aiosk/covidn/cont...    False    False
# 110990  https://api.github.com/repos/BlueWing0/Check-I...    False    False
#
#        stargazers_count watchers_count forks_count  ... has_wiki  \
# 0                 27211          27211       17432  ...     True
# 1                   642            642         221  ...     True
# 2                   394            394         175  ...     True
# 3                  1115           1115          87  ...     True
# 4                  1208           1208         343  ...     True
# ...                 ...            ...         ...  ...      ...
# 110986                1              1           0  ...     True
# 110987                0              0           0  ...     True
# 110988                0              0           0  ...     True
# 110989                0              0           0  ...     True
# 110990                0              0           0  ...     True
#
#                                                  homepage  \
# 0       https://systems.jhu.edu/research/public-health...
# 1                                                     NaN
# 2              https://ramikrispin.github.io/coronavirus/
# 3                               https://foldingathome.org
# 4                             https://nextstrain.org/ncov
# ...                                                   ...
# 110986                                                NaN
# 110987                                                NaN
# 110988                                                NaN
# 110989                    https://aiosk.github.io/covidn/
# 110990                                                NaN
#
#                                                  html_url license  \
# 0              https://github.com/CSSEGISandData/COVID-19     NaN
# 1               https://github.com/midas-network/COVID-19     NaN
# 2              https://github.com/RamiKrispin/coronavirus     NaN
# 3            https://github.com/FoldingAtHome/coronavirus     NaN
# 4                      https://github.com/nextstrain/ncov     NaN
# ...                                                   ...     ...
# 110986  https://github.com/jakubvalenta/covid-berlin-s...     NaN
# 110987  https://github.com/AraceliCastillo/PAP_V20_Cov...     NaN
# 110988           https://github.com/trevinofernando/ADLTS     NaN
# 110989                    https://github.com/aiosk/covidn     NaN
# 110990         https://github.com/BlueWing0/Check-InToday     NaN
#
#                 language            created_at             pushed_at  \
# 0                    NaN  2020-02-04T22:03:53Z  2021-08-14T11:35:08Z
# 1                    TeX  2020-01-21T15:27:23Z  2021-08-12T20:15:14Z
# 2                      R  2020-02-11T14:08:06Z  2021-08-14T08:19:49Z
# 3                 Python  2020-01-30T03:12:19Z  2020-10-27T03:29:18Z
# 4                 Python  2020-01-19T17:23:17Z  2021-08-13T12:36:06Z
# ...                  ...                   ...                   ...
# 110986              HTML  2020-06-07T16:26:05Z  2021-06-04T09:02:03Z
# 110987  Jupyter Notebook  2020-06-07T18:21:52Z  2020-06-16T17:43:36Z
# 110988               C++  2020-06-07T23:53:01Z  2020-12-05T16:45:14Z
# 110989               Vue  2020-06-07T17:25:40Z  2021-08-12T16:56:47Z
# 110990               NaN  2020-06-07T21:59:28Z  2020-06-07T21:59:29Z
#
#                   updated_at  \
# 0       2021-08-14T11:56:01Z
# 1       2021-08-12T20:15:21Z
# 2       2021-08-14T08:19:52Z
# 3       2021-08-09T21:17:36Z
# 4       2021-08-13T12:36:10Z
# ...                      ...
# 110986  2021-06-04T09:01:29Z
# 110987  2020-06-16T17:43:38Z
# 110988  2020-12-05T16:45:16Z
# 110989  2020-09-21T20:36:47Z
# 110990  2020-06-07T21:59:28Z
#
#                                                   svn_url      owner.login
# 0              https://github.com/CSSEGISandData/COVID-19   CSSEGISandData
# 1               https://github.com/midas-network/COVID-19    midas-network
# 2              https://github.com/RamiKrispin/coronavirus      RamiKrispin
# 3            https://github.com/FoldingAtHome/coronavirus    FoldingAtHome
# 4                      https://github.com/nextstrain/ncov       nextstrain
# ...                                                   ...              ...
# 110986  https://github.com/jakubvalenta/covid-berlin-s...     jakubvalenta
# 110987  https://github.com/AraceliCastillo/PAP_V20_Cov...  AraceliCastillo
# 110988           https://github.com/trevinofernando/ADLTS  trevinofernando
# 110989                    https://github.com/aiosk/covidn            aiosk
# 110990         https://github.com/BlueWing0/Check-InToday        BlueWing0
#
# [337195 rows x 24 columns]

# %%
df_completo.shape[0]
# Out:
# 337195

# %% [markdown]
# ### Limpieza y preprocesamiento

# %% [markdown]
# Eliminamos las filas duplicadas.

# %%
print(df_completo.duplicated(['id']).sum())
# Out:
# 159125

# %%
df_deduplicado = df_completo.drop_duplicates(subset=['id'])

# %%
df_deduplicado
# Out:
#                id                             name  \
# 0       238316428                         COVID-19
# 1       235374822                         COVID-19
# 2       239777191                      coronavirus
# 3       237129709                      coronavirus
# 4       234936988                             ncov
# ...           ...                              ...
# 110402  269527538  OpenWeatherMap-concat-histories
# 110652  270034436                    mzansi_corona
# 110656  269906994              face-mask-detection
# 110661  270013759                         frontend
# 110662  270006438                          backend
#
#                                      full_name  \
# 0                      CSSEGISandData/COVID-19
# 1                       midas-network/COVID-19
# 2                      RamiKrispin/coronavirus
# 3                    FoldingAtHome/coronavirus
# 4                              nextstrain/ncov
# ...                                        ...
# 110402  ALT-F1/OpenWeatherMap-concat-histories
# 110652             marvinIsSacul/mzansi_corona
# 110656      jahnavi-prasad/face-mask-detection
# 110661                        Tackode/frontend
# 110662                         Tackode/backend
#
#                                               description  \
# 0       Novel Coronavirus (COVID-19) Cases, provided b...
# 1                       2019 novel coronavirus repository
# 2                                 The coronavirus dataset
# 3                           Folding@home COVID-19 efforts
# 4       Nextstrain build for novel coronavirus SARS-CoV-2
# ...                                                   ...
# 110402  Concatenate histories weather data collected b...
# 110652  Flutter app about South Africa's Corona Virus ...
# 110656  Simple project to detect if a person is wearin...
# 110661                               Frontend for Tackode
# 110662                                Backend for Tackode
#
#                                          contributors_url archived disabled  \
# 0       https://api.github.com/repos/CSSEGISandData/CO...    False    False
# 1       https://api.github.com/repos/midas-network/COV...    False    False
# 2       https://api.github.com/repos/RamiKrispin/coron...    False    False
# 3       https://api.github.com/repos/FoldingAtHome/cor...    False    False
# 4       https://api.github.com/repos/nextstrain/ncov/c...    False    False
# ...                                                   ...      ...      ...
# 110402  https://api.github.com/repos/ALT-F1/OpenWeathe...    False    False
# 110652  https://api.github.com/repos/marvinIsSacul/mza...    False    False
# 110656  https://api.github.com/repos/jahnavi-prasad/fa...    False    False
# 110661  https://api.github.com/repos/Tackode/frontend/...    False    False
# 110662  https://api.github.com/repos/Tackode/backend/c...    False    False
#
#        stargazers_count watchers_count forks_count  ... has_wiki  \
# 0                 27211          27211       17432  ...     True
# 1                   642            642         221  ...     True
# 2                   394            394         175  ...     True
# 3                  1115           1115          87  ...     True
# 4                  1208           1208         343  ...     True
# ...                 ...            ...         ...  ...      ...
# 110402                1              1           0  ...     True
# 110652                0              0           0  ...     True
# 110656                6              6           7  ...     True
# 110661                0              0           0  ...     True
# 110662                0              0           0  ...     True
#
#                                                  homepage  \
# 0       https://systems.jhu.edu/research/public-health...
# 1                                                     NaN
# 2              https://ramikrispin.github.io/coronavirus/
# 3                               https://foldingathome.org
# 4                             https://nextstrain.org/ncov
# ...                                                   ...
# 110402                               http://www.alt-f1.be
# 110652                                                NaN
# 110656                                                NaN
# 110661                                https://tackode.com
# 110662                                https://tackode.com
#
#                                                  html_url license language  \
# 0              https://github.com/CSSEGISandData/COVID-19     NaN      NaN
# 1               https://github.com/midas-network/COVID-19     NaN      TeX
# 2              https://github.com/RamiKrispin/coronavirus     NaN        R
# 3            https://github.com/FoldingAtHome/coronavirus     NaN   Python
# 4                      https://github.com/nextstrain/ncov     NaN   Python
# ...                                                   ...     ...      ...
# 110402  https://github.com/ALT-F1/OpenWeatherMap-conca...     NaN   Python
# 110652     https://github.com/marvinIsSacul/mzansi_corona     NaN     Dart
# 110656  https://github.com/jahnavi-prasad/face-mask-de...     NaN   Python
# 110661                https://github.com/Tackode/frontend     NaN      Vue
# 110662                 https://github.com/Tackode/backend     NaN     Rust
#
#                   created_at             pushed_at            updated_at  \
# 0       2020-02-04T22:03:53Z  2021-08-14T11:35:08Z  2021-08-14T11:56:01Z
# 1       2020-01-21T15:27:23Z  2021-08-12T20:15:14Z  2021-08-12T20:15:21Z
# 2       2020-02-11T14:08:06Z  2021-08-14T08:19:49Z  2021-08-14T08:19:52Z
# 3       2020-01-30T03:12:19Z  2020-10-27T03:29:18Z  2021-08-09T21:17:36Z
# 4       2020-01-19T17:23:17Z  2021-08-13T12:36:06Z  2021-08-13T12:36:10Z
# ...                      ...                   ...                   ...
# 110402  2020-06-05T04:04:46Z  2021-08-12T13:30:11Z  2020-06-08T12:44:27Z
# 110652  2020-06-06T16:15:43Z  2020-07-22T12:22:12Z  2021-03-08T18:24:34Z
# 110656  2020-06-06T07:39:31Z  2020-06-06T07:46:00Z  2021-05-03T13:00:00Z
# 110661  2020-06-06T14:57:50Z  2021-08-12T04:05:02Z  2021-01-11T08:38:35Z
# 110662  2020-06-06T14:30:13Z  2021-08-13T04:03:31Z  2021-05-26T08:44:01Z
#
#                                                   svn_url     owner.login
# 0              https://github.com/CSSEGISandData/COVID-19  CSSEGISandData
# 1               https://github.com/midas-network/COVID-19   midas-network
# 2              https://github.com/RamiKrispin/coronavirus     RamiKrispin
# 3            https://github.com/FoldingAtHome/coronavirus   FoldingAtHome
# 4                      https://github.com/nextstrain/ncov      nextstrain
# ...                                                   ...             ...
# 110402  https://github.com/ALT-F1/OpenWeatherMap-conca...          ALT-F1
# 110652     https://github.com/marvinIsSacul/mzansi_corona   marvinIsSacul
# 110656  https://github.com/jahnavi-prasad/face-mask-de...  jahnavi-prasad
# 110661                https://github.com/Tackode/frontend         Tackode
# 110662                 https://github.com/Tackode/backend         Tackode
#
# [178070 rows x 24 columns]

# %%
# Exportamos a CSV para no perder el progreso
df_deduplicado.to_csv(r'df_deduplicado.csv', index = False, encoding="utf-8-sig")

# %% [markdown]
# Eliminamos la columna license, obtenida por error y sin haberse parseado correctamente desde JSON a tabla por ser objeto:

# %%
df = pd.read_csv('df_deduplicado.csv')

df_sin_license = df.drop(columns=['license'])

# %% [markdown]
# Finalmente lo exportamos de nuevo:

# %%
df_sin_license.to_csv(r'df_repositorios.csv', index = False, encoding="utf-8-sig")

# %% [markdown]
# ------

# %% [markdown]
# ## Filtrado

# %%
df = pd.read_csv('df_repositorios.csv')
df
# Out:
#                id                             name  \
# 0       238316428                         COVID-19
# 1       235374822                         COVID-19
# 2       239777191                      coronavirus
# 3       237129709                      coronavirus
# 4       234936988                             ncov
# ...           ...                              ...
# 178065  269527538  OpenWeatherMap-concat-histories
# 178066  270034436                    mzansi_corona
# 178067  269906994              face-mask-detection
# 178068  270013759                         frontend
# 178069  270006438                          backend
#
#                                      full_name  \
# 0                      CSSEGISandData/COVID-19
# 1                       midas-network/COVID-19
# 2                      RamiKrispin/coronavirus
# 3                    FoldingAtHome/coronavirus
# 4                              nextstrain/ncov
# ...                                        ...
# 178065  ALT-F1/OpenWeatherMap-concat-histories
# 178066             marvinIsSacul/mzansi_corona
# 178067      jahnavi-prasad/face-mask-detection
# 178068                        Tackode/frontend
# 178069                         Tackode/backend
#
#                                               description  \
# 0       Novel Coronavirus (COVID-19) Cases, provided b...
# 1                       2019 novel coronavirus repository
# 2                                 The coronavirus dataset
# 3                           Folding@home COVID-19 efforts
# 4       Nextstrain build for novel coronavirus SARS-CoV-2
# ...                                                   ...
# 178065  Concatenate histories weather data collected b...
# 178066  Flutter app about South Africa's Corona Virus ...
# 178067  Simple project to detect if a person is wearin...
# 178068                               Frontend for Tackode
# 178069                                Backend for Tackode
#
#                                          contributors_url  archived  disabled  \
# 0       https://api.github.com/repos/CSSEGISandData/CO...     False     False
# 1       https://api.github.com/repos/midas-network/COV...     False     False
# 2       https://api.github.com/repos/RamiKrispin/coron...     False     False
# 3       https://api.github.com/repos/FoldingAtHome/cor...     False     False
# 4       https://api.github.com/repos/nextstrain/ncov/c...     False     False
# ...                                                   ...       ...       ...
# 178065  https://api.github.com/repos/ALT-F1/OpenWeathe...     False     False
# 178066  https://api.github.com/repos/marvinIsSacul/mza...     False     False
# 178067  https://api.github.com/repos/jahnavi-prasad/fa...     False     False
# 178068  https://api.github.com/repos/Tackode/frontend/...     False     False
# 178069  https://api.github.com/repos/Tackode/backend/c...     False     False
#
#         stargazers_count  watchers_count  forks_count  ...  has_projects  \
# 0                  27211           27211        17432  ...          True
# 1                    642             642          221  ...          True
# 2                    394             394          175  ...          True
# 3                   1115            1115           87  ...          True
# 4                   1208            1208          343  ...          True
# ...                  ...             ...          ...  ...           ...
# 178065                 1               1            0  ...          True
# 178066                 0               0            0  ...          True
# 178067                 6               6            7  ...          True
# 178068                 0               0            0  ...          True
# 178069                 0               0            0  ...          True
#
#         has_wiki                                           homepage  \
# 0           True  https://systems.jhu.edu/research/public-health...
# 1           True                                                NaN
# 2           True         https://ramikrispin.github.io/coronavirus/
# 3           True                          https://foldingathome.org
# 4           True                        https://nextstrain.org/ncov
# ...          ...                                                ...
# 178065      True                               http://www.alt-f1.be
# 178066      True                                                NaN
# 178067      True                                                NaN
# 178068      True                                https://tackode.com
# 178069      True                                https://tackode.com
#
#                                                  html_url  language  \
# 0              https://github.com/CSSEGISandData/COVID-19       NaN
# 1               https://github.com/midas-network/COVID-19       TeX
# 2              https://github.com/RamiKrispin/coronavirus         R
# 3            https://github.com/FoldingAtHome/coronavirus    Python
# 4                      https://github.com/nextstrain/ncov    Python
# ...                                                   ...       ...
# 178065  https://github.com/ALT-F1/OpenWeatherMap-conca...    Python
# 178066     https://github.com/marvinIsSacul/mzansi_corona      Dart
# 178067  https://github.com/jahnavi-prasad/face-mask-de...    Python
# 178068                https://github.com/Tackode/frontend       Vue
# 178069                 https://github.com/Tackode/backend      Rust
#
#                   created_at             pushed_at            updated_at  \
# 0       2020-02-04T22:03:53Z  2021-08-14T11:35:08Z  2021-08-14T11:56:01Z
# 1       2020-01-21T15:27:23Z  2021-08-12T20:15:14Z  2021-08-12T20:15:21Z
# 2       2020-02-11T14:08:06Z  2021-08-14T08:19:49Z  2021-08-14T08:19:52Z
# 3       2020-01-30T03:12:19Z  2020-10-27T03:29:18Z  2021-08-09T21:17:36Z
# 4       2020-01-19T17:23:17Z  2021-08-13T12:36:06Z  2021-08-13T12:36:10Z
# ...                      ...                   ...                   ...
# 178065  2020-06-05T04:04:46Z  2021-08-12T13:30:11Z  2020-06-08T12:44:27Z
# 178066  2020-06-06T16:15:43Z  2020-07-22T12:22:12Z  2021-03-08T18:24:34Z
# 178067  2020-06-06T07:39:31Z  2020-06-06T07:46:00Z  2021-05-03T13:00:00Z
# 178068  2020-06-06T14:57:50Z  2021-08-12T04:05:02Z  2021-01-11T08:38:35Z
# 178069  2020-06-06T14:30:13Z  2021-08-13T04:03:31Z  2021-05-26T08:44:01Z
#
#                                                   svn_url     owner.login
# 0              https://github.com/CSSEGISandData/COVID-19  CSSEGISandData
# 1               https://github.com/midas-network/COVID-19   midas-network
# 2              https://github.com/RamiKrispin/coronavirus     RamiKrispin
# 3            https://github.com/FoldingAtHome/coronavirus   FoldingAtHome
# 4                      https://github.com/nextstrain/ncov      nextstrain
# ...                                                   ...             ...
# 178065  https://github.com/ALT-F1/OpenWeatherMap-conca...          ALT-F1
# 178066     https://github.com/marvinIsSacul/mzansi_corona   marvinIsSacul
# 178067  https://github.com/jahnavi-prasad/face-mask-de...  jahnavi-prasad
# 178068                https://github.com/Tackode/frontend         Tackode
# 178069                 https://github.com/Tackode/backend         Tackode
#
# [178070 rows x 23 columns]

# %% [markdown]
# Con la librería pandasgui podemos visualizar mejor los dataframes de Pandas:

# %%
from pandasgui import show
show(df)
# Out:
# PandasGUI INFO — pandasgui.gui — Opening PandasGUI

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178070 entries, 0 to 178069
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                178070 non-null  int64
#  1   name              178070 non-null  object
#  2   full_name         178070 non-null  object
#  3   description       100021 non-null  object
#  4   contributors_url  178070 non-null  object
#  5   archived          178070 non-null  bool
#  6   disabled          178070 non-null  bool
#  7   stargazers_count  178070 non-null  int64
#  8   watchers_count    178070 non-null  int64
#  9   forks_count       178070 non-null  int64
#  10  has_downloads     178070 non-null  bool
#  11  has_issues        178070 non-null  bool
#  12  has_pages         178070 non-null  bool
#  13  has_projects      178070 non-null  bool
#  14  has_wiki          178070 non-null  bool
#  15  homepage          15382 non-null   object
#  16  html_url          178070 non-null  object
#  17  language          147689 non-null  object
#  18  created_at        178070 non-null  object
#  19  pushed_at         178069 non-null  object
#  20  updated_at        178070 non-null  object
#  21  svn_url           178070 non-null  object
#  22  owner.login       178070 non-null  object
# dtypes: bool(7), int64(4), object(12)
# memory usage: 22.9+ MB

# %% [markdown]
# ## Palabras relacionadas

# %%
related_name_words = ["corona", "coronavirus", "covid", "covid19", "covid-19", "sars-cov-2", "sars-cov-2", "sars-cov", "cov", 
                 "ncov", "ncov2019", "ncov19", "19ncov", "19-ncov", "2019ncov", "2019-ncov", "virus", "pandemic", "epidemic",
                    "新冠病毒", "新型冠状病毒"]
related_description_words = ["corona", "coronavirus", "covid", "covid19", "covid-19", "sars-cov-2", "sars-cov-2", "sars-cov", 
                             "cov", "ncov", "ncov2019", "ncov19", "19ncov", "19-ncov", "2019ncov", "2019-ncov", "virus", 
                             "pandemic", "epidemic", "新冠病毒", "新型冠状病毒", "cases", "contagios" "reported", "medical", 
                             "infections", "infection", "lockdown", "viral", "mask", "vaccine", "disease", "deaths", 
                             "pneumonia"]

# %%
pattern_name = "(?i)" + '|'.join(related_name_words)
pattern_description = "(?i)" + '|'.join(related_description_words)
pattern_description
# Out:
# '(?i)corona|coronavirus|covid|covid19|covid-19|sars-cov-2|sars-cov-2|sars-cov|cov|ncov|ncov2019|ncov19|19ncov|19-ncov|2019ncov|2019-ncov|virus|pandemic|epidemic|新冠病毒|新型冠状病毒|cases|contagiosreported|medical|infections|infection|lockdown|viral|mask|vaccine|disease|deaths|pneumonia'

# %%
df = pd.read_csv('repositorios_primer_filtrado.csv')
df
# Out:
#                id                             name  \
# 0       238316428                         COVID-19
# 1       235374822                         COVID-19
# 2       239777191                      coronavirus
# 3       237129709                      coronavirus
# 4       234936988                             ncov
# ...           ...                              ...
# 178038  269527538  OpenWeatherMap-concat-histories
# 178039  270034436                    mzansi_corona
# 178040  269906994              face-mask-detection
# 178041  270013759                         frontend
# 178042  270006438                          backend
#
#                                      full_name  \
# 0                      CSSEGISandData/COVID-19
# 1                       midas-network/COVID-19
# 2                      RamiKrispin/coronavirus
# 3                    FoldingAtHome/coronavirus
# 4                              nextstrain/ncov
# ...                                        ...
# 178038  ALT-F1/OpenWeatherMap-concat-histories
# 178039             marvinIsSacul/mzansi_corona
# 178040      jahnavi-prasad/face-mask-detection
# 178041                        Tackode/frontend
# 178042                         Tackode/backend
#
#                                               description  \
# 0       Novel Coronavirus (COVID-19) Cases, provided b...
# 1                       2019 novel coronavirus repository
# 2                                 The coronavirus dataset
# 3                           Folding@home COVID-19 efforts
# 4       Nextstrain build for novel coronavirus SARS-CoV-2
# ...                                                   ...
# 178038  Concatenate histories weather data collected b...
# 178039  Flutter app about South Africa's Corona Virus ...
# 178040  Simple project to detect if a person is wearin...
# 178041                               Frontend for Tackode
# 178042                                Backend for Tackode
#
#                                          contributors_url  archived  disabled  \
# 0       https://api.github.com/repos/CSSEGISandData/CO...     False     False
# 1       https://api.github.com/repos/midas-network/COV...     False     False
# 2       https://api.github.com/repos/RamiKrispin/coron...     False     False
# 3       https://api.github.com/repos/FoldingAtHome/cor...     False     False
# 4       https://api.github.com/repos/nextstrain/ncov/c...     False     False
# ...                                                   ...       ...       ...
# 178038  https://api.github.com/repos/ALT-F1/OpenWeathe...     False     False
# 178039  https://api.github.com/repos/marvinIsSacul/mza...     False     False
# 178040  https://api.github.com/repos/jahnavi-prasad/fa...     False     False
# 178041  https://api.github.com/repos/Tackode/frontend/...     False     False
# 178042  https://api.github.com/repos/Tackode/backend/c...     False     False
#
#         stargazers_count  watchers_count  forks_count  ...  has_projects  \
# 0                  27211           27211        17432  ...          True
# 1                    642             642          221  ...          True
# 2                    394             394          175  ...          True
# 3                   1115            1115           87  ...          True
# 4                   1208            1208          343  ...          True
# ...                  ...             ...          ...  ...           ...
# 178038                 1               1            0  ...          True
# 178039                 0               0            0  ...          True
# 178040                 6               6            7  ...          True
# 178041                 0               0            0  ...          True
# 178042                 0               0            0  ...          True
#
#         has_wiki                                           homepage  \
# 0           True  https://systems.jhu.edu/research/public-health...
# 1           True                                                NaN
# 2           True         https://ramikrispin.github.io/coronavirus/
# 3           True                          https://foldingathome.org
# 4           True                        https://nextstrain.org/ncov
# ...          ...                                                ...
# 178038      True                               http://www.alt-f1.be
# 178039      True                                                NaN
# 178040      True                                                NaN
# 178041      True                                https://tackode.com
# 178042      True                                https://tackode.com
#
#                                                  html_url  language  \
# 0              https://github.com/CSSEGISandData/COVID-19       NaN
# 1               https://github.com/midas-network/COVID-19       TeX
# 2              https://github.com/RamiKrispin/coronavirus         R
# 3            https://github.com/FoldingAtHome/coronavirus    Python
# 4                      https://github.com/nextstrain/ncov    Python
# ...                                                   ...       ...
# 178038  https://github.com/ALT-F1/OpenWeatherMap-conca...    Python
# 178039     https://github.com/marvinIsSacul/mzansi_corona      Dart
# 178040  https://github.com/jahnavi-prasad/face-mask-de...    Python
# 178041                https://github.com/Tackode/frontend       Vue
# 178042                 https://github.com/Tackode/backend      Rust
#
#                   created_at             pushed_at            updated_at  \
# 0       2020-02-04T22:03:53Z  2021-08-14T11:35:08Z  2021-08-14T11:56:01Z
# 1       2020-01-21T15:27:23Z  2021-08-12T20:15:14Z  2021-08-12T20:15:21Z
# 2       2020-02-11T14:08:06Z  2021-08-14T08:19:49Z  2021-08-14T08:19:52Z
# 3       2020-01-30T03:12:19Z  2020-10-27T03:29:18Z  2021-08-09T21:17:36Z
# 4       2020-01-19T17:23:17Z  2021-08-13T12:36:06Z  2021-08-13T12:36:10Z
# ...                      ...                   ...                   ...
# 178038  2020-06-05T04:04:46Z  2021-08-12T13:30:11Z  2020-06-08T12:44:27Z
# 178039  2020-06-06T16:15:43Z  2020-07-22T12:22:12Z  2021-03-08T18:24:34Z
# 178040  2020-06-06T07:39:31Z  2020-06-06T07:46:00Z  2021-05-03T13:00:00Z
# 178041  2020-06-06T14:57:50Z  2021-08-12T04:05:02Z  2021-01-11T08:38:35Z
# 178042  2020-06-06T14:30:13Z  2021-08-13T04:03:31Z  2021-05-26T08:44:01Z
#
#                                                   svn_url     owner.login
# 0              https://github.com/CSSEGISandData/COVID-19  CSSEGISandData
# 1               https://github.com/midas-network/COVID-19   midas-network
# 2              https://github.com/RamiKrispin/coronavirus     RamiKrispin
# 3            https://github.com/FoldingAtHome/coronavirus   FoldingAtHome
# 4                      https://github.com/nextstrain/ncov      nextstrain
# ...                                                   ...             ...
# 178038  https://github.com/ALT-F1/OpenWeatherMap-conca...          ALT-F1
# 178039     https://github.com/marvinIsSacul/mzansi_corona   marvinIsSacul
# 178040  https://github.com/jahnavi-prasad/face-mask-de...  jahnavi-prasad
# 178041                https://github.com/Tackode/frontend         Tackode
# 178042                 https://github.com/Tackode/backend         Tackode
#
# [178043 rows x 23 columns]

# %% [markdown]
# ### Comprobación solo en el nombre:

# %% [markdown]
# Dataframe resultante con columna *full_name* conteniendo el patrón:

# %%
df_in_name_boolean = df.full_name.str.contains(pattern_name)
df_in_name_boolean
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 178065    False
# 178066     True
# 178067    False
# 178068    False
# 178069    False
# Name: full_name, Length: 178070, dtype: bool

# %%
df_in_name_boolean.sum()
# Out:
# 159157

# %%
df_in_name = df[df_in_name_boolean]
df_in_name
# Out:
#                id                 name                        full_name  \
# 0       238316428             COVID-19          CSSEGISandData/COVID-19
# 1       235374822             COVID-19           midas-network/COVID-19
# 2       239777191          coronavirus          RamiKrispin/coronavirus
# 3       237129709          coronavirus        FoldingAtHome/coronavirus
# 4       234936988                 ncov                  nextstrain/ncov
# ...           ...                  ...                              ...
# 178054  268148998  Epidemics-Modelling  pierpaolo28/Epidemics-Modelling
# 178056  268314248                   UI                    CovidToday/UI
# 178061  268770101             coroname                mariabnd/coroname
# 178064  269601203      CoronaDashboard            StefH/CoronaDashboard
# 178066  270034436        mzansi_corona      marvinIsSacul/mzansi_corona
#
#                                               description  \
# 0       Novel Coronavirus (COVID-19) Cases, provided b...
# 1                       2019 novel coronavirus repository
# 2                                 The coronavirus dataset
# 3                           Folding@home COVID-19 efforts
# 4       Nextstrain build for novel coronavirus SARS-CoV-2
# ...                                                   ...
# 178054  Modelling and tracking of epidemics data analy...
# 178056                                                NaN
# 178061                                                NaN
# 178064  Een Corona Dashboard gebaseerd op cijfers van ...
# 178066  Flutter app about South Africa's Corona Virus ...
#
#                                          contributors_url  archived  disabled  \
# 0       https://api.github.com/repos/CSSEGISandData/CO...     False     False
# 1       https://api.github.com/repos/midas-network/COV...     False     False
# 2       https://api.github.com/repos/RamiKrispin/coron...     False     False
# 3       https://api.github.com/repos/FoldingAtHome/cor...     False     False
# 4       https://api.github.com/repos/nextstrain/ncov/c...     False     False
# ...                                                   ...       ...       ...
# 178054  https://api.github.com/repos/pierpaolo28/Epide...     False     False
# 178056  https://api.github.com/repos/CovidToday/UI/con...     False     False
# 178061  https://api.github.com/repos/mariabnd/coroname...     False     False
# 178064  https://api.github.com/repos/StefH/CoronaDashb...     False     False
# 178066  https://api.github.com/repos/marvinIsSacul/mza...     False     False
#
#         stargazers_count  watchers_count  forks_count  ...  has_projects  \
# 0                  27211           27211        17432  ...          True
# 1                    642             642          221  ...          True
# 2                    394             394          175  ...          True
# 3                   1115            1115           87  ...          True
# 4                   1208            1208          343  ...          True
# ...                  ...             ...          ...  ...           ...
# 178054                 1               1            0  ...          True
# 178056                 0               0            0  ...          True
# 178061                 0               0            0  ...          True
# 178064                 1               1            0  ...          True
# 178066                 0               0            0  ...          True
#
#         has_wiki                                           homepage  \
# 0           True  https://systems.jhu.edu/research/public-health...
# 1           True                                                NaN
# 2           True         https://ramikrispin.github.io/coronavirus/
# 3           True                          https://foldingathome.org
# 4           True                        https://nextstrain.org/ncov
# ...          ...                                                ...
# 178054      True                           http://3.22.240.181:8501
# 178056     False                                                NaN
# 178061      True                                                NaN
# 178064      True                                                NaN
# 178066      True                                                NaN
#
#                                                  html_url          language  \
# 0              https://github.com/CSSEGISandData/COVID-19               NaN
# 1               https://github.com/midas-network/COVID-19               TeX
# 2              https://github.com/RamiKrispin/coronavirus                 R
# 3            https://github.com/FoldingAtHome/coronavirus            Python
# 4                      https://github.com/nextstrain/ncov            Python
# ...                                                   ...               ...
# 178054  https://github.com/pierpaolo28/Epidemics-Model...  Jupyter Notebook
# 178056                   https://github.com/CovidToday/UI        JavaScript
# 178061               https://github.com/mariabnd/coroname               NaN
# 178064           https://github.com/StefH/CoronaDashboard                C#
# 178066     https://github.com/marvinIsSacul/mzansi_corona              Dart
#
#                   created_at             pushed_at            updated_at  \
# 0       2020-02-04T22:03:53Z  2021-08-14T11:35:08Z  2021-08-14T11:56:01Z
# 1       2020-01-21T15:27:23Z  2021-08-12T20:15:14Z  2021-08-12T20:15:21Z
# 2       2020-02-11T14:08:06Z  2021-08-14T08:19:49Z  2021-08-14T08:19:52Z
# 3       2020-01-30T03:12:19Z  2020-10-27T03:29:18Z  2021-08-09T21:17:36Z
# 4       2020-01-19T17:23:17Z  2021-08-13T12:36:06Z  2021-08-13T12:36:10Z
# ...                      ...                   ...                   ...
# 178054  2020-05-30T19:48:56Z  2020-11-17T19:44:00Z  2021-01-30T21:40:09Z
# 178056  2020-05-31T16:02:18Z  2021-08-12T15:32:29Z  2020-09-03T02:43:14Z
# 178061  2020-06-02T10:25:35Z  2021-01-06T12:52:34Z  2021-01-06T12:52:37Z
# 178064  2020-06-05T10:29:30Z  2021-07-19T15:54:46Z  2021-07-19T15:52:49Z
# 178066  2020-06-06T16:15:43Z  2020-07-22T12:22:12Z  2021-03-08T18:24:34Z
#
#                                                   svn_url     owner.login
# 0              https://github.com/CSSEGISandData/COVID-19  CSSEGISandData
# 1               https://github.com/midas-network/COVID-19   midas-network
# 2              https://github.com/RamiKrispin/coronavirus     RamiKrispin
# 3            https://github.com/FoldingAtHome/coronavirus   FoldingAtHome
# 4                      https://github.com/nextstrain/ncov      nextstrain
# ...                                                   ...             ...
# 178054  https://github.com/pierpaolo28/Epidemics-Model...     pierpaolo28
# 178056                   https://github.com/CovidToday/UI      CovidToday
# 178061               https://github.com/mariabnd/coroname        mariabnd
# 178064           https://github.com/StefH/CoronaDashboard           StefH
# 178066     https://github.com/marvinIsSacul/mzansi_corona   marvinIsSacul
#
# [159157 rows x 23 columns]

# %% [markdown]
# **159.157** repositorios.

# %% [markdown]
# ### Comprobación solo en la descripción:

# %% [markdown]
# Comprobamos previamente si hay repositorios con la descripción vacía:

# %%
df["description"].isnull().sum()
# Out:
# 78049

# %% [markdown]
# Existen 78049 repositorios sin descripción. Lo tendremos en cuenta a continuación.

# %%
df_in_description_boolean = df.description.str.contains(pattern_description)
df_in_description_boolean
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 178065    False
# 178066     True
# 178067     True
# 178068    False
# 178069    False
# Name: description, Length: 178070, dtype: object

# %% [markdown]
# De aquí saldrán 78049 valores que no se corresponderán a False ni True, por lo que no nos dejará filtrar el dataframe. Los convertimos a False:

# %%
print(df_in_description_boolean.isnull().sum())
# Out:
# 78049

# %%
df_in_description_boolean = df_in_description_boolean.fillna(False)

#Comprobamos si tiene valores nulos
print(df_in_description_boolean.isnull().sum())
# Out:
# 0

# %% [markdown]
# Contamos cuantos repositorios tienen las palabras relacionadas en la descripción:

# %%
df_in_description_boolean.sum()
# Out:
# 84100

# %%
df_in_description = df[df_in_description_boolean]
df_in_description
# Out:
#                id                          name  \
# 0       238316428                      COVID-19
# 1       235374822                      COVID-19
# 2       239777191                   coronavirus
# 3       237129709                   coronavirus
# 4       234936988                          ncov
# ...           ...                           ...
# 178051  267858096  face_mask_detection_openvino
# 178054  268148998           Epidemics-Modelling
# 178064  269601203               CoronaDashboard
# 178066  270034436                 mzansi_corona
# 178067  269906994           face-mask-detection
#
#                                    full_name  \
# 0                    CSSEGISandData/COVID-19
# 1                     midas-network/COVID-19
# 2                    RamiKrispin/coronavirus
# 3                  FoldingAtHome/coronavirus
# 4                            nextstrain/ncov
# ...                                      ...
# 178051  mmphego/face_mask_detection_openvino
# 178054       pierpaolo28/Epidemics-Modelling
# 178064                 StefH/CoronaDashboard
# 178066           marvinIsSacul/mzansi_corona
# 178067    jahnavi-prasad/face-mask-detection
#
#                                               description  \
# 0       Novel Coronavirus (COVID-19) Cases, provided b...
# 1                       2019 novel coronavirus repository
# 2                                 The coronavirus dataset
# 3                           Folding@home COVID-19 efforts
# 4       Nextstrain build for novel coronavirus SARS-CoV-2
# ...                                                   ...
# 178051  Detect faces and determine whether people are ...
# 178054  Modelling and tracking of epidemics data analy...
# 178064  Een Corona Dashboard gebaseerd op cijfers van ...
# 178066  Flutter app about South Africa's Corona Virus ...
# 178067  Simple project to detect if a person is wearin...
#
#                                          contributors_url  archived  disabled  \
# 0       https://api.github.com/repos/CSSEGISandData/CO...     False     False
# 1       https://api.github.com/repos/midas-network/COV...     False     False
# 2       https://api.github.com/repos/RamiKrispin/coron...     False     False
# 3       https://api.github.com/repos/FoldingAtHome/cor...     False     False
# 4       https://api.github.com/repos/nextstrain/ncov/c...     False     False
# ...                                                   ...       ...       ...
# 178051  https://api.github.com/repos/mmphego/face_mask...     False     False
# 178054  https://api.github.com/repos/pierpaolo28/Epide...     False     False
# 178064  https://api.github.com/repos/StefH/CoronaDashb...     False     False
# 178066  https://api.github.com/repos/marvinIsSacul/mza...     False     False
# 178067  https://api.github.com/repos/jahnavi-prasad/fa...     False     False
#
#         stargazers_count  watchers_count  forks_count  ...  has_projects  \
# 0                  27211           27211        17432  ...          True
# 1                    642             642          221  ...          True
# 2                    394             394          175  ...          True
# 3                   1115            1115           87  ...          True
# 4                   1208            1208          343  ...          True
# ...                  ...             ...          ...  ...           ...
# 178051                35              35           11  ...          True
# 178054                 1               1            0  ...          True
# 178064                 1               1            0  ...          True
# 178066                 0               0            0  ...          True
# 178067                 6               6            7  ...          True
#
#         has_wiki                                           homepage  \
# 0           True  https://systems.jhu.edu/research/public-health...
# 1           True                                                NaN
# 2           True         https://ramikrispin.github.io/coronavirus/
# 3           True                          https://foldingathome.org
# 4           True                        https://nextstrain.org/ncov
# ...          ...                                                ...
# 178051      True  https://blog.mphomphego.co.za/blog/2020/06/02/...
# 178054      True                           http://3.22.240.181:8501
# 178064      True                                                NaN
# 178066      True                                                NaN
# 178067      True                                                NaN
#
#                                                  html_url          language  \
# 0              https://github.com/CSSEGISandData/COVID-19               NaN
# 1               https://github.com/midas-network/COVID-19               TeX
# 2              https://github.com/RamiKrispin/coronavirus                 R
# 3            https://github.com/FoldingAtHome/coronavirus            Python
# 4                      https://github.com/nextstrain/ncov            Python
# ...                                                   ...               ...
# 178051  https://github.com/mmphego/face_mask_detection...            Python
# 178054  https://github.com/pierpaolo28/Epidemics-Model...  Jupyter Notebook
# 178064           https://github.com/StefH/CoronaDashboard                C#
# 178066     https://github.com/marvinIsSacul/mzansi_corona              Dart
# 178067  https://github.com/jahnavi-prasad/face-mask-de...            Python
#
#                   created_at             pushed_at            updated_at  \
# 0       2020-02-04T22:03:53Z  2021-08-14T11:35:08Z  2021-08-14T11:56:01Z
# 1       2020-01-21T15:27:23Z  2021-08-12T20:15:14Z  2021-08-12T20:15:21Z
# 2       2020-02-11T14:08:06Z  2021-08-14T08:19:49Z  2021-08-14T08:19:52Z
# 3       2020-01-30T03:12:19Z  2020-10-27T03:29:18Z  2021-08-09T21:17:36Z
# 4       2020-01-19T17:23:17Z  2021-08-13T12:36:06Z  2021-08-13T12:36:10Z
# ...                      ...                   ...                   ...
# 178051  2020-05-29T12:56:47Z  2021-02-16T12:18:40Z  2021-05-25T21:53:17Z
# 178054  2020-05-30T19:48:56Z  2020-11-17T19:44:00Z  2021-01-30T21:40:09Z
# 178064  2020-06-05T10:29:30Z  2021-07-19T15:54:46Z  2021-07-19T15:52:49Z
# 178066  2020-06-06T16:15:43Z  2020-07-22T12:22:12Z  2021-03-08T18:24:34Z
# 178067  2020-06-06T07:39:31Z  2020-06-06T07:46:00Z  2021-05-03T13:00:00Z
#
#                                                   svn_url     owner.login
# 0              https://github.com/CSSEGISandData/COVID-19  CSSEGISandData
# 1               https://github.com/midas-network/COVID-19   midas-network
# 2              https://github.com/RamiKrispin/coronavirus     RamiKrispin
# 3            https://github.com/FoldingAtHome/coronavirus   FoldingAtHome
# 4                      https://github.com/nextstrain/ncov      nextstrain
# ...                                                   ...             ...
# 178051  https://github.com/mmphego/face_mask_detection...         mmphego
# 178054  https://github.com/pierpaolo28/Epidemics-Model...     pierpaolo28
# 178064           https://github.com/StefH/CoronaDashboard           StefH
# 178066     https://github.com/marvinIsSacul/mzansi_corona   marvinIsSacul
# 178067  https://github.com/jahnavi-prasad/face-mask-de...  jahnavi-prasad
#
# [84100 rows x 23 columns]

# %% [markdown]
# **84.100** repositorios.

# %% [markdown]
# ### En el nombre y no la descripción:

# %%
#En el nombre:
df_in_name_not_in_description = df.full_name.str.contains(pattern_name)
df_in_name_not_in_description
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 178065    False
# 178066     True
# 178067    False
# 178068    False
# 178069    False
# Name: full_name, Length: 178070, dtype: bool

# %%
df_in_name_not_in_description = df[df_in_name_not_in_description]
df_in_name_not_in_description
# Out:
#                id                 name                        full_name  \
# 0       238316428             COVID-19          CSSEGISandData/COVID-19
# 1       235374822             COVID-19           midas-network/COVID-19
# 2       239777191          coronavirus          RamiKrispin/coronavirus
# 3       237129709          coronavirus        FoldingAtHome/coronavirus
# 4       234936988                 ncov                  nextstrain/ncov
# ...           ...                  ...                              ...
# 178054  268148998  Epidemics-Modelling  pierpaolo28/Epidemics-Modelling
# 178056  268314248                   UI                    CovidToday/UI
# 178061  268770101             coroname                mariabnd/coroname
# 178064  269601203      CoronaDashboard            StefH/CoronaDashboard
# 178066  270034436        mzansi_corona      marvinIsSacul/mzansi_corona
#
#                                               description  \
# 0       Novel Coronavirus (COVID-19) Cases, provided b...
# 1                       2019 novel coronavirus repository
# 2                                 The coronavirus dataset
# 3                           Folding@home COVID-19 efforts
# 4       Nextstrain build for novel coronavirus SARS-CoV-2
# ...                                                   ...
# 178054  Modelling and tracking of epidemics data analy...
# 178056                                                NaN
# 178061                                                NaN
# 178064  Een Corona Dashboard gebaseerd op cijfers van ...
# 178066  Flutter app about South Africa's Corona Virus ...
#
#                                          contributors_url  archived  disabled  \
# 0       https://api.github.com/repos/CSSEGISandData/CO...     False     False
# 1       https://api.github.com/repos/midas-network/COV...     False     False
# 2       https://api.github.com/repos/RamiKrispin/coron...     False     False
# 3       https://api.github.com/repos/FoldingAtHome/cor...     False     False
# 4       https://api.github.com/repos/nextstrain/ncov/c...     False     False
# ...                                                   ...       ...       ...
# 178054  https://api.github.com/repos/pierpaolo28/Epide...     False     False
# 178056  https://api.github.com/repos/CovidToday/UI/con...     False     False
# 178061  https://api.github.com/repos/mariabnd/coroname...     False     False
# 178064  https://api.github.com/repos/StefH/CoronaDashb...     False     False
# 178066  https://api.github.com/repos/marvinIsSacul/mza...     False     False
#
#         stargazers_count  watchers_count  forks_count  ...  has_projects  \
# 0                  27211           27211        17432  ...          True
# 1                    642             642          221  ...          True
# 2                    394             394          175  ...          True
# 3                   1115            1115           87  ...          True
# 4                   1208            1208          343  ...          True
# ...                  ...             ...          ...  ...           ...
# 178054                 1               1            0  ...          True
# 178056                 0               0            0  ...          True
# 178061                 0               0            0  ...          True
# 178064                 1               1            0  ...          True
# 178066                 0               0            0  ...          True
#
#         has_wiki                                           homepage  \
# 0           True  https://systems.jhu.edu/research/public-health...
# 1           True                                                NaN
# 2           True         https://ramikrispin.github.io/coronavirus/
# 3           True                          https://foldingathome.org
# 4           True                        https://nextstrain.org/ncov
# ...          ...                                                ...
# 178054      True                           http://3.22.240.181:8501
# 178056     False                                                NaN
# 178061      True                                                NaN
# 178064      True                                                NaN
# 178066      True                                                NaN
#
#                                                  html_url          language  \
# 0              https://github.com/CSSEGISandData/COVID-19               NaN
# 1               https://github.com/midas-network/COVID-19               TeX
# 2              https://github.com/RamiKrispin/coronavirus                 R
# 3            https://github.com/FoldingAtHome/coronavirus            Python
# 4                      https://github.com/nextstrain/ncov            Python
# ...                                                   ...               ...
# 178054  https://github.com/pierpaolo28/Epidemics-Model...  Jupyter Notebook
# 178056                   https://github.com/CovidToday/UI        JavaScript
# 178061               https://github.com/mariabnd/coroname               NaN
# 178064           https://github.com/StefH/CoronaDashboard                C#
# 178066     https://github.com/marvinIsSacul/mzansi_corona              Dart
#
#                   created_at             pushed_at            updated_at  \
# 0       2020-02-04T22:03:53Z  2021-08-14T11:35:08Z  2021-08-14T11:56:01Z
# 1       2020-01-21T15:27:23Z  2021-08-12T20:15:14Z  2021-08-12T20:15:21Z
# 2       2020-02-11T14:08:06Z  2021-08-14T08:19:49Z  2021-08-14T08:19:52Z
# 3       2020-01-30T03:12:19Z  2020-10-27T03:29:18Z  2021-08-09T21:17:36Z
# 4       2020-01-19T17:23:17Z  2021-08-13T12:36:06Z  2021-08-13T12:36:10Z
# ...                      ...                   ...                   ...
# 178054  2020-05-30T19:48:56Z  2020-11-17T19:44:00Z  2021-01-30T21:40:09Z
# 178056  2020-05-31T16:02:18Z  2021-08-12T15:32:29Z  2020-09-03T02:43:14Z
# 178061  2020-06-02T10:25:35Z  2021-01-06T12:52:34Z  2021-01-06T12:52:37Z
# 178064  2020-06-05T10:29:30Z  2021-07-19T15:54:46Z  2021-07-19T15:52:49Z
# 178066  2020-06-06T16:15:43Z  2020-07-22T12:22:12Z  2021-03-08T18:24:34Z
#
#                                                   svn_url     owner.login
# 0              https://github.com/CSSEGISandData/COVID-19  CSSEGISandData
# 1               https://github.com/midas-network/COVID-19   midas-network
# 2              https://github.com/RamiKrispin/coronavirus     RamiKrispin
# 3            https://github.com/FoldingAtHome/coronavirus   FoldingAtHome
# 4                      https://github.com/nextstrain/ncov      nextstrain
# ...                                                   ...             ...
# 178054  https://github.com/pierpaolo28/Epidemics-Model...     pierpaolo28
# 178056                   https://github.com/CovidToday/UI      CovidToday
# 178061               https://github.com/mariabnd/coroname        mariabnd
# 178064           https://github.com/StefH/CoronaDashboard           StefH
# 178066     https://github.com/marvinIsSacul/mzansi_corona   marvinIsSacul
#
# [159157 rows x 23 columns]

# %% [markdown]
# No en la descripción:

# %%
df_in_name_not_in_description_boolean = df.description.str.contains(pattern_description) == False
df_in_name_not_in_description_boolean
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 178065     True
# 178066    False
# 178067    False
# 178068     True
# 178069     True
# Name: description, Length: 178070, dtype: bool

# %%
df_in_name_not_in_description = df_in_name_not_in_description[df_in_name_not_in_description_boolean]
df_in_name_not_in_description
# Out:
# <ipython-input-19-efb1122a8ec8>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_in_name_not_in_description = df_in_name_not_in_description[df_in_name_not_in_description_boolean]
#                id                         name  \
# 56      238121123                  coronavirus
# 70      238965247                  coronavirus
# 86      238643080  Noval-Coronavirus-763-Cases
# 148     239239938        coronavirus-2019-nCov
# 158     242778847                  Here-Corona
# ...           ...                          ...
# 177930  259285155           Novel-Corona-India
# 177956  260912128        Covid-19-info-Counter
# 177958  261163082             Project-COVgh-V1
# 177991  264028112                 covid-19-app
# 178031  266802091          REIDCoronaHackathon
#
#                                      full_name  \
# 56                        bjwa2020/coronavirus
# 70                     weimeilin79/coronavirus
# 86      839-Studio/Noval-Coronavirus-763-Cases
# 148             C0D4-101/coronavirus-2019-nCov
# 158                       SoonGwan/Here-Corona
# ...                                        ...
# 177930         ni3mumbaikar/Novel-Corona-India
# 177956         KhanOmair/Covid-19-info-Counter
# 177958            E-B-Manohar/Project-COVgh-V1
# 177991               leoalcantara/covid-19-app
# 178031     vinnik-dmitry07/REIDCoronaHackathon
#
#                                               description  \
# 56                    新冠疫情小区分布数据（数据来自各城市卫健委等官方微信公众号和官方网站）
# 70                                Camel K Serverless Demo
# 86                 763例冠状病毒确诊患者的详细情况，包括出行轨迹、发病就诊时间、人传人情况。
# 148          Data Extracts from World Health Organization
# 158     국내, 전세계 코로나 현황을 한눈에 알아 볼 수 있으며, 여러 정보를 제공하는 웹 ...
# ...                                                   ...
# 177930  This Project is good example of web scraping u...
# 177956  This is a Project I created by me while I was ...
# 177958  Sickness Detection with 80% Val Accuracy. Trai...
# 177991                  Aplicação feita com ReactJS e PWA
# 178031  Multiple cameras recognition of prolonged inte...
#
#                                          contributors_url  archived  disabled  \
# 56      https://api.github.com/repos/bjwa2020/coronavi...     False     False
# 70      https://api.github.com/repos/weimeilin79/coron...     False     False
# 86      https://api.github.com/repos/839-Studio/Noval-...     False     False
# 148     https://api.github.com/repos/C0D4-101/coronavi...     False     False
# 158     https://api.github.com/repos/SoonGwan/Here-Cor...     False     False
# ...                                                   ...       ...       ...
# 177930  https://api.github.com/repos/ni3mumbaikar/Nove...     False     False
# 177956  https://api.github.com/repos/KhanOmair/Covid-1...     False     False
# 177958  https://api.github.com/repos/E-B-Manohar/Proje...     False     False
# 177991  https://api.github.com/repos/leoalcantara/covi...     False     False
# 178031  https://api.github.com/repos/vinnik-dmitry07/R...     False     False
#
#         stargazers_count  watchers_count  forks_count  ...  has_projects  \
# 56                    23              23            3  ...          True
# 70                     5               5            4  ...          True
# 86                    11              11            4  ...          True
# 148                    8               8            1  ...          True
# 158                    8               8            3  ...          True
# ...                  ...             ...          ...  ...           ...
# 177930                 1               1            2  ...          True
# 177956                 0               0            0  ...          True
# 177958                 7               7            3  ...          True
# 177991                 0               0            0  ...          True
# 178031                 0               0            0  ...          True
#
#         has_wiki              homepage  \
# 56          True  https://www.gubi.io/
# 70          True                   NaN
# 86          True                   NaN
# 148         True                   NaN
# 158         True                   NaN
# ...          ...                   ...
# 177930      True                   NaN
# 177956      True                   NaN
# 177958      True                   NaN
# 177991      True                   NaN
# 178031      True                   NaN
#
#                                                  html_url          language  \
# 56                https://github.com/bjwa2020/coronavirus               NaN
# 70             https://github.com/weimeilin79/coronavirus        JavaScript
# 86      https://github.com/839-Studio/Noval-Coronaviru...               NaN
# 148     https://github.com/C0D4-101/coronavirus-2019-nCov              HTML
# 158               https://github.com/SoonGwan/Here-Corona        JavaScript
# ...                                                   ...               ...
# 177930  https://github.com/ni3mumbaikar/Novel-Corona-I...               EJS
# 177956  https://github.com/KhanOmair/Covid-19-info-Cou...              Dart
# 177958    https://github.com/E-B-Manohar/Project-COVgh-V1  Jupyter Notebook
# 177991       https://github.com/leoalcantara/covid-19-app        JavaScript
# 178031  https://github.com/vinnik-dmitry07/REIDCoronaH...  Jupyter Notebook
#
#                   created_at             pushed_at            updated_at  \
# 56      2020-02-04T04:15:07Z  2020-02-29T07:49:55Z  2021-07-30T00:11:10Z
# 70      2020-02-07T15:59:25Z  2020-09-11T19:15:11Z  2020-09-16T08:36:30Z
# 86      2020-02-06T08:40:28Z  2020-02-06T08:54:43Z  2020-09-16T07:28:46Z
# 148     2020-02-09T03:21:05Z  2020-02-28T09:05:32Z  2020-07-18T18:33:17Z
# 158     2020-02-24T15:59:21Z  2021-01-05T21:46:26Z  2021-04-26T22:44:09Z
# ...                      ...                   ...                   ...
# 177930  2020-04-27T10:49:10Z  2021-08-04T06:09:17Z  2021-08-04T06:09:19Z
# 177956  2020-05-03T12:33:01Z  2020-05-03T13:56:42Z  2020-05-03T13:56:45Z
# 177958  2020-05-04T11:58:58Z  2020-09-09T09:46:17Z  2021-08-11T05:55:33Z
# 177991  2020-05-14T21:22:38Z  2021-01-06T03:02:59Z  2020-06-19T02:15:26Z
# 178031  2020-05-25T14:35:11Z  2020-12-05T13:41:19Z  2021-03-23T10:23:31Z
#
#                                                   svn_url      owner.login
# 56                https://github.com/bjwa2020/coronavirus         bjwa2020
# 70             https://github.com/weimeilin79/coronavirus      weimeilin79
# 86      https://github.com/839-Studio/Noval-Coronaviru...       839-Studio
# 148     https://github.com/C0D4-101/coronavirus-2019-nCov         C0D4-101
# 158               https://github.com/SoonGwan/Here-Corona         SoonGwan
# ...                                                   ...              ...
# 177930  https://github.com/ni3mumbaikar/Novel-Corona-I...     ni3mumbaikar
# 177956  https://github.com/KhanOmair/Covid-19-info-Cou...        KhanOmair
# 177958    https://github.com/E-B-Manohar/Project-COVgh-V1      E-B-Manohar
# 177991       https://github.com/leoalcantara/covid-19-app     leoalcantara
# 178031  https://github.com/vinnik-dmitry07/REIDCoronaH...  vinnik-dmitry07
#
# [14714 rows x 23 columns]

# %% [markdown]
# **14.714** repositorios.

# %% [markdown]
# ### No en el nombre pero sí en la descripción:

# %%
df_not_in_name_but_in_description = df.full_name.str.contains(pattern_name) == False
df_not_in_name_but_in_description
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 178065     True
# 178066    False
# 178067     True
# 178068     True
# 178069     True
# Name: full_name, Length: 178070, dtype: bool

# %%
df_not_in_name_but_in_description = df[df_not_in_name_but_in_description]
df_not_in_name_but_in_description
# Out:
#                id                              name  \
# 40      237221585                        gatsby-map
# 41      236218942                              cido
# 64      237385601  Getting-Things-Done-with-Pytorch
# 67      236146885                         pneumonia
# 72      229427465                Hentai-discord-bot
# ...           ...                               ...
# 178063  269479371                           jupyter
# 178065  269527538   OpenWeatherMap-concat-histories
# 178067  269906994               face-mask-detection
# 178068  270013759                          frontend
# 178069  270006438                           backend
#
#                                           full_name  \
# 40                              elinlutz/gatsby-map
# 41                               CIDO-ontology/cido
# 64      curiousily/Getting-Things-Done-with-Pytorch
# 67                                lispczz/pneumonia
# 72                     Eddy-Arch/Hentai-discord-bot
# ...                                             ...
# 178063                                kclhi/jupyter
# 178065       ALT-F1/OpenWeatherMap-concat-histories
# 178067           jahnavi-prasad/face-mask-detection
# 178068                             Tackode/frontend
# 178069                              Tackode/backend
#
#                                               description  \
# 40      Mapping the coronavirus in react, gatsby.js an...
# 41          CIDO: Coronavirus Infectious Disease Ontology
# 64      Jupyter Notebook tutorials on solving real-wor...
# 67                                       中国新型冠状病毒肺炎地级市疫情图
# 72      A NSFW hentai discord bot with extra functiona...
# ...                                                   ...
# 178063           :whale2: JupyterHub Docker configuration
# 178065  Concatenate histories weather data collected b...
# 178067  Simple project to detect if a person is wearin...
# 178068                               Frontend for Tackode
# 178069                                Backend for Tackode
#
#                                          contributors_url  archived  disabled  \
# 40      https://api.github.com/repos/elinlutz/gatsby-m...     False     False
# 41      https://api.github.com/repos/CIDO-ontology/cid...     False     False
# 64      https://api.github.com/repos/curiousily/Gettin...     False     False
# 67      https://api.github.com/repos/lispczz/pneumonia...     False     False
# 72      https://api.github.com/repos/Eddy-Arch/Hentai-...     False     False
# ...                                                   ...       ...       ...
# 178063  https://api.github.com/repos/kclhi/jupyter/con...     False     False
# 178065  https://api.github.com/repos/ALT-F1/OpenWeathe...     False     False
# 178067  https://api.github.com/repos/jahnavi-prasad/fa...     False     False
# 178068  https://api.github.com/repos/Tackode/frontend/...     False     False
# 178069  https://api.github.com/repos/Tackode/backend/c...     False     False
#
#         stargazers_count  watchers_count  forks_count  ...  has_projects  \
# 40                    31              31           12  ...          True
# 41                    13              13            9  ...          True
# 64                   957             957          300  ...          True
# 67                   356             356          100  ...          True
# 72                    21              21           12  ...          True
# ...                  ...             ...          ...  ...           ...
# 178063                 2               2            0  ...          True
# 178065                 1               1            0  ...          True
# 178067                 6               6            7  ...          True
# 178068                 0               0            0  ...          True
# 178069                 0               0            0  ...          True
#
#         has_wiki                              homepage  \
# 40          True               https://coronakartan.se
# 41          True                                   NaN
# 64          True           https://www.curiousily.com/
# 67          True  https://lispczz.github.io/pneumonia/
# 72          True                                   NaN
# ...          ...                                   ...
# 178063      True                     https://kclhi.org
# 178065      True                  http://www.alt-f1.be
# 178067      True                                   NaN
# 178068      True                   https://tackode.com
# 178069      True                   https://tackode.com
#
#                                                  html_url          language  \
# 40                 https://github.com/elinlutz/gatsby-map        JavaScript
# 41                  https://github.com/CIDO-ontology/cido               NaN
# 64      https://github.com/curiousily/Getting-Things-D...  Jupyter Notebook
# 67                   https://github.com/lispczz/pneumonia        JavaScript
# 72        https://github.com/Eddy-Arch/Hentai-discord-bot            Python
# ...                                                   ...               ...
# 178063                   https://github.com/kclhi/jupyter            Python
# 178065  https://github.com/ALT-F1/OpenWeatherMap-conca...            Python
# 178067  https://github.com/jahnavi-prasad/face-mask-de...            Python
# 178068                https://github.com/Tackode/frontend               Vue
# 178069                 https://github.com/Tackode/backend              Rust
#
#                   created_at             pushed_at            updated_at  \
# 40      2020-01-30T13:43:13Z  2021-05-06T16:13:49Z  2020-07-01T14:29:51Z
# 41      2020-01-25T19:30:01Z  2021-08-12T05:47:50Z  2021-08-12T05:47:53Z
# 64      2020-01-31T08:02:53Z  2021-06-14T09:47:01Z  2021-08-14T11:16:33Z
# 67      2020-01-25T08:56:59Z  2021-08-12T22:57:00Z  2021-07-30T00:06:31Z
# 72      2019-12-21T12:55:55Z  2021-07-18T09:53:05Z  2021-07-29T10:33:41Z
# ...                      ...                   ...                   ...
# 178063  2020-06-04T22:35:16Z  2021-06-11T18:23:39Z  2021-08-14T14:32:53Z
# 178065  2020-06-05T04:04:46Z  2021-08-12T13:30:11Z  2020-06-08T12:44:27Z
# 178067  2020-06-06T07:39:31Z  2020-06-06T07:46:00Z  2021-05-03T13:00:00Z
# 178068  2020-06-06T14:57:50Z  2021-08-12T04:05:02Z  2021-01-11T08:38:35Z
# 178069  2020-06-06T14:30:13Z  2021-08-13T04:03:31Z  2021-05-26T08:44:01Z
#
#                                                   svn_url     owner.login
# 40                 https://github.com/elinlutz/gatsby-map        elinlutz
# 41                  https://github.com/CIDO-ontology/cido   CIDO-ontology
# 64      https://github.com/curiousily/Getting-Things-D...      curiousily
# 67                   https://github.com/lispczz/pneumonia         lispczz
# 72        https://github.com/Eddy-Arch/Hentai-discord-bot       Eddy-Arch
# ...                                                   ...             ...
# 178063                   https://github.com/kclhi/jupyter           kclhi
# 178065  https://github.com/ALT-F1/OpenWeatherMap-conca...          ALT-F1
# 178067  https://github.com/jahnavi-prasad/face-mask-de...  jahnavi-prasad
# 178068                https://github.com/Tackode/frontend         Tackode
# 178069                 https://github.com/Tackode/backend         Tackode
#
# [18913 rows x 23 columns]

# %%
df_not_in_name_but_in_description_boolean = df.description.str.contains(pattern_description)
df_not_in_name_but_in_description_boolean
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 178065    False
# 178066     True
# 178067     True
# 178068    False
# 178069    False
# Name: description, Length: 178070, dtype: object

# %%
df_not_in_name_but_in_description_boolean = df_not_in_name_but_in_description_boolean.fillna(False)

# %%
df_not_in_name_but_in_description = df_not_in_name_but_in_description[df_not_in_name_but_in_description_boolean]
df_not_in_name_but_in_description
# Out:
# <ipython-input-24-fa5b93223eed>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_not_in_name_but_in_description = df_not_in_name_but_in_description[df_not_in_name_but_in_description_boolean]
#                id                              name  \
# 40      237221585                        gatsby-map
# 41      236218942                              cido
# 64      237385601  Getting-Things-Done-with-Pytorch
# 67      236146885                         pneumonia
# 72      229427465                Hentai-discord-bot
# ...           ...                               ...
# 178037  267352452                    steam-lockdown
# 178047  267575087                Smart-Food-Storage
# 178050  246130172                         Airplanes
# 178051  267858096      face_mask_detection_openvino
# 178067  269906994               face-mask-detection
#
#                                           full_name  \
# 40                              elinlutz/gatsby-map
# 41                               CIDO-ontology/cido
# 64      curiousily/Getting-Things-Done-with-Pytorch
# 67                                lispczz/pneumonia
# 72                     Eddy-Arch/Hentai-discord-bot
# ...                                             ...
# 178037             digital-wellbeing/steam-lockdown
# 178047                m-boutaleb/Smart-Food-Storage
# 178050                          cgettings/Airplanes
# 178051         mmphego/face_mask_detection_openvino
# 178067           jahnavi-prasad/face-mask-detection
#
#                                               description  \
# 40      Mapping the coronavirus in react, gatsby.js an...
# 41          CIDO: Coronavirus Infectious Disease Ontology
# 64      Jupyter Notebook tutorials on solving real-wor...
# 67                                       中国新型冠状病毒肺炎地级市疫情图
# 72      A NSFW hentai discord bot with extra functiona...
# ...                                                   ...
# 178037  How has gaming changed during lockdown? Analys...
# 178047  An intelligent application (very useful during...
# 178050  Visualizing flights into LGA at the start of t...
# 178051  Detect faces and determine whether people are ...
# 178067  Simple project to detect if a person is wearin...
#
#                                          contributors_url  archived  disabled  \
# 40      https://api.github.com/repos/elinlutz/gatsby-m...     False     False
# 41      https://api.github.com/repos/CIDO-ontology/cid...     False     False
# 64      https://api.github.com/repos/curiousily/Gettin...     False     False
# 67      https://api.github.com/repos/lispczz/pneumonia...     False     False
# 72      https://api.github.com/repos/Eddy-Arch/Hentai-...     False     False
# ...                                                   ...       ...       ...
# 178037  https://api.github.com/repos/digital-wellbeing...     False     False
# 178047  https://api.github.com/repos/m-boutaleb/Smart-...     False     False
# 178050  https://api.github.com/repos/cgettings/Airplan...     False     False
# 178051  https://api.github.com/repos/mmphego/face_mask...     False     False
# 178067  https://api.github.com/repos/jahnavi-prasad/fa...     False     False
#
#         stargazers_count  watchers_count  forks_count  ...  has_projects  \
# 40                    31              31           12  ...          True
# 41                    13              13            9  ...          True
# 64                   957             957          300  ...          True
# 67                   356             356          100  ...          True
# 72                    21              21           12  ...          True
# ...                  ...             ...          ...  ...           ...
# 178037                 0               0            0  ...          True
# 178047                 0               0            0  ...          True
# 178050                 0               0            0  ...          True
# 178051                35              35           11  ...          True
# 178067                 6               6            7  ...          True
#
#         has_wiki                                           homepage  \
# 40          True                            https://coronakartan.se
# 41          True                                                NaN
# 64          True                        https://www.curiousily.com/
# 67          True               https://lispczz.github.io/pneumonia/
# 72          True                                                NaN
# ...          ...                                                ...
# 178037      True  https://digital-wellbeing.github.io/steam-lock...
# 178047      True                                                NaN
# 178050     False                                                NaN
# 178051      True  https://blog.mphomphego.co.za/blog/2020/06/02/...
# 178067      True                                                NaN
#
#                                                  html_url          language  \
# 40                 https://github.com/elinlutz/gatsby-map        JavaScript
# 41                  https://github.com/CIDO-ontology/cido               NaN
# 64      https://github.com/curiousily/Getting-Things-D...  Jupyter Notebook
# 67                   https://github.com/lispczz/pneumonia        JavaScript
# 72        https://github.com/Eddy-Arch/Hentai-discord-bot            Python
# ...                                                   ...               ...
# 178037  https://github.com/digital-wellbeing/steam-loc...              HTML
# 178047   https://github.com/m-boutaleb/Smart-Food-Storage              Java
# 178050             https://github.com/cgettings/Airplanes              HTML
# 178051  https://github.com/mmphego/face_mask_detection...            Python
# 178067  https://github.com/jahnavi-prasad/face-mask-de...            Python
#
#                   created_at             pushed_at            updated_at  \
# 40      2020-01-30T13:43:13Z  2021-05-06T16:13:49Z  2020-07-01T14:29:51Z
# 41      2020-01-25T19:30:01Z  2021-08-12T05:47:50Z  2021-08-12T05:47:53Z
# 64      2020-01-31T08:02:53Z  2021-06-14T09:47:01Z  2021-08-14T11:16:33Z
# 67      2020-01-25T08:56:59Z  2021-08-12T22:57:00Z  2021-07-30T00:06:31Z
# 72      2019-12-21T12:55:55Z  2021-07-18T09:53:05Z  2021-07-29T10:33:41Z
# ...                      ...                   ...                   ...
# 178037  2020-05-27T15:10:55Z  2021-02-10T14:26:15Z  2021-02-16T13:48:34Z
# 178047  2020-05-28T11:45:23Z  2020-10-04T15:25:00Z  2021-03-23T08:43:26Z
# 178050  2020-03-09T20:01:16Z  2020-08-10T19:11:27Z  2020-08-10T19:11:31Z
# 178051  2020-05-29T12:56:47Z  2021-02-16T12:18:40Z  2021-05-25T21:53:17Z
# 178067  2020-06-06T07:39:31Z  2020-06-06T07:46:00Z  2021-05-03T13:00:00Z
#
#                                                   svn_url        owner.login
# 40                 https://github.com/elinlutz/gatsby-map           elinlutz
# 41                  https://github.com/CIDO-ontology/cido      CIDO-ontology
# 64      https://github.com/curiousily/Getting-Things-D...         curiousily
# 67                   https://github.com/lispczz/pneumonia            lispczz
# 72        https://github.com/Eddy-Arch/Hentai-discord-bot          Eddy-Arch
# ...                                                   ...                ...
# 178037  https://github.com/digital-wellbeing/steam-loc...  digital-wellbeing
# 178047   https://github.com/m-boutaleb/Smart-Food-Storage         m-boutaleb
# 178050             https://github.com/cgettings/Airplanes          cgettings
# 178051  https://github.com/mmphego/face_mask_detection...            mmphego
# 178067  https://github.com/jahnavi-prasad/face-mask-de...     jahnavi-prasad
#
# [17566 rows x 23 columns]

# %% [markdown]
# **17.566** repositorios.

# %% [markdown]
# ### En el nombre y en la descripción:

# %%
df_in_name_and_description_boolean = df.full_name.str.contains(pattern_name) & df.description.str.contains(pattern_description)
df_in_name_and_description_boolean
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 178065    False
# 178066     True
# 178067    False
# 178068    False
# 178069    False
# Length: 178070, dtype: bool

# %%
df_in_name_and_description = df[df_in_name_and_description_boolean]
df_in_name_and_description
# Out:
#                id                                               name  \
# 0       238316428                                           COVID-19
# 1       235374822                                           COVID-19
# 2       239777191                                        coronavirus
# 3       237129709                                        coronavirus
# 4       234936988                                               ncov
# ...           ...                                                ...
# 178042  267669502                                            pydemic
# 178046  267472666  simulation-model-of-interventions-to-interrupt...
# 178054  268148998                                Epidemics-Modelling
# 178064  269601203                                    CoronaDashboard
# 178066  270034436                                      mzansi_corona
#
#                                                 full_name  \
# 0                                 CSSEGISandData/COVID-19
# 1                                  midas-network/COVID-19
# 2                                 RamiKrispin/coronavirus
# 3                               FoldingAtHome/coronavirus
# 4                                         nextstrain/ncov
# ...                                                   ...
# 178042                      uiuc-covid19-modeling/pydemic
# 178046  nicolaspenagos/simulation-model-of-interventio...
# 178054                    pierpaolo28/Epidemics-Modelling
# 178064                              StefH/CoronaDashboard
# 178066                        marvinIsSacul/mzansi_corona
#
#                                               description  \
# 0       Novel Coronavirus (COVID-19) Cases, provided b...
# 1                       2019 novel coronavirus repository
# 2                                 The coronavirus dataset
# 3                           Folding@home COVID-19 efforts
# 4       Nextstrain build for novel coronavirus SARS-CoV-2
# ...                                                   ...
# 178042  a python driver for epidemic modeling and infe...
# 178046  I present software to simulate how biosecurity...
# 178054  Modelling and tracking of epidemics data analy...
# 178064  Een Corona Dashboard gebaseerd op cijfers van ...
# 178066  Flutter app about South Africa's Corona Virus ...
#
#                                          contributors_url  archived  disabled  \
# 0       https://api.github.com/repos/CSSEGISandData/CO...     False     False
# 1       https://api.github.com/repos/midas-network/COV...     False     False
# 2       https://api.github.com/repos/RamiKrispin/coron...     False     False
# 3       https://api.github.com/repos/FoldingAtHome/cor...     False     False
# 4       https://api.github.com/repos/nextstrain/ncov/c...     False     False
# ...                                                   ...       ...       ...
# 178042  https://api.github.com/repos/uiuc-covid19-mode...     False     False
# 178046  https://api.github.com/repos/nicolaspenagos/si...     False     False
# 178054  https://api.github.com/repos/pierpaolo28/Epide...     False     False
# 178064  https://api.github.com/repos/StefH/CoronaDashb...     False     False
# 178066  https://api.github.com/repos/marvinIsSacul/mza...     False     False
#
#         stargazers_count  watchers_count  forks_count  ...  has_projects  \
# 0                  27211           27211        17432  ...          True
# 1                    642             642          221  ...          True
# 2                    394             394          175  ...          True
# 3                   1115            1115           87  ...          True
# 4                   1208            1208          343  ...          True
# ...                  ...             ...          ...  ...           ...
# 178042                 5               5            4  ...          True
# 178046                 0               0            0  ...          True
# 178054                 1               1            0  ...          True
# 178064                 1               1            0  ...          True
# 178066                 0               0            0  ...          True
#
#         has_wiki                                           homepage  \
# 0           True  https://systems.jhu.edu/research/public-health...
# 1           True                                                NaN
# 2           True         https://ramikrispin.github.io/coronavirus/
# 3           True                          https://foldingathome.org
# 4           True                        https://nextstrain.org/ncov
# ...          ...                                                ...
# 178042      True                                                NaN
# 178046      True                                                NaN
# 178054      True                           http://3.22.240.181:8501
# 178064      True                                                NaN
# 178066      True                                                NaN
#
#                                                  html_url          language  \
# 0              https://github.com/CSSEGISandData/COVID-19               NaN
# 1               https://github.com/midas-network/COVID-19               TeX
# 2              https://github.com/RamiKrispin/coronavirus                 R
# 3            https://github.com/FoldingAtHome/coronavirus            Python
# 4                      https://github.com/nextstrain/ncov            Python
# ...                                                   ...               ...
# 178042   https://github.com/uiuc-covid19-modeling/pydemic            Python
# 178046  https://github.com/nicolaspenagos/simulation-m...              Java
# 178054  https://github.com/pierpaolo28/Epidemics-Model...  Jupyter Notebook
# 178064           https://github.com/StefH/CoronaDashboard                C#
# 178066     https://github.com/marvinIsSacul/mzansi_corona              Dart
#
#                   created_at             pushed_at            updated_at  \
# 0       2020-02-04T22:03:53Z  2021-08-14T11:35:08Z  2021-08-14T11:56:01Z
# 1       2020-01-21T15:27:23Z  2021-08-12T20:15:14Z  2021-08-12T20:15:21Z
# 2       2020-02-11T14:08:06Z  2021-08-14T08:19:49Z  2021-08-14T08:19:52Z
# 3       2020-01-30T03:12:19Z  2020-10-27T03:29:18Z  2021-08-09T21:17:36Z
# 4       2020-01-19T17:23:17Z  2021-08-13T12:36:06Z  2021-08-13T12:36:10Z
# ...                      ...                   ...                   ...
# 178042  2020-05-28T18:45:50Z  2021-01-19T16:34:17Z  2021-07-22T14:31:13Z
# 178046  2020-05-28T02:18:43Z  2020-07-13T04:28:52Z  2020-08-15T08:18:43Z
# 178054  2020-05-30T19:48:56Z  2020-11-17T19:44:00Z  2021-01-30T21:40:09Z
# 178064  2020-06-05T10:29:30Z  2021-07-19T15:54:46Z  2021-07-19T15:52:49Z
# 178066  2020-06-06T16:15:43Z  2020-07-22T12:22:12Z  2021-03-08T18:24:34Z
#
#                                                   svn_url  \
# 0              https://github.com/CSSEGISandData/COVID-19
# 1               https://github.com/midas-network/COVID-19
# 2              https://github.com/RamiKrispin/coronavirus
# 3            https://github.com/FoldingAtHome/coronavirus
# 4                      https://github.com/nextstrain/ncov
# ...                                                   ...
# 178042   https://github.com/uiuc-covid19-modeling/pydemic
# 178046  https://github.com/nicolaspenagos/simulation-m...
# 178054  https://github.com/pierpaolo28/Epidemics-Model...
# 178064           https://github.com/StefH/CoronaDashboard
# 178066     https://github.com/marvinIsSacul/mzansi_corona
#
#                   owner.login
# 0              CSSEGISandData
# 1               midas-network
# 2                 RamiKrispin
# 3               FoldingAtHome
# 4                  nextstrain
# ...                       ...
# 178042  uiuc-covid19-modeling
# 178046         nicolaspenagos
# 178054            pierpaolo28
# 178064                  StefH
# 178066          marvinIsSacul
#
# [66534 rows x 23 columns]

# %%
df_in_name_and_description.shape[0]
# Out:
# 66534

# %% [markdown]
# **66.534** repositorios.

# %% [markdown]
# ------

# %% [markdown]
# ### Comprobación del 62,7% de repositorios descartados si nos quedásemos con la última opción

# %%
df = pd.read_csv('df_repositorios.csv')
df_sin = df[~df_in_name_and_description_boolean]
df_sin
# Out:
#                id                             name  \
# 20      241636482                      coronavirus
# 40      237221585                       gatsby-map
# 41      236218942                             cido
# 48      237517471     Coronavirus-Chrome-Extension
# 50      236273771                  corona-frontend
# ...           ...                              ...
# 178063  269479371                          jupyter
# 178065  269527538  OpenWeatherMap-concat-histories
# 178067  269906994              face-mask-detection
# 178068  270013759                         frontend
# 178069  270006438                          backend
#
#                                             full_name  \
# 20                         YaseenAbdullah/coronavirus
# 40                                elinlutz/gatsby-map
# 41                                 CIDO-ontology/cido
# 48      WebDevSimplified/Coronavirus-Chrome-Extension
# 50                          theleadio/corona-frontend
# ...                                               ...
# 178063                                  kclhi/jupyter
# 178065         ALT-F1/OpenWeatherMap-concat-histories
# 178067             jahnavi-prasad/face-mask-detection
# 178068                               Tackode/frontend
# 178069                                Tackode/backend
#
#                                               description  \
# 20                                                    NaN
# 40      Mapping the coronavirus in react, gatsby.js an...
# 41          CIDO: Coronavirus Infectious Disease Ontology
# 48                                                    NaN
# 50                                                    NaN
# ...                                                   ...
# 178063           :whale2: JupyterHub Docker configuration
# 178065  Concatenate histories weather data collected b...
# 178067  Simple project to detect if a person is wearin...
# 178068                               Frontend for Tackode
# 178069                                Backend for Tackode
#
#                                          contributors_url  archived  disabled  \
# 20      https://api.github.com/repos/YaseenAbdullah/co...     False     False
# 40      https://api.github.com/repos/elinlutz/gatsby-m...     False     False
# 41      https://api.github.com/repos/CIDO-ontology/cid...     False     False
# 48      https://api.github.com/repos/WebDevSimplified/...     False     False
# 50      https://api.github.com/repos/theleadio/corona-...     False     False
# ...                                                   ...       ...       ...
# 178063  https://api.github.com/repos/kclhi/jupyter/con...     False     False
# 178065  https://api.github.com/repos/ALT-F1/OpenWeathe...     False     False
# 178067  https://api.github.com/repos/jahnavi-prasad/fa...     False     False
# 178068  https://api.github.com/repos/Tackode/frontend/...     False     False
# 178069  https://api.github.com/repos/Tackode/backend/c...     False     False
#
#         stargazers_count  watchers_count  forks_count  ...  has_projects  \
# 20                    34              34           13  ...          True
# 40                    31              31           12  ...          True
# 41                    13              13            9  ...          True
# 48                    24              24           10  ...          True
# 50                    45              45           33  ...          True
# ...                  ...             ...          ...  ...           ...
# 178063                 2               2            0  ...          True
# 178065                 1               1            0  ...          True
# 178067                 6               6            7  ...          True
# 178068                 0               0            0  ...          True
# 178069                 0               0            0  ...          True
#
#         has_wiki                        homepage  \
# 20          True                             NaN
# 40          True         https://coronakartan.se
# 41          True                             NaN
# 48          True                             NaN
# 50          True  https://www.coronatracker.com/
# ...          ...                             ...
# 178063      True               https://kclhi.org
# 178065      True            http://www.alt-f1.be
# 178067      True                             NaN
# 178068      True             https://tackode.com
# 178069      True             https://tackode.com
#
#                                                  html_url    language  \
# 20          https://github.com/YaseenAbdullah/coronavirus        Dart
# 40                 https://github.com/elinlutz/gatsby-map  JavaScript
# 41                  https://github.com/CIDO-ontology/cido         NaN
# 48      https://github.com/WebDevSimplified/Coronaviru...  JavaScript
# 50           https://github.com/theleadio/corona-frontend  JavaScript
# ...                                                   ...         ...
# 178063                   https://github.com/kclhi/jupyter      Python
# 178065  https://github.com/ALT-F1/OpenWeatherMap-conca...      Python
# 178067  https://github.com/jahnavi-prasad/face-mask-de...      Python
# 178068                https://github.com/Tackode/frontend         Vue
# 178069                 https://github.com/Tackode/backend        Rust
#
#                   created_at             pushed_at            updated_at  \
# 20      2020-02-19T14:03:45Z  2020-05-10T14:58:36Z  2021-03-27T16:11:56Z
# 40      2020-01-30T13:43:13Z  2021-05-06T16:13:49Z  2020-07-01T14:29:51Z
# 41      2020-01-25T19:30:01Z  2021-08-12T05:47:50Z  2021-08-12T05:47:53Z
# 48      2020-01-31T21:15:58Z  2020-01-31T21:18:07Z  2021-07-25T14:47:10Z
# 50      2020-01-26T06:01:59Z  2021-08-11T22:39:03Z  2021-05-04T15:05:19Z
# ...                      ...                   ...                   ...
# 178063  2020-06-04T22:35:16Z  2021-06-11T18:23:39Z  2021-08-14T14:32:53Z
# 178065  2020-06-05T04:04:46Z  2021-08-12T13:30:11Z  2020-06-08T12:44:27Z
# 178067  2020-06-06T07:39:31Z  2020-06-06T07:46:00Z  2021-05-03T13:00:00Z
# 178068  2020-06-06T14:57:50Z  2021-08-12T04:05:02Z  2021-01-11T08:38:35Z
# 178069  2020-06-06T14:30:13Z  2021-08-13T04:03:31Z  2021-05-26T08:44:01Z
#
#                                                   svn_url       owner.login
# 20          https://github.com/YaseenAbdullah/coronavirus    YaseenAbdullah
# 40                 https://github.com/elinlutz/gatsby-map          elinlutz
# 41                  https://github.com/CIDO-ontology/cido     CIDO-ontology
# 48      https://github.com/WebDevSimplified/Coronaviru...  WebDevSimplified
# 50           https://github.com/theleadio/corona-frontend         theleadio
# ...                                                   ...               ...
# 178063                   https://github.com/kclhi/jupyter             kclhi
# 178065  https://github.com/ALT-F1/OpenWeatherMap-conca...            ALT-F1
# 178067  https://github.com/jahnavi-prasad/face-mask-de...    jahnavi-prasad
# 178068                https://github.com/Tackode/frontend           Tackode
# 178069                 https://github.com/Tackode/backend           Tackode
#
# [111536 rows x 23 columns]

# %%
df_sin.sort_values(by=['stargazers_count'])
# Out:
#                id                           name  \
# 93690   253104417                covid19-chatbot
# 117101  361328496          Taller-Covid-Colombia
# 117100  361553148     vue-tailwind-covid-tracker
# 117099  361405214            flutter_covid_today
# 117098  361355998       COVID-19-Cough-Detection
# ...           ...                            ...
# 96169   253216457            springer_free_books
# 13534   260712390                     cwa-server
# 2993    247821387                            app
# 154209  260064828  exposure-notifications-server
# 50852   245077032                            API
#
#                                         full_name  \
# 93690                     dbacall/covid19-chatbot
# 117101               levf18/Taller-Covid-Colombia
# 117100  Brian-Santeliz/vue-tailwind-covid-tracker
# 117099            sing3demons/flutter_covid_today
# 117098    HrithikNambiar/COVID-19-Cough-Detection
# ...                                           ...
# 96169                alexgand/springer_free_books
# 13534                  corona-warn-app/cwa-server
# 2993                  WorldHealthOrganization/app
# 154209       google/exposure-notifications-server
# 50852                              disease-sh/API
#
#                                               description  \
# 93690                                                 NaN
# 117101                                                NaN
# 117100                                                NaN
# 117099                                                NaN
# 117098  An attempt at INTERSPEECH 2021 Computational P...
# ...                                                   ...
# 96169   Python script to download all Springer books r...
# 13534   Backend implementation for the Apple/Google ex...
# 2993                                         COVID-19 App
# 154209  Exposure Notification Reference Server | Covid...
# 50852   API for Current cases and more stuff about COV...
#
#                                          contributors_url  archived  disabled  \
# 93690   https://api.github.com/repos/dbacall/covid19-c...     False     False
# 117101  https://api.github.com/repos/levf18/Taller-Cov...     False     False
# 117100  https://api.github.com/repos/Brian-Santeliz/vu...     False     False
# 117099  https://api.github.com/repos/sing3demons/flutt...     False     False
# 117098  https://api.github.com/repos/HrithikNambiar/CO...     False     False
# ...                                                   ...       ...       ...
# 96169   https://api.github.com/repos/alexgand/springer...     False     False
# 13534   https://api.github.com/repos/corona-warn-app/c...     False     False
# 2993    https://api.github.com/repos/WorldHealthOrgani...     False     False
# 154209  https://api.github.com/repos/google/exposure-n...     False     False
# 50852   https://api.github.com/repos/disease-sh/API/co...     False     False
#
#         stargazers_count  watchers_count  forks_count  ...  has_projects  \
# 93690                  0               0            0  ...          True
# 117101                 0               0            0  ...          True
# 117100                 0               0            0  ...          True
# 117099                 0               0            0  ...          True
# 117098                 0               0            0  ...          True
# ...                  ...             ...          ...  ...           ...
# 96169               1633            1633          370  ...          True
# 13534               1752            1752          336  ...         False
# 2993                2060            2060          528  ...          True
# 154209              2076            2076          289  ...         False
# 50852               2289            2289          625  ...          True
#
#         has_wiki                                           homepage  \
# 93690       True                                                NaN
# 117101      True                                                NaN
# 117100      True                                                NaN
# 117099      True                                                NaN
# 117098      True                                                NaN
# ...          ...                                                ...
# 96169       True                                                NaN
# 13534      False                        https://www.coronawarn.app/
# 2993        True                                                NaN
# 154209     False  https://www.google.com/covid19/exposurenotific...
# 50852       True                                https://disease.sh/
#
#                                                  html_url          language  \
# 93690          https://github.com/dbacall/covid19-chatbot        JavaScript
# 117101    https://github.com/levf18/Taller-Covid-Colombia            Python
# 117100  https://github.com/Brian-Santeliz/vue-tailwind...        JavaScript
# 117099  https://github.com/sing3demons/flutter_covid_t...              Dart
# 117098  https://github.com/HrithikNambiar/COVID-19-Cou...  Jupyter Notebook
# ...                                                   ...               ...
# 96169     https://github.com/alexgand/springer_free_books            Python
# 13534       https://github.com/corona-warn-app/cwa-server              Java
# 2993       https://github.com/WorldHealthOrganization/app              Dart
# 154209  https://github.com/google/exposure-notificatio...                Go
# 50852                   https://github.com/disease-sh/API        JavaScript
#
#                   created_at             pushed_at            updated_at  \
# 93690   2020-04-04T21:44:11Z  2021-08-12T06:02:10Z  2020-04-09T10:11:47Z
# 117101  2021-04-25T04:12:53Z  2021-04-25T04:43:04Z  2021-04-25T04:43:06Z
# 117100  2021-04-25T22:31:27Z  2021-04-26T02:29:38Z  2021-04-26T02:29:40Z
# 117099  2021-04-25T11:06:34Z  2021-04-25T11:08:39Z  2021-04-25T11:08:41Z
# 117098  2021-04-25T07:05:25Z  2021-06-04T08:18:32Z  2021-07-07T13:39:53Z
# ...                      ...                   ...                   ...
# 96169   2020-04-05T11:14:34Z  2021-06-02T01:22:57Z  2021-08-09T05:40:25Z
# 13534   2020-05-02T15:07:31Z  2021-08-13T11:24:57Z  2021-08-12T15:49:00Z
# 2993    2020-03-16T21:38:17Z  2021-08-13T06:01:40Z  2021-08-11T02:43:08Z
# 154209  2020-04-29T23:03:36Z  2021-08-12T17:01:13Z  2021-08-12T17:01:16Z
# 50852   2020-03-05T05:28:12Z  2021-07-30T14:49:36Z  2021-08-12T21:21:29Z
#
#                                                   svn_url  \
# 93690          https://github.com/dbacall/covid19-chatbot
# 117101    https://github.com/levf18/Taller-Covid-Colombia
# 117100  https://github.com/Brian-Santeliz/vue-tailwind...
# 117099  https://github.com/sing3demons/flutter_covid_t...
# 117098  https://github.com/HrithikNambiar/COVID-19-Cou...
# ...                                                   ...
# 96169     https://github.com/alexgand/springer_free_books
# 13534       https://github.com/corona-warn-app/cwa-server
# 2993       https://github.com/WorldHealthOrganization/app
# 154209  https://github.com/google/exposure-notificatio...
# 50852                   https://github.com/disease-sh/API
#
#                     owner.login
# 93690                   dbacall
# 117101                   levf18
# 117100           Brian-Santeliz
# 117099              sing3demons
# 117098           HrithikNambiar
# ...                         ...
# 96169                  alexgand
# 13534           corona-warn-app
# 2993    WorldHealthOrganization
# 154209                   google
# 50852                disease-sh
#
# [111536 rows x 23 columns]

# %%
df_sin_sorted = df_sin.sort_values(by=['stargazers_count'], ascending=False).head(20)
df_sin_sorted[['id', 'name', 'full_name', 'description', 'stargazers_count', 'html_url']]
# Out:
#                id                                               name  \
# 50852   245077032                                                API
# 154209  260064828                      exposure-notifications-server
# 2993    247821387                                                app
# 13534   260712390                                         cwa-server
# 96169   253216457                                springer_free_books
# 105038  254129456  Free_CyberSecurity_Professional_Development_Re...
# 176821   21244714                                        tika-python
# 7113    250585282      Amazon-Fresh-Whole-Foods-delivery-slot-finder
# 64      237385601                   Getting-Things-Done-with-Pytorch
# 177900  257567981                                Face-Mask-Detection
# 176819  125756247                                   ESP32-Paxcounter
# 176627  264477930                                 immuni-app-android
# 102026  253851344                                Covid-19-Flutter-UI
# 171365  268543048                                    covid-alert-app
# 6793    250296192                                   coronavirus-data
# 3784    248180072                                             makair
# 143294  383424499             korea-covid-19-remaining-vaccine-macro
# 27786   248910514                                                api
# 176986  281475256                                            paperai
# 118662  362534835                              covid-vaccine-booking
#
#                                                 full_name  \
# 50852                                      disease-sh/API
# 154209               google/exposure-notifications-server
# 2993                          WorldHealthOrganization/app
# 13534                          corona-warn-app/cwa-server
# 96169                        alexgand/springer_free_books
# 105038  gerryguy311/Free_CyberSecurity_Professional_De...
# 176821                          chrismattmann/tika-python
# 7113    ahertel/Amazon-Fresh-Whole-Foods-delivery-slot...
# 64            curiousily/Getting-Things-Done-with-Pytorch
# 177900                  chandrikadeb7/Face-Mask-Detection
# 176819                        cyberman54/ESP32-Paxcounter
# 176627                      immuni-app/immuni-app-android
# 102026                    abuanwar072/Covid-19-Flutter-UI
# 171365                            cds-snc/covid-alert-app
# 6793                           nychealth/coronavirus-data
# 3784                               makers-for-life/makair
# 143294      SJang1/korea-covid-19-remaining-vaccine-macro
# 27786                                    covid19india/api
# 176986                                      neuml/paperai
# 118662                      pallupz/covid-vaccine-booking
#
#                                               description  stargazers_count  \
# 50852   API for Current cases and more stuff about COV...              2289
# 154209  Exposure Notification Reference Server | Covid...              2076
# 2993                                         COVID-19 App              2060
# 13534   Backend implementation for the Apple/Google ex...              1752
# 96169   Python script to download all Springer books r...              1633
# 105038  An awesome list of FREE resources for training...              1075
# 176821  Tika-Python is a Python binding to the Apache ...              1062
# 7113    A Mac tool that finds available delivery slots...              1049
# 64      Jupyter Notebook tutorials on solving real-wor...               957
# 177900  Face Mask Detection system based on computer v...               952
# 176819  Wifi & BLE driven passenger flow metering with...               906
# 176627   Official repository for the Android version o...               878
# 102026                                                NaN               875
# 171365  Exposure notification client application / App...               874
# 6793                                                  NaN               841
# 3784    🫁 The world's first open-source ventilator tes...               726
# 143294                                   잔여백신 조회 및 예약 매크로               676
# 27786                                        Our Database               656
# 176986  AI-powered literature discovery and review eng...               630
# 118662  This very basic script can be used to automate...               623
#
#                                                  html_url
# 50852                   https://github.com/disease-sh/API
# 154209  https://github.com/google/exposure-notificatio...
# 2993       https://github.com/WorldHealthOrganization/app
# 13534       https://github.com/corona-warn-app/cwa-server
# 96169     https://github.com/alexgand/springer_free_books
# 105038  https://github.com/gerryguy311/Free_CyberSecur...
# 176821       https://github.com/chrismattmann/tika-python
# 7113    https://github.com/ahertel/Amazon-Fresh-Whole-...
# 64      https://github.com/curiousily/Getting-Things-D...
# 177900  https://github.com/chandrikadeb7/Face-Mask-Det...
# 176819     https://github.com/cyberman54/ESP32-Paxcounter
# 176627   https://github.com/immuni-app/immuni-app-android
# 102026  https://github.com/abuanwar072/Covid-19-Flutte...
# 171365         https://github.com/cds-snc/covid-alert-app
# 6793        https://github.com/nychealth/coronavirus-data
# 3784            https://github.com/makers-for-life/makair
# 143294  https://github.com/SJang1/korea-covid-19-remai...
# 27786                 https://github.com/covid19india/api
# 176986                   https://github.com/neuml/paperai
# 118662   https://github.com/pallupz/covid-vaccine-booking

# %%
# show(df_sin_sorted[['id', 'name', 'full_name', 'description', 'stargazers_count', 'html_url']])

# %% [markdown]
# ----

# %% [markdown]
# ### 4.2.8.3 Estrategia de filtrado

# %% [markdown]
# Primero comprobamos las palabras claves en el nombre:

# %%
df_in_name
# Out:
#                id                 name                        full_name  \
# 0       238316428             COVID-19          CSSEGISandData/COVID-19
# 1       235374822             COVID-19           midas-network/COVID-19
# 2       239777191          coronavirus          RamiKrispin/coronavirus
# 3       237129709          coronavirus        FoldingAtHome/coronavirus
# 4       234936988                 ncov                  nextstrain/ncov
# ...           ...                  ...                              ...
# 178054  268148998  Epidemics-Modelling  pierpaolo28/Epidemics-Modelling
# 178056  268314248                   UI                    CovidToday/UI
# 178061  268770101             coroname                mariabnd/coroname
# 178064  269601203      CoronaDashboard            StefH/CoronaDashboard
# 178066  270034436        mzansi_corona      marvinIsSacul/mzansi_corona
#
#                                               description  \
# 0       Novel Coronavirus (COVID-19) Cases, provided b...
# 1                       2019 novel coronavirus repository
# 2                                 The coronavirus dataset
# 3                           Folding@home COVID-19 efforts
# 4       Nextstrain build for novel coronavirus SARS-CoV-2
# ...                                                   ...
# 178054  Modelling and tracking of epidemics data analy...
# 178056                                                NaN
# 178061                                                NaN
# 178064  Een Corona Dashboard gebaseerd op cijfers van ...
# 178066  Flutter app about South Africa's Corona Virus ...
#
#                                          contributors_url  archived  disabled  \
# 0       https://api.github.com/repos/CSSEGISandData/CO...     False     False
# 1       https://api.github.com/repos/midas-network/COV...     False     False
# 2       https://api.github.com/repos/RamiKrispin/coron...     False     False
# 3       https://api.github.com/repos/FoldingAtHome/cor...     False     False
# 4       https://api.github.com/repos/nextstrain/ncov/c...     False     False
# ...                                                   ...       ...       ...
# 178054  https://api.github.com/repos/pierpaolo28/Epide...     False     False
# 178056  https://api.github.com/repos/CovidToday/UI/con...     False     False
# 178061  https://api.github.com/repos/mariabnd/coroname...     False     False
# 178064  https://api.github.com/repos/StefH/CoronaDashb...     False     False
# 178066  https://api.github.com/repos/marvinIsSacul/mza...     False     False
#
#         stargazers_count  watchers_count  forks_count  ...  has_projects  \
# 0                  27211           27211        17432  ...          True
# 1                    642             642          221  ...          True
# 2                    394             394          175  ...          True
# 3                   1115            1115           87  ...          True
# 4                   1208            1208          343  ...          True
# ...                  ...             ...          ...  ...           ...
# 178054                 1               1            0  ...          True
# 178056                 0               0            0  ...          True
# 178061                 0               0            0  ...          True
# 178064                 1               1            0  ...          True
# 178066                 0               0            0  ...          True
#
#         has_wiki                                           homepage  \
# 0           True  https://systems.jhu.edu/research/public-health...
# 1           True                                                NaN
# 2           True         https://ramikrispin.github.io/coronavirus/
# 3           True                          https://foldingathome.org
# 4           True                        https://nextstrain.org/ncov
# ...          ...                                                ...
# 178054      True                           http://3.22.240.181:8501
# 178056     False                                                NaN
# 178061      True                                                NaN
# 178064      True                                                NaN
# 178066      True                                                NaN
#
#                                                  html_url          language  \
# 0              https://github.com/CSSEGISandData/COVID-19               NaN
# 1               https://github.com/midas-network/COVID-19               TeX
# 2              https://github.com/RamiKrispin/coronavirus                 R
# 3            https://github.com/FoldingAtHome/coronavirus            Python
# 4                      https://github.com/nextstrain/ncov            Python
# ...                                                   ...               ...
# 178054  https://github.com/pierpaolo28/Epidemics-Model...  Jupyter Notebook
# 178056                   https://github.com/CovidToday/UI        JavaScript
# 178061               https://github.com/mariabnd/coroname               NaN
# 178064           https://github.com/StefH/CoronaDashboard                C#
# 178066     https://github.com/marvinIsSacul/mzansi_corona              Dart
#
#                   created_at             pushed_at            updated_at  \
# 0       2020-02-04T22:03:53Z  2021-08-14T11:35:08Z  2021-08-14T11:56:01Z
# 1       2020-01-21T15:27:23Z  2021-08-12T20:15:14Z  2021-08-12T20:15:21Z
# 2       2020-02-11T14:08:06Z  2021-08-14T08:19:49Z  2021-08-14T08:19:52Z
# 3       2020-01-30T03:12:19Z  2020-10-27T03:29:18Z  2021-08-09T21:17:36Z
# 4       2020-01-19T17:23:17Z  2021-08-13T12:36:06Z  2021-08-13T12:36:10Z
# ...                      ...                   ...                   ...
# 178054  2020-05-30T19:48:56Z  2020-11-17T19:44:00Z  2021-01-30T21:40:09Z
# 178056  2020-05-31T16:02:18Z  2021-08-12T15:32:29Z  2020-09-03T02:43:14Z
# 178061  2020-06-02T10:25:35Z  2021-01-06T12:52:34Z  2021-01-06T12:52:37Z
# 178064  2020-06-05T10:29:30Z  2021-07-19T15:54:46Z  2021-07-19T15:52:49Z
# 178066  2020-06-06T16:15:43Z  2020-07-22T12:22:12Z  2021-03-08T18:24:34Z
#
#                                                   svn_url     owner.login
# 0              https://github.com/CSSEGISandData/COVID-19  CSSEGISandData
# 1               https://github.com/midas-network/COVID-19   midas-network
# 2              https://github.com/RamiKrispin/coronavirus     RamiKrispin
# 3            https://github.com/FoldingAtHome/coronavirus   FoldingAtHome
# 4                      https://github.com/nextstrain/ncov      nextstrain
# ...                                                   ...             ...
# 178054  https://github.com/pierpaolo28/Epidemics-Model...     pierpaolo28
# 178056                   https://github.com/CovidToday/UI      CovidToday
# 178061               https://github.com/mariabnd/coroname        mariabnd
# 178064           https://github.com/StefH/CoronaDashboard           StefH
# 178066     https://github.com/marvinIsSacul/mzansi_corona   marvinIsSacul
#
# [159157 rows x 23 columns]

# %% [markdown]
# Filtramos los que tienen palabras claves en el nombre y nos quedamos con el resto para seguir analizándolo:

# %%
df_res_final = df_in_name #Aquí se irán acumulando los repositorios válidos

# %%
df_not_in_name = df[~df_in_name_boolean]

# %%
df_not_in_name
# Out:
#                id                              name  \
# 40      237221585                        gatsby-map
# 41      236218942                              cido
# 64      237385601  Getting-Things-Done-with-Pytorch
# 67      236146885                         pneumonia
# 72      229427465                Hentai-discord-bot
# ...           ...                               ...
# 178063  269479371                           jupyter
# 178065  269527538   OpenWeatherMap-concat-histories
# 178067  269906994               face-mask-detection
# 178068  270013759                          frontend
# 178069  270006438                           backend
#
#                                           full_name  \
# 40                              elinlutz/gatsby-map
# 41                               CIDO-ontology/cido
# 64      curiousily/Getting-Things-Done-with-Pytorch
# 67                                lispczz/pneumonia
# 72                     Eddy-Arch/Hentai-discord-bot
# ...                                             ...
# 178063                                kclhi/jupyter
# 178065       ALT-F1/OpenWeatherMap-concat-histories
# 178067           jahnavi-prasad/face-mask-detection
# 178068                             Tackode/frontend
# 178069                              Tackode/backend
#
#                                               description  \
# 40      Mapping the coronavirus in react, gatsby.js an...
# 41          CIDO: Coronavirus Infectious Disease Ontology
# 64      Jupyter Notebook tutorials on solving real-wor...
# 67                                       中国新型冠状病毒肺炎地级市疫情图
# 72      A NSFW hentai discord bot with extra functiona...
# ...                                                   ...
# 178063           :whale2: JupyterHub Docker configuration
# 178065  Concatenate histories weather data collected b...
# 178067  Simple project to detect if a person is wearin...
# 178068                               Frontend for Tackode
# 178069                                Backend for Tackode
#
#                                          contributors_url  archived  disabled  \
# 40      https://api.github.com/repos/elinlutz/gatsby-m...     False     False
# 41      https://api.github.com/repos/CIDO-ontology/cid...     False     False
# 64      https://api.github.com/repos/curiousily/Gettin...     False     False
# 67      https://api.github.com/repos/lispczz/pneumonia...     False     False
# 72      https://api.github.com/repos/Eddy-Arch/Hentai-...     False     False
# ...                                                   ...       ...       ...
# 178063  https://api.github.com/repos/kclhi/jupyter/con...     False     False
# 178065  https://api.github.com/repos/ALT-F1/OpenWeathe...     False     False
# 178067  https://api.github.com/repos/jahnavi-prasad/fa...     False     False
# 178068  https://api.github.com/repos/Tackode/frontend/...     False     False
# 178069  https://api.github.com/repos/Tackode/backend/c...     False     False
#
#         stargazers_count  watchers_count  forks_count  ...  has_projects  \
# 40                    31              31           12  ...          True
# 41                    13              13            9  ...          True
# 64                   957             957          300  ...          True
# 67                   356             356          100  ...          True
# 72                    21              21           12  ...          True
# ...                  ...             ...          ...  ...           ...
# 178063                 2               2            0  ...          True
# 178065                 1               1            0  ...          True
# 178067                 6               6            7  ...          True
# 178068                 0               0            0  ...          True
# 178069                 0               0            0  ...          True
#
#         has_wiki                              homepage  \
# 40          True               https://coronakartan.se
# 41          True                                   NaN
# 64          True           https://www.curiousily.com/
# 67          True  https://lispczz.github.io/pneumonia/
# 72          True                                   NaN
# ...          ...                                   ...
# 178063      True                     https://kclhi.org
# 178065      True                  http://www.alt-f1.be
# 178067      True                                   NaN
# 178068      True                   https://tackode.com
# 178069      True                   https://tackode.com
#
#                                                  html_url          language  \
# 40                 https://github.com/elinlutz/gatsby-map        JavaScript
# 41                  https://github.com/CIDO-ontology/cido               NaN
# 64      https://github.com/curiousily/Getting-Things-D...  Jupyter Notebook
# 67                   https://github.com/lispczz/pneumonia        JavaScript
# 72        https://github.com/Eddy-Arch/Hentai-discord-bot            Python
# ...                                                   ...               ...
# 178063                   https://github.com/kclhi/jupyter            Python
# 178065  https://github.com/ALT-F1/OpenWeatherMap-conca...            Python
# 178067  https://github.com/jahnavi-prasad/face-mask-de...            Python
# 178068                https://github.com/Tackode/frontend               Vue
# 178069                 https://github.com/Tackode/backend              Rust
#
#                   created_at             pushed_at            updated_at  \
# 40      2020-01-30T13:43:13Z  2021-05-06T16:13:49Z  2020-07-01T14:29:51Z
# 41      2020-01-25T19:30:01Z  2021-08-12T05:47:50Z  2021-08-12T05:47:53Z
# 64      2020-01-31T08:02:53Z  2021-06-14T09:47:01Z  2021-08-14T11:16:33Z
# 67      2020-01-25T08:56:59Z  2021-08-12T22:57:00Z  2021-07-30T00:06:31Z
# 72      2019-12-21T12:55:55Z  2021-07-18T09:53:05Z  2021-07-29T10:33:41Z
# ...                      ...                   ...                   ...
# 178063  2020-06-04T22:35:16Z  2021-06-11T18:23:39Z  2021-08-14T14:32:53Z
# 178065  2020-06-05T04:04:46Z  2021-08-12T13:30:11Z  2020-06-08T12:44:27Z
# 178067  2020-06-06T07:39:31Z  2020-06-06T07:46:00Z  2021-05-03T13:00:00Z
# 178068  2020-06-06T14:57:50Z  2021-08-12T04:05:02Z  2021-01-11T08:38:35Z
# 178069  2020-06-06T14:30:13Z  2021-08-13T04:03:31Z  2021-05-26T08:44:01Z
#
#                                                   svn_url     owner.login
# 40                 https://github.com/elinlutz/gatsby-map        elinlutz
# 41                  https://github.com/CIDO-ontology/cido   CIDO-ontology
# 64      https://github.com/curiousily/Getting-Things-D...      curiousily
# 67                   https://github.com/lispczz/pneumonia         lispczz
# 72        https://github.com/Eddy-Arch/Hentai-discord-bot       Eddy-Arch
# ...                                                   ...             ...
# 178063                   https://github.com/kclhi/jupyter           kclhi
# 178065  https://github.com/ALT-F1/OpenWeatherMap-conca...          ALT-F1
# 178067  https://github.com/jahnavi-prasad/face-mask-de...  jahnavi-prasad
# 178068                https://github.com/Tackode/frontend         Tackode
# 178069                 https://github.com/Tackode/backend         Tackode
#
# [18913 rows x 23 columns]

# %% [markdown]
# Comprobamos los repositorios que tienen palabras relacionadas en la descripción:

# %%
df_in_description_boolean = df_not_in_name.description.str.contains(pattern_description)
df_in_description_boolean
# Out:
# 40         True
# 41         True
# 64         True
# 67         True
# 72         True
#           ...
# 178063    False
# 178065    False
# 178067     True
# 178068    False
# 178069    False
# Name: description, Length: 18913, dtype: object

# %% [markdown]
# Número de repositorios que tienen la descripción a nula:

# %%
df_in_description_boolean.isnull().sum()
# Out:
# 140

# %%
#Rellenamos a False los valores nulos de la descripción
df_in_description_boolean = df_in_description_boolean.fillna(False)

df_in_description = df_not_in_name[df_in_description_boolean]
df_in_description
# Out:
#                id                              name  \
# 40      237221585                        gatsby-map
# 41      236218942                              cido
# 64      237385601  Getting-Things-Done-with-Pytorch
# 67      236146885                         pneumonia
# 72      229427465                Hentai-discord-bot
# ...           ...                               ...
# 178037  267352452                    steam-lockdown
# 178047  267575087                Smart-Food-Storage
# 178050  246130172                         Airplanes
# 178051  267858096      face_mask_detection_openvino
# 178067  269906994               face-mask-detection
#
#                                           full_name  \
# 40                              elinlutz/gatsby-map
# 41                               CIDO-ontology/cido
# 64      curiousily/Getting-Things-Done-with-Pytorch
# 67                                lispczz/pneumonia
# 72                     Eddy-Arch/Hentai-discord-bot
# ...                                             ...
# 178037             digital-wellbeing/steam-lockdown
# 178047                m-boutaleb/Smart-Food-Storage
# 178050                          cgettings/Airplanes
# 178051         mmphego/face_mask_detection_openvino
# 178067           jahnavi-prasad/face-mask-detection
#
#                                               description  \
# 40      Mapping the coronavirus in react, gatsby.js an...
# 41          CIDO: Coronavirus Infectious Disease Ontology
# 64      Jupyter Notebook tutorials on solving real-wor...
# 67                                       中国新型冠状病毒肺炎地级市疫情图
# 72      A NSFW hentai discord bot with extra functiona...
# ...                                                   ...
# 178037  How has gaming changed during lockdown? Analys...
# 178047  An intelligent application (very useful during...
# 178050  Visualizing flights into LGA at the start of t...
# 178051  Detect faces and determine whether people are ...
# 178067  Simple project to detect if a person is wearin...
#
#                                          contributors_url  archived  disabled  \
# 40      https://api.github.com/repos/elinlutz/gatsby-m...     False     False
# 41      https://api.github.com/repos/CIDO-ontology/cid...     False     False
# 64      https://api.github.com/repos/curiousily/Gettin...     False     False
# 67      https://api.github.com/repos/lispczz/pneumonia...     False     False
# 72      https://api.github.com/repos/Eddy-Arch/Hentai-...     False     False
# ...                                                   ...       ...       ...
# 178037  https://api.github.com/repos/digital-wellbeing...     False     False
# 178047  https://api.github.com/repos/m-boutaleb/Smart-...     False     False
# 178050  https://api.github.com/repos/cgettings/Airplan...     False     False
# 178051  https://api.github.com/repos/mmphego/face_mask...     False     False
# 178067  https://api.github.com/repos/jahnavi-prasad/fa...     False     False
#
#         stargazers_count  watchers_count  forks_count  ...  has_projects  \
# 40                    31              31           12  ...          True
# 41                    13              13            9  ...          True
# 64                   957             957          300  ...          True
# 67                   356             356          100  ...          True
# 72                    21              21           12  ...          True
# ...                  ...             ...          ...  ...           ...
# 178037                 0               0            0  ...          True
# 178047                 0               0            0  ...          True
# 178050                 0               0            0  ...          True
# 178051                35              35           11  ...          True
# 178067                 6               6            7  ...          True
#
#         has_wiki                                           homepage  \
# 40          True                            https://coronakartan.se
# 41          True                                                NaN
# 64          True                        https://www.curiousily.com/
# 67          True               https://lispczz.github.io/pneumonia/
# 72          True                                                NaN
# ...          ...                                                ...
# 178037      True  https://digital-wellbeing.github.io/steam-lock...
# 178047      True                                                NaN
# 178050     False                                                NaN
# 178051      True  https://blog.mphomphego.co.za/blog/2020/06/02/...
# 178067      True                                                NaN
#
#                                                  html_url          language  \
# 40                 https://github.com/elinlutz/gatsby-map        JavaScript
# 41                  https://github.com/CIDO-ontology/cido               NaN
# 64      https://github.com/curiousily/Getting-Things-D...  Jupyter Notebook
# 67                   https://github.com/lispczz/pneumonia        JavaScript
# 72        https://github.com/Eddy-Arch/Hentai-discord-bot            Python
# ...                                                   ...               ...
# 178037  https://github.com/digital-wellbeing/steam-loc...              HTML
# 178047   https://github.com/m-boutaleb/Smart-Food-Storage              Java
# 178050             https://github.com/cgettings/Airplanes              HTML
# 178051  https://github.com/mmphego/face_mask_detection...            Python
# 178067  https://github.com/jahnavi-prasad/face-mask-de...            Python
#
#                   created_at             pushed_at            updated_at  \
# 40      2020-01-30T13:43:13Z  2021-05-06T16:13:49Z  2020-07-01T14:29:51Z
# 41      2020-01-25T19:30:01Z  2021-08-12T05:47:50Z  2021-08-12T05:47:53Z
# 64      2020-01-31T08:02:53Z  2021-06-14T09:47:01Z  2021-08-14T11:16:33Z
# 67      2020-01-25T08:56:59Z  2021-08-12T22:57:00Z  2021-07-30T00:06:31Z
# 72      2019-12-21T12:55:55Z  2021-07-18T09:53:05Z  2021-07-29T10:33:41Z
# ...                      ...                   ...                   ...
# 178037  2020-05-27T15:10:55Z  2021-02-10T14:26:15Z  2021-02-16T13:48:34Z
# 178047  2020-05-28T11:45:23Z  2020-10-04T15:25:00Z  2021-03-23T08:43:26Z
# 178050  2020-03-09T20:01:16Z  2020-08-10T19:11:27Z  2020-08-10T19:11:31Z
# 178051  2020-05-29T12:56:47Z  2021-02-16T12:18:40Z  2021-05-25T21:53:17Z
# 178067  2020-06-06T07:39:31Z  2020-06-06T07:46:00Z  2021-05-03T13:00:00Z
#
#                                                   svn_url        owner.login
# 40                 https://github.com/elinlutz/gatsby-map           elinlutz
# 41                  https://github.com/CIDO-ontology/cido      CIDO-ontology
# 64      https://github.com/curiousily/Getting-Things-D...         curiousily
# 67                   https://github.com/lispczz/pneumonia            lispczz
# 72        https://github.com/Eddy-Arch/Hentai-discord-bot          Eddy-Arch
# ...                                                   ...                ...
# 178037  https://github.com/digital-wellbeing/steam-loc...  digital-wellbeing
# 178047   https://github.com/m-boutaleb/Smart-Food-Storage         m-boutaleb
# 178050             https://github.com/cgettings/Airplanes          cgettings
# 178051  https://github.com/mmphego/face_mask_detection...            mmphego
# 178067  https://github.com/jahnavi-prasad/face-mask-de...     jahnavi-prasad
#
# [17566 rows x 23 columns]

# %% [markdown]
# Actualizamos en *df_res_final* con los repositorios que tienen palabras relacionadas en la descripción:

# %%
df_res_final = df_res_final.append(df_in_description)
df_res_final
# Out:
#                id                          name  \
# 0       238316428                      COVID-19
# 1       235374822                      COVID-19
# 2       239777191                   coronavirus
# 3       237129709                   coronavirus
# 4       234936988                          ncov
# ...           ...                           ...
# 178037  267352452                steam-lockdown
# 178047  267575087            Smart-Food-Storage
# 178050  246130172                     Airplanes
# 178051  267858096  face_mask_detection_openvino
# 178067  269906994           face-mask-detection
#
#                                    full_name  \
# 0                    CSSEGISandData/COVID-19
# 1                     midas-network/COVID-19
# 2                    RamiKrispin/coronavirus
# 3                  FoldingAtHome/coronavirus
# 4                            nextstrain/ncov
# ...                                      ...
# 178037      digital-wellbeing/steam-lockdown
# 178047         m-boutaleb/Smart-Food-Storage
# 178050                   cgettings/Airplanes
# 178051  mmphego/face_mask_detection_openvino
# 178067    jahnavi-prasad/face-mask-detection
#
#                                               description  \
# 0       Novel Coronavirus (COVID-19) Cases, provided b...
# 1                       2019 novel coronavirus repository
# 2                                 The coronavirus dataset
# 3                           Folding@home COVID-19 efforts
# 4       Nextstrain build for novel coronavirus SARS-CoV-2
# ...                                                   ...
# 178037  How has gaming changed during lockdown? Analys...
# 178047  An intelligent application (very useful during...
# 178050  Visualizing flights into LGA at the start of t...
# 178051  Detect faces and determine whether people are ...
# 178067  Simple project to detect if a person is wearin...
#
#                                          contributors_url  archived  disabled  \
# 0       https://api.github.com/repos/CSSEGISandData/CO...     False     False
# 1       https://api.github.com/repos/midas-network/COV...     False     False
# 2       https://api.github.com/repos/RamiKrispin/coron...     False     False
# 3       https://api.github.com/repos/FoldingAtHome/cor...     False     False
# 4       https://api.github.com/repos/nextstrain/ncov/c...     False     False
# ...                                                   ...       ...       ...
# 178037  https://api.github.com/repos/digital-wellbeing...     False     False
# 178047  https://api.github.com/repos/m-boutaleb/Smart-...     False     False
# 178050  https://api.github.com/repos/cgettings/Airplan...     False     False
# 178051  https://api.github.com/repos/mmphego/face_mask...     False     False
# 178067  https://api.github.com/repos/jahnavi-prasad/fa...     False     False
#
#         stargazers_count  watchers_count  forks_count  ...  has_projects  \
# 0                  27211           27211        17432  ...          True
# 1                    642             642          221  ...          True
# 2                    394             394          175  ...          True
# 3                   1115            1115           87  ...          True
# 4                   1208            1208          343  ...          True
# ...                  ...             ...          ...  ...           ...
# 178037                 0               0            0  ...          True
# 178047                 0               0            0  ...          True
# 178050                 0               0            0  ...          True
# 178051                35              35           11  ...          True
# 178067                 6               6            7  ...          True
#
#         has_wiki                                           homepage  \
# 0           True  https://systems.jhu.edu/research/public-health...
# 1           True                                                NaN
# 2           True         https://ramikrispin.github.io/coronavirus/
# 3           True                          https://foldingathome.org
# 4           True                        https://nextstrain.org/ncov
# ...          ...                                                ...
# 178037      True  https://digital-wellbeing.github.io/steam-lock...
# 178047      True                                                NaN
# 178050     False                                                NaN
# 178051      True  https://blog.mphomphego.co.za/blog/2020/06/02/...
# 178067      True                                                NaN
#
#                                                  html_url  language  \
# 0              https://github.com/CSSEGISandData/COVID-19       NaN
# 1               https://github.com/midas-network/COVID-19       TeX
# 2              https://github.com/RamiKrispin/coronavirus         R
# 3            https://github.com/FoldingAtHome/coronavirus    Python
# 4                      https://github.com/nextstrain/ncov    Python
# ...                                                   ...       ...
# 178037  https://github.com/digital-wellbeing/steam-loc...      HTML
# 178047   https://github.com/m-boutaleb/Smart-Food-Storage      Java
# 178050             https://github.com/cgettings/Airplanes      HTML
# 178051  https://github.com/mmphego/face_mask_detection...    Python
# 178067  https://github.com/jahnavi-prasad/face-mask-de...    Python
#
#                   created_at             pushed_at            updated_at  \
# 0       2020-02-04T22:03:53Z  2021-08-14T11:35:08Z  2021-08-14T11:56:01Z
# 1       2020-01-21T15:27:23Z  2021-08-12T20:15:14Z  2021-08-12T20:15:21Z
# 2       2020-02-11T14:08:06Z  2021-08-14T08:19:49Z  2021-08-14T08:19:52Z
# 3       2020-01-30T03:12:19Z  2020-10-27T03:29:18Z  2021-08-09T21:17:36Z
# 4       2020-01-19T17:23:17Z  2021-08-13T12:36:06Z  2021-08-13T12:36:10Z
# ...                      ...                   ...                   ...
# 178037  2020-05-27T15:10:55Z  2021-02-10T14:26:15Z  2021-02-16T13:48:34Z
# 178047  2020-05-28T11:45:23Z  2020-10-04T15:25:00Z  2021-03-23T08:43:26Z
# 178050  2020-03-09T20:01:16Z  2020-08-10T19:11:27Z  2020-08-10T19:11:31Z
# 178051  2020-05-29T12:56:47Z  2021-02-16T12:18:40Z  2021-05-25T21:53:17Z
# 178067  2020-06-06T07:39:31Z  2020-06-06T07:46:00Z  2021-05-03T13:00:00Z
#
#                                                   svn_url        owner.login
# 0              https://github.com/CSSEGISandData/COVID-19     CSSEGISandData
# 1               https://github.com/midas-network/COVID-19      midas-network
# 2              https://github.com/RamiKrispin/coronavirus        RamiKrispin
# 3            https://github.com/FoldingAtHome/coronavirus      FoldingAtHome
# 4                      https://github.com/nextstrain/ncov         nextstrain
# ...                                                   ...                ...
# 178037  https://github.com/digital-wellbeing/steam-loc...  digital-wellbeing
# 178047   https://github.com/m-boutaleb/Smart-Food-Storage         m-boutaleb
# 178050             https://github.com/cgettings/Airplanes          cgettings
# 178051  https://github.com/mmphego/face_mask_detection...            mmphego
# 178067  https://github.com/jahnavi-prasad/face-mask-de...     jahnavi-prasad
#
# [176723 rows x 23 columns]

# %% [markdown]
# A continuación filtramos, quedándonos con los que NO tienen palabras relacionadas en la descripción:

# %%
df_not_in_description = df_not_in_name[~df_in_description_boolean]
df_not_in_description
# Out:
#                id                             name  \
# 79      229502804       data-visualisation-scripts
# 140     141635301          Water-Monitoring-System
# 157     237388368                        red-cross
# 458     170732312                 limnoria-plugins
# 842     155705971                  alm-api-backend
# ...           ...                              ...
# 178062  268856502               iot-contact-tracer
# 178063  269479371                          jupyter
# 178065  269527538  OpenWeatherMap-concat-histories
# 178068  270013759                         frontend
# 178069  270006438                          backend
#
#                                      full_name  \
# 79       Perishleaf/data-visualisation-scripts
# 140       vinitshahdeo/Water-Monitoring-System
# 157                       WeileiZeng/red-cross
# 458                   oddluck/limnoria-plugins
# 842                     Beor18/alm-api-backend
# ...                                        ...
# 178062                 fwcd/iot-contact-tracer
# 178063                           kclhi/jupyter
# 178065  ALT-F1/OpenWeatherMap-concat-histories
# 178068                        Tackode/frontend
# 178069                         Tackode/backend
#
#                                               description  \
# 79      Collection of scripts for data visualisation a...
# 140     Water Monitoring System is an IOT based Liquid...
# 157                                              官方公示数据概览
# 458                   Limnoria plugins I wrote or forked.
# 842     Comenzo como desafio almundo.com y ahora estoy...
# ...                                                   ...
# 178062  Decentralized contact tracing system supportin...
# 178063           :whale2: JupyterHub Docker configuration
# 178065  Concatenate histories weather data collected b...
# 178068                               Frontend for Tackode
# 178069                                Backend for Tackode
#
#                                          contributors_url  archived  disabled  \
# 79      https://api.github.com/repos/Perishleaf/data-v...     False     False
# 140     https://api.github.com/repos/vinitshahdeo/Wate...     False     False
# 157     https://api.github.com/repos/WeileiZeng/red-cr...     False     False
# 458     https://api.github.com/repos/oddluck/limnoria-...     False     False
# 842     https://api.github.com/repos/Beor18/alm-api-ba...     False     False
# ...                                                   ...       ...       ...
# 178062  https://api.github.com/repos/fwcd/iot-contact-...     False     False
# 178063  https://api.github.com/repos/kclhi/jupyter/con...     False     False
# 178065  https://api.github.com/repos/ALT-F1/OpenWeathe...     False     False
# 178068  https://api.github.com/repos/Tackode/frontend/...     False     False
# 178069  https://api.github.com/repos/Tackode/backend/c...     False     False
#
#         stargazers_count  watchers_count  forks_count  ...  has_projects  \
# 79                    80              80           90  ...          True
# 140                  128             128          245  ...          True
# 157                   19              19            4  ...          True
# 458                   33              33            8  ...          True
# 842                   11              11            2  ...          True
# ...                  ...             ...          ...  ...           ...
# 178062                 1               1            0  ...          True
# 178063                 2               2            0  ...          True
# 178065                 1               1            0  ...          True
# 178068                 0               0            0  ...          True
# 178069                 0               0            0  ...          True
#
#         has_wiki                                           homepage  \
# 79          True                                                NaN
# 140         True  https://vinitshahdeo.github.io/Water-Monitorin...
# 157         True            https://weileizeng.github.io/red-cross/
# 458         True                                                NaN
# 842         True  https://almundo-examen.herokuapp.com/api/v1/ho...
# ...          ...                                                ...
# 178062      True                                                NaN
# 178063      True                                  https://kclhi.org
# 178065      True                               http://www.alt-f1.be
# 178068      True                                https://tackode.com
# 178069      True                                https://tackode.com
#
#                                                  html_url          language  \
# 79      https://github.com/Perishleaf/data-visualisati...  Jupyter Notebook
# 140     https://github.com/vinitshahdeo/Water-Monitori...              HTML
# 157               https://github.com/WeileiZeng/red-cross            Python
# 458           https://github.com/oddluck/limnoria-plugins            Python
# 842             https://github.com/Beor18/alm-api-backend        JavaScript
# ...                                                   ...               ...
# 178062         https://github.com/fwcd/iot-contact-tracer              Dart
# 178063                   https://github.com/kclhi/jupyter            Python
# 178065  https://github.com/ALT-F1/OpenWeatherMap-conca...            Python
# 178068                https://github.com/Tackode/frontend               Vue
# 178069                 https://github.com/Tackode/backend              Rust
#
#                   created_at             pushed_at            updated_at  \
# 79      2019-12-22T01:12:45Z  2020-08-06T12:06:03Z  2021-06-10T12:17:53Z
# 140     2018-07-19T22:06:05Z  2021-06-09T18:42:30Z  2021-08-06T15:01:36Z
# 157     2020-01-31T08:22:45Z  2021-07-13T07:01:42Z  2020-05-27T05:59:00Z
# 458     2019-02-14T17:40:29Z  2021-06-23T19:44:25Z  2021-08-14T00:12:47Z
# 842     2018-11-01T11:37:25Z  2020-07-13T22:22:44Z  2020-09-20T03:56:50Z
# ...                      ...                   ...                   ...
# 178062  2020-06-02T16:46:15Z  2020-09-04T13:14:05Z  2020-09-04T15:03:54Z
# 178063  2020-06-04T22:35:16Z  2021-06-11T18:23:39Z  2021-08-14T14:32:53Z
# 178065  2020-06-05T04:04:46Z  2021-08-12T13:30:11Z  2020-06-08T12:44:27Z
# 178068  2020-06-06T14:57:50Z  2021-08-12T04:05:02Z  2021-01-11T08:38:35Z
# 178069  2020-06-06T14:30:13Z  2021-08-13T04:03:31Z  2021-05-26T08:44:01Z
#
#                                                   svn_url   owner.login
# 79      https://github.com/Perishleaf/data-visualisati...    Perishleaf
# 140     https://github.com/vinitshahdeo/Water-Monitori...  vinitshahdeo
# 157               https://github.com/WeileiZeng/red-cross    WeileiZeng
# 458           https://github.com/oddluck/limnoria-plugins       oddluck
# 842             https://github.com/Beor18/alm-api-backend        Beor18
# ...                                                   ...           ...
# 178062         https://github.com/fwcd/iot-contact-tracer          fwcd
# 178063                   https://github.com/kclhi/jupyter         kclhi
# 178065  https://github.com/ALT-F1/OpenWeatherMap-conca...        ALT-F1
# 178068                https://github.com/Tackode/frontend       Tackode
# 178069                 https://github.com/Tackode/backend       Tackode
#
# [1347 rows x 23 columns]

# %%
df_not_in_description.shape[0]
# Out:
# 1347

# %% [markdown]
# Nos quedan 1347 repositorios que habrá que analizar individualmente para saber si están relacionados con la COVID-19 o no. Para ello consultaremos los *topics* que los componen, a fin de encontrar tópicos relacionados con la pandemia.

# %%
# show(df_not_in_description)

# %% [markdown]
# ### Comprobación de *topics* en repositorios

# %%
token = "" # Rellenar con token generado en GitHub
header = {'Authorization': 'token %s' % token, 'Accept':'application/vnd.github.mercy-preview+json'}

# %%
df_topics = pd.DataFrame(columns=['id', 'topics'])

for ind in df_not_in_description.index:
    print("\n\n -- OBTENIENDO TOPICS DEL REPOSITORIO {} --".format(df_not_in_description['name'][ind]))
    
    query = "?q=per_page=100"

    response = requests.get('https://api.github.com/repos/' + df_not_in_description['full_name'][ind] + "/topics" + query, 
                            headers=header)
    response_json = response.json()
    
    if "names" in response_json:
        print(response_json["names"])

        df_topics.loc[ind] = [df_not_in_description['id'][ind], response_json["names"]]
    else:
        df_topics.loc[ind] = [df_not_in_description['id'][ind], None]
        
    print("Esperando 0,5 segundos...")
    time.sleep(0.5)
# Out:
#  -- OBTENIENDO TOPICS DEL REPOSITORIO data-visualisation-scripts --
# ['datavisualization', 'python3', 'covid-19', 'dashborad', 'matplotlib', 'plotly-dash', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Water-Monitoring-System --
# ['iot', 'water-monitoring', 'jquery', 'javascript', 'arduino', 'ultrasonic-sensors', 'hardware', 'nodejs', 'django', 'api', 'rgsoc', 'gssoc20', 'gssoc', 'covid-19', 'coronavirus-tracking', 'coronavirus', 'coronavirus-real-time', 'hacktoberfest', 'hacktoberfest2020']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO red-cross --
# ['red-cross', 'github-pages', 'coronavirus', 'covid-19', 'open-source-wuhan', 'ncov']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO limnoria-plugins --
# ['limnoria', 'irc', 'ascii-art', 'jeopardy', 'uno', 'interactive-fiction', 'lyrics', 'irc-art', 'ansi-art', 'cards-against-humanity', 'zork', 'limnoria-plugins', 'trivia', 'supybot', 'supybot-plugin', 'dice-roller', 'boggle', 'anagrams', 'irc-game', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO alm-api-backend --
# ['mongodb', 'nodejs', 'api', 'apirest', 'javascript', 'graphql', 'express', 'express-graphql', 'boilerplate', 'moongose', 'coronavirus', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO PCI-Outbreak --
# ['machine-learning', 'china', 'propaganda', 'wuhan', 'policy-change', 'official-media', 'psl-incubating', 'outbreak', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Personal-Projects --
# ['whatsapp', 'covid-19', 'coronavirus', 'webscraping']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO data-visualiztion-library --
# ['data-visualization', 'coronavirus', 'data-exploration', 'coronavirus-dataset', 'coronavirus-data-analysis']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO web --
# ['d3', 'data-visualization', 'covid19', 'coronavirus', 'vuejs', 'gridsome', 'static-site']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Korean-Data-Set --
# ['korean', 'database', 'dataset', 'datasets', 'cocktails', 'p2p', 'coronavirus', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO MikeOwino.github.io --
# ['personal-website', 'personal', 'blog', 'coronavirus', 'coronavirus-tracking', 'coronavirus-real-time', 'corona', 'ncov', 'ncov-2019', 'trending-repositories', 'trending', 'covidly', 'covid-19', 'covid19', 'covid19-data', 'pandemic', 'virus', 'jhu-csse', 'html']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO koronatartunnat --
# ['svelte', 'geojson', 'coronavirus', 'visualization', 'ssr']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Pressure --
# ['arduino-library', 'arduino', 'pressure-sensor', 'covid-19', 'arduino-sensors', 'coronavirus', 'nxp-pressure', 'mxp-pressure', 'nxp-mxp', 'mpxv5010', 'mpx5700', 'sensor', 'sensor-mpx', 'kpa', 'cmh2o-quantities', 'pressure', 'gauge-sensors', 'manufacturer-nxp', 'pressure-sensing', 'pressure-sensors']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO convid_19_crawler --
# ['scrapy', 'scrapy-crawler', 'covid-19', 'coronavirus', 'covid19-data']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO iorestoacasa.work --
# ['covid-19', 'covid19', 'coronavirus', 'iorestoacasa', 'jitsi', 'jitsi-meet', 'videocall']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO QQCourseBot --
# ['qq', 'qqbot', 'online-course', 'china', 'coronavirus', 'cqhttp', 'tencent-meeting', 'coolq']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO is-it-safe-to --
# ['coronavirus', 'safety']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO sports-hall-management-calendar --
# ['sports', 'training', 'calendar', 'covid-19', 'planning', 'participation', 'management', 'corona', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO diventiamo-immuni --
# ['immuni', 'covid-19', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Forschungsseminar_I3C_ChallengeApp --
# ['gamification', 'covid-19', 'coronavirus', 'challenges', 'social']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO fossresponders.com --
# ['website', 'foss', 'coronavirus', 'covid-19', 'floss', 'oss', 'open-source']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO bear_market --
# ['stock-market', 'coronavirus', 'recession-indicator', 'recession', 'algorithmic-trading', 'leverage', 'futuresmarkets', 'trading-strategies', 'trading-algorithms', 'trading-bot']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Python-Quiz-Application --
# ['python', 'python3', 'isolation', 'coronavirus', 'tkinter-gui', 'tkinter', 'quizapp', 'txt', 'idle', 'python38', 'quiz-app', 'quiz-game', 'lists', 'readme', 'autogenerated', 'auto-generated', 'auto-generate', 'os-package', 'os']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO heimschulung.github.io --
# ['coronavirus', 'heimschulung', 'homeschooling', 'schweiz']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO hclbetterhealthhackathon --
# ['hcl', 'hackathon', 'coronavirus', 'coronavirus-real-time', 'socialdistancing', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO AndroidBluetoothChatSample --
# ['android', 'java', 'coronavirus', 'bluetooth', 'chat', 'communication', 'socialdistancing']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO World-Happiness-Index-2020--data-visualization --
# ['data-science', 'datavisualization', 'dataanalysis', 'datacleaning', 'machine-learning', 'covid19', 'covid-19', 'machinelearning', 'machine-learning-algorithms', 'coronavirus', 'worldhappiness']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO plasmabankbd --
# ['coronavirus', 'covid-19', 'website', 'plasma', 'donors']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO AnomalyDetect --
# ['heart-rate', 'smartwatch-data', 'rhr', 'anomaly-detection-algorithm', 'gaussian', 'covid-19', 'sars-cov-2', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO council-lotteries --
# ['gambling', 'councils', 'coronavirus', 'shareddataunit']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO fiipregatit.ro --
# ['emergency-response', 'coronavirus', 'covid-19', 'emergency-situation', 'civic-tech']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO social-distancing --
# ['javascript', 'html5-canvas', 'epidemiology', 'coronavirus', 'covid-19', 'social-distancing']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO spec-shield --
# ['spec-shield', 'coronavirus', 'face-shield', 'face-mask', 'covid-19', 'covid']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Keep_Distance --
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO fahclient-azure-vm --
# ['coronavirus', 'covid-19', 'foldingathome', 'azure', 'arm-templates', 'linux']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO fah-heroku --
# ['heroku', 'fah', 'foldingathome', 'covid-19', 'herokuapp', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO cv-updates --
# ['coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO visualizations --
# ['visualization', 'data-visualization', 'd3', 'd3js', 'tableau', 'python', 'covid-19', 'coronavirus', 'fitbit']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO rpkg --
# ['epidemiology', 'epidemic-simulations', 'sir-model', 'epidemiology-analysis', 'epidemic-model', 'epidemics', 'covid-19', 'covid', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO WFH_Resources --
# ['wfh-resources', 'wfh', 'coronavirus', 'corona']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO happy-life-home --
# ['awesome-list', 'covid-19', 'coronavirus', 'stem', 'kids-learn', 'homeschooling']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO cocoa-getinfo --
# ['python', 'ocr', 'google-sheets', 'twitter-api', 'scraping-websites', 'tesseract', 'covid-19', 'matplotlib', 'pandas', 'gspread', 'covid19-data', 'coronavirus-info', 'coronavirus', 'coronavirus-analysis', 'raspberry-pi']
# Esperando 0,5 segundos...
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Many-Api --
# ['api', 'garfield', 'covid19', 'coronavirus', 'c19', 'pokemon', 'pokemondata', 'pokemonapi', 'garfieldapi', 'atla', 'coronavirus-data', 'mcu', 'marvel', 'marvelquotes', 'twitter', 'tweets', 'marvel-api', 'covidapi', 'jokes', 'jokes-api']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO status --
# ['vkontakte', 'vk-api', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO awesome-confinement --
# ['awesome-list', 'awesome-lists', 'coronavirus', 'confinement']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO OpenVentilator --
# ['ventilator', 'arduino', 'covid-19', 'covid', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO KoronaKartta --
# ['coronavirus', 'map', 'finland', 'history']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO attestation-deplacement-derogatoire --
# ['france', 'confinement', 'covid-19', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO toilet-paper-calculator --
# ['javascript', 'reactjs', 'coronavirus', 'math']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO transafer --
# ['coronavirus', 'public-transport', 'seirs', 'chatbot']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO cocoa-documentation --
# ['covid-19', 'covid-19-japan', 'exposure-notification', 'cocoa', 'coronavirus', 'cocoa-debugging']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Social_Distancing-CV --
# ['social-distancing', 'covid-19', 'computer-vision', 'opencv', 'tensorflow', 'ai', 'python', 'covid19', 'deep-learning', 'coronavirus', 'caffe', 'ssd', 'object-detection', 'social-distancing-detection', 'social-distance-monitoring']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Decoding-the-Digital-Divide --
# ['broadband-access', 'school-district', 'impact', 'digital-divide', 'coronavirus', 'education', 'census', 'census-data', 'data-science', 'portfolio', 'flatiron-school', 'scikit-learn', 'python', 'decision-tree-regression']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO cocoa-issues --
# ['covid-19', 'covid-19-japan', 'coronavirus', 'exposure-notification', 'cocoa', 'cocoa-debugging']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Virtual_Line_Client_App --
# ['android', 'android-application', 'android-app', 'androidstudio', 'mvvm-android', 'retrofit', 'googlemaps-sdk', 'mapbox-android-sdk', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO makair --
# ['covid-19', 'fusion-360', 'cad', 'covid', 'coronavirus', 'sars-cov-2', 'nucleo-board', 'covid-respirator', 'makair-respirators', 'medical', 'ards', 'electronics']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO StopTouchingYourFace --
# ['swift', 'macos', 'coreml', 'segmentation', 'computer-vision', 'machine-learning', 'covid-19', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO hackactivista --
# ['coronavirus', 'covid-19', 'coronavirus-tracking', 'innovation', 'innovacionsocial', 'peru', 'chatbot-fb', 'chatbot-telegram']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO flu_vaccination --
# ['coronavirus', 'vaccination', 'health', 'flu', 'nhs']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO COCOAmockservice --
# ['codiv19', 'coronavirus', 'exposure-notification', 'python', 'python3', 'cocoa', 'cocoa-debugging', 'mock-server', 'flask']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO co2light --
# ['co2', 'traffic-light', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO reach4help --
# ['covid-19', 'coronavirus', 'volunteers', 'react']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO folding-at-home-docker --
# ['covid-19', 'covid-virus', 'coronavirus', 'foldingathome']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO sirsimx --
# ['sir-model', 'coronavirus', 'covid-19', 'simulation', 'javascript']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO service-relief --
# ['javascript', 'gatsby', 'service-relief', 'cities', 'corona', 'covid-19', 'covid19', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO corominder --
# ['coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO crisisite --
# ['coronavirus', 'vuejs', 'nuxtjs', 'wordpress', 'headless', 'jamstack']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Youtube-Projects --
# ['youtube', 'youtube-tutorials', 'html', 'css', 'javascript', 'python', 'juypter-notebook', 'jquery-plugin', 'website', 'scraper', 'crawler', 'google', 'chrome-extension', 'coronavirus', 'covid-19', 'msexcel', 'easy', 'webscraping', 'algorithms', 'project']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO bingo --
# ['bingo', 'coronavirus', 'covid-19', 'online', 'school']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Meditation_Yoga-Flutter --
# ['flutter', 'dart', 'meditation', 'yoga', 'excercise', 'covid-19', 'corona', 'coronavirus', 'asana', 'health', 'relaxation']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO provider-map-client --
# ['covid-19', 'covid-api', 'covid', 'coronavirus', 'coronavirus-info']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO charts --
# ['coronavirus', 'donate', 'kubernetes', 'compute', 'capacity', 'helm', 'chart', 'helm-chart', 'covid-19', 'covid19', 'foldingathome', 'folding', 'home', 'hpc', 'graphs4good']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO denverservicerelief --
# ['javscript', 'gatsby', 'service-relief', 'coronavirus', 'corona', 'covid-19', 'covid19', 'denver', 'colorado']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Rasa-bots --
# ['rasa-chatbot', 'rasa', 'rasa-nlu', 'rasa-core', 'rasa-x', 'chatbot', 'faq', 'data-collection', 'signinlog', 'registration-forms', 'coronavirus', 'fruit-bot', 'product-recommendation', 'apriori-algorithm', 'product-sellers', 'mysql-database']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO bluto --
# ['coronavirus', 'wirvsvirus', 'wirvsvirushack']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO respiradorhacker.github.io --
# ['gh-pages', 'jekyll', 'healthcare', 'covid-19', 'coronavirus', 'open-source']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO nexd-android --
# ['android', 'coronavirus', 'helper', 'nexd', 'rxjava', 'kotlin', 'data-binding', 'mvvm', 'wirvsvirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO experten-app --
# ['covid-19', 'wirvsvirushack', 'wirvsvirus', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO murmeltier-frontend --
# ['wirvsvirus', 'wirvsvirushack', 'mood', 'covid-19', 'coronavirus', 'murmeltier']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO murmeltier-backend --
# ['wirvsvirus', 'wirvsvirushack', 'mood', 'covid-19', 'coronavirus', 'murmeltier']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO app --
# ['wirvsvirus', 'wirvsvirushackathon', 'angular', 'local', 'secure', 'supermarket', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO documentation --
# ['coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO tracy-mobile-app --
# ['covid-19', 'coronavirus', 'react-native']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO SupplyInfo --
# ['coronavirus', 'covid-19', 'neighbourhood-supply', 'essentials', 'lockdown']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO epi-collect --
# ['covid-19', 'covid19', 'coronavirus', 'coronavirus-tracking', 'google-takeout', 'epidemiology', 'epidemiology-analysis']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Projeto-EAR-Celso --
# ['healthcare', 'covid-19', 'coronavirus', 'open-source', 'ear', 'open-hardware', 'ventilator', 'respirator', 'covid19', 'celso-monteiro', 'emerging-countries']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO stay-at-home-ohio --
# ['coronavirus', 'covid-19']
# Esperando 0,5 segundos...
#  -- OBTENIENDO TOPICS DEL REPOSITORIO super-simple-ventilator --
# ['ventilator', 'ventilator-firmware', 'platformio', 'coronavirus', 'covid-19', 'arduino']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO orange-cxr-classifier --
# ['covid-19', 'coronavirus', 'xray', 'chest', 'machine-learning', 'orange']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO RIST --
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO 7dayserlangen --
# ['hacktoberfest', 'coronavirus', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO pyross --
# ['covid-19', 'infectious-disease-models', 'epidemiological-predictions', 'epidemic-simulations', 'coronavirus', 'sars-cov-2', 'compartment-models', 'epidemiological-models', 'pyross']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO camara-descontaminacao-ar --
# ['healtcare', 'coronavirus', 'covid-19', 'open-source']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Quarantine --
# ['quarantine', 'quarantined', 'webdevelopment', 'opensource', 'open-source', 'css', 'html', 'first-issue', 'covid-19', 'coronavirus', 'contributions-welcome', 'contributions', 'hacktoberfest', 'hacktoberfest2020', 'hacktober']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO chronovid19 --
# ['chronodrive', 'covid-19', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO SIAFINALS --
# ['usjr', 'adelante', 'coronavirus', 'washyourhands']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO pillapp --
# ['2020', 'python', 'social-good', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO notouch-dispenser --
# ['covid19', 'covid-19', 'covid-2019', 'covid', 'healthy', 'healthcare', 'health', 'hand', 'cleaner', 'cleaning', 'domotic', 'iot', 'arduino', 'servo', 'ultrasonic-sensor', 'ultrasound', 'hc-sr04', 'sg90', 'ino', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO inteng33 --
# ['arduino', 'iot', 'webapp', 'flask', 'dash', 'coronavirus', 'brazil']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO r-package-assessment-Phyllis-Lin --
# ['coronavirus', 'shiny']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO C2N3_C3N3 --
# ['javascript', 'projet-validation', 'html', 'css', 'css3', 'flexbox-css', 'eventlistener', 'eventhandler', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO molecule-generation --
# ['machine-learning', 'pytorch', 'molecule-generation', 'computational-chemistry', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO adaptador-snorkel-a-epi --
# ['coronavirus', 'covid-19', 'covid19', '3d-printing', '3d-printer', '3d-models', 'epis', 'snorkel', 'cpap', 'epis-sanitario', 'ipe', 'sanitarie']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO ADD_202010 --
# ['attestation', 'confinement', 'covid-19', 'france', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO visualizacoes --
# ['ggplot2', 'storm-database', 'gtrends', 'coronavirus', 'pnad', 'dplyr', 'srvyr']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO awesome-quarantine --
# ['hackathons', 'webinar', 'online-learning', 'entertainment', 'softwares', 'coronavirus', 'covid19', 'quarantined', 'coronavirus-globaloutbreak', 'collaboration', 'students', 'meetings', 'jekyll', 'githubpages']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO FoodBanks --
# ['covid-19', 'coronavirus', 'food', 'foodbanks']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO solocoin-backend --
# ['coronavirus', 'coronavirus-tracking', 'social-distancing']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO fever-tracker --
# ['coronavirus', 'coronavirus-tracking', 'corona', 'nodejs', 'expressjs']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Edgar_Cardoso_Portfolio --
# ['covid-19', 'data-science', 'python', 'machine-learning', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Evos --
# ['evos', 'discord', 'discord-bot', 'python', 'bot', 'commands', 'coronavirus', 'currency-converter', 'lavalink', 'jar', 'music', 'discordpy']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO captcha-api --
# ['coronavirus', 'restapi', 'nodejs', 'npm', 'mysq', 'adonisjs', 'adonis-framework', 'adonisjs-framework']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO babino2020masks --
# ['masks', 'covid-19', 'covid', 'covid19', 'causality', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO tuvascraquer --
# ['covid-19', 'covid19', 'coronavirus', 'france', 'lockdown', 'confinement', 'quiz', 'fun', 'gatsby', 'gatsbyjs']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Good-News-Machine --
# ['sentiment-analysis', 'amazon-comprehend', 'pubsub', 'pubnub', 'rss-aggregator', 'rss', 'rss-feed-scraper', 'rss-generator', 'realtime', 'real-time', 'golang', 'news', 'coronavirus', 'coronavirus-real-time', 'rss-firehose', 'dashboard', 'positivity', 'news-machine', 'news-feed', 'news-aggregator']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO age-uk-boost --
# ['rails', 'coronavirus', 'covid-19', 'age-uk', 'charity', 'geocoding']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO BS_Mobile_Assignment --
# ['android-application', 'dagger2', 'mvvm', 'clean-architecture', 'clean-code', 'architecture-components', 'kotlin', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO whats-in-the-menu --
# ['covid', 'coronavirus', 'qr-code', 'python', 'django', 'html', 'css', 'scss', 'javascript', 'jquery']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Amazon-Fresh-Whole-Foods-delivery-slot-finder --
# ['applescript', 'amazon', 'whole-foods', 'automation', 'script', 'apple', 'mac', 'coronavirus', 'grocery-delivery', 'amazon-fresh', 'wholefoods', 'foods-delivery', 'delivery-slots', 'amazon-fresh-services', 'delivery-window-finder', 'scpt', 'notification']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO quarantine-help-hybrid --
# ['coronavirus', 'covid19', 'quarantine', 'volunteer-management', 'resource-management']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO karuna2020.org --
# ['karuna-2020', 'static-site', 'html', 'css', 'parcel', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO CT_lung_3D_segmentation --
# ['3d-segmentation', 'ct-scan-images', 'lung-segmentation', 'covid-19', 'coronavirus', '3d-unet']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO lmo --
# ['ruby', 'coronavirus', 'france', 'cli', 'rick-and-morty']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Heed --
# ['android', 'coronavirus', 'mapbox', 'location-based-services']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Kaggle-CORD-19 --
# ['cord19', 'python', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO TraceON --
# ['covid-19', 'coronavirus', 'traceon']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO CORD-19 --
# ['coronavirus', 'covid-19', 'kaggle']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO open-data --
# ['open-data', 'open-api', 'api', 'data', 'json', 'karuna-2020', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO branding --
# ['design', 'branding', 'logo', 'assets', 'cdn', 'karuna-2020', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Open-Bio-Ventilation-system --
# ['ventilation', 'ventilator', 'arduino', 'motor', 'bioinformatics', 'biotechnology', 'coronavirus', 'coronavirus-tracking', 'corona', 'coronavirus-real-time', 'coronavirus-info', 'capillaries', 'carbon-dioxide', 'concentration-gradient', 'covid-19', 'covid19', 'covid', 'covid19-data', 'covid-virus', 'covid-19-india']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO diky2020-backend --
# ['thanks', 'coronavirus', 'year', 'donations']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO delivery-do-bem --
# ['delivery', 'bem', 'covid-19', 'coronavirus', 'small', 'producers', 'brazilian']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Crawling --
# ['crawling', 'crawling-python', 'selenium', 'beautifulsoup', 'lda', 'lda-model', 'algorithms', 'wordcloud', 'coronavirus', 'covid19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Prioritize-Vaccine-Delivery --
# ['python', 'ai-ml', 'covid-19', 'coronavirus', 'vaccine', 'ai-model', 'ml-model', 'covidindia', 'vaccine-distribution', 'ey-hackathon']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO CO2_traffic_light --
# ['co2', 'sensor', 'arduino', 'python', 'stl', '7segment', 'rgb-led', 'arduinonano', 'coronavirus', 'air-quality']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO datamuseum.github.io --
# ['coronavirus', 'dashboard', 'covid-19', 'coronavirus-real-time']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO kryzysowa-kawa --
# ['crisis-related', 'coronavirus', 'poland']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Data --
# ['covid-19', 'coronavirus-tracking', '2019-ncov', '2019-ncov-data-vis', '2019-ncov-data', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO twitter-digest --
# ['netlify', 'serverless', 'netlify-lambda', 'covid-19', 'coronavirus', 'email', 'twitter-api', 'hacktoberfest']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO opendata-project --
# ['coronavirus', 'opendata', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO app16-nodejs --
# ['nodejs', 'mysql', 'app16', 'covid-19', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO blue-badges --
# ['shareddataunit', 'blue-badges', 'disability', 'disabilities', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO chezona --
# ['covid-19', 'italia', 'italy', 'coronavirus', 'zone']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO nl-eHealth-experimental --
# ['hl7', 'fhir', 'health', 'coronavirus', 'covid-19', 'covid19', 'european-union', 'minvws']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO terraform-folding-at-home --
# ['covid-19', 'foldingathome', 'coronavirus', 'terraform-template', 'gpu-models', 'terraform', 'gcp', 'containers', 'compute-engine']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO stimulus-check-calculator --
# ['covid-19', 'coronavirus-info', 'coronavirus', 'nextjs', 'react', 'reactjs']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO lost_years --
# ['life-tables', 'coronavirus', 'mortality', 'covid-19', 'who', 'hld', 'ssa']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO mortality2020 --
# ['coronavirus', 'covid-19', 'mortality']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Document-retrieval-system --
# ['sbert', 'nlp', 'cord-19', 'cord-19-dataset', 'coronavirus', 'sentence-embeddings', 'bert', 'infersent', 'pytorch', 'ai', 'ai2']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Project_Donghak --
# ['coronavirus', 'stockprice']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO BioExplorer --
# ['covid19', 'raytracing', 'coronavirus', 'science', 'molecular-biology', 'virus', 'sars-cov-2', 'viral-infection', 'glucose-levels', 'immune-system', 'virology', 'rendering-engine']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Helping-UCIs-Main --
# ['covid-19', 'health', 'uci', 'hospital', 'hackaton', 'vencealvirus', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO bioseq --
# ['perl', 'bioinformatics', 'genome', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Project-DIY-Ventilator --
# ['open-source', 'ventilator', 'diy', 'open-source-hardware', 'covid-19', 'covid-19-india', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO hack-the-crisis-2020-submission --
# ['hackthecrisis2020', 'coronavirus', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO ppe-donations --
# ['ppe', 'coronavirus', 'donation-drop', 'sewn-ties', 'visors', 'headband', 'face-shields', 'nih', '3d-printers', 'headbands-printed']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO site-mobiliza --
# ['coronavirus', 'unb', 'universidade-de-brasilia', 'site', 'mobiliza-ft']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO motivation-repository --
# ['room-database', 'retrofit2', 'cache-storage', 'livedata', 'databinding', 'coronavirus', 'viewmodel-pattern', 'mvvm-architecture']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO freeThingsToDoRightNow --
# ['covid19', 'free', 'list', 'awesome-list', 'awesome', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO infection-map --
# ['covid-19', 'coronavirus', 'coronavirus-tracking', 'avoid']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO maker-community-ppe --
# ['ppe', 'volunteering', 'makerspace', 'coronavirus', 'community', 'community-project']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO dangerous-crowds-tracker-server --
# ['coronavirus', 'server']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Android --
# ['android-application', 'coronavirus', 'vaccine']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO visitoraccess --
# ['2019-ncov', 'coronavirus', 'covid-19', 'covid19', 'health', 'hospital', 'access-management', 'react-native', 'javascript', 'nodejs', 'express', 'redux']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Cough-data --
# ['cough', 'covid-19', 'coronavirus', 'coronavirus-real-time']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Cough-signal-processing --
# ['signal-processing', 'covid-19', 'machine-learning', 'deep-learning', 'covid19', 'coronavirus', 'coronavirus-real-time', 'open-source']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO k8s-fah --
# ['folding', 'kubernetes', 'coronavirus', 'research', 'folding-at-home', 'covid', 'kubernetes-deployment']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO SearchMask --
# ['coronavirus', 'mask']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO CitizenScience --
# ['ireland', 'coronavirus', 'coronavirus-analysis']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO dct_client --
# ['coronavirus', 'mobile']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO szczepienia.github.io --
# ['covid-19', 'coronavirus', 'vaccine']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO auto-grocery-delivery --
# ['grocery-delivery', 'grocery', 'coronavirus', 'covid-19', 'instacart', 'automation', 'selenium', 'chromedriver', 'rspec-capybara', 'delivery-window-finder', 'amazon', 'whole-foods', 'checkout']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO vaccination-worker --
# ['wrangler', 'cloudflare', 'serverless', 'lametric', 'covid19', 'coronavirus', 'vaccination-tracker']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO myspeechassistant --
# ['speech-recognition', 'speech-to-text', 'coronavirus', 'news', 'email', 'ai', 'start', 'start-small-but-start', 'artificial-intelligence', 'assistant', 'speech-analysis']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO quarantine-help-web --
# ['covid19', 'coronavirus', 'quarantine', 'resource-manager', 'volunteer-management']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO cothings --
# ['coronavirus', 'covid-19', 'elixir-phoenix', 'share-house', 'beacons', 'socket', 'realtime', 'beacon', 'ibeacon', 'altbeacon', 'utilities', 'utility', 'counter', 'utility-counter', 'phoenix', 'elixir', 'kubernetes', 'kubernetes-deployment', 'docker', 'docker-image']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO CoConjure --
# ['coronavirus', 'coronavirus-tracking', 'javascript', 'php', 'geolocation', 'fetch-api']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO letsfighttogether --
# ['covid-19', 'coronavirus', 'donate']
# Esperando 0,5 segundos...
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Hackathon2021 --
# ['hackathon', 'iot', 'octopus', 'esp8266', 'co2', 'coronavirus', 'regression', 'physcomp']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO ExpCowin --
# ['nodejs', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO swaas-bot --
# ['nodejs', 'expressjs', 'javascript', 'mongodb', 'coronavirus', 'vaccination', 'india', 'whastappbot']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO bored-af --
# ['quarantine', 'quarantine-project', 'covid-19', 'python', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Amazon-Whole-Foods-Delivery-Slots-Finder --
# ['whole-foods', 'coronavirus', 'delivery-slots', 'covid-19', 'stay-home', 'amazon', 'chrome-extension', 'grocery-delivery', 'food-delivery', 'mac', 'windows', 'google-chrome', 'delivery-slot-alert', 'quarantine', 'alert']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO cowin-tracker --
# ['coronavirus', 'coronavirus-tracking', 'coronavirus-real-time', 'covid-19', 'cowin-vaccine-tracker']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Vac-Cowin --
# ['python', 'shell', 'terminal', 'command-line', 'covid', 'covid-19', 'cowin', 'cowin-api', 'covid19', 'software', 'apisetu', 'powershell', 'vaccination', 'vaccine', 'cowin-vaccine-tracker', 'algorithm', 'cli', 'coronavirus', 'cowin-portal', 'corona']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO workhealth --
# ['2019-ncov', 'coronavirus', 'covid-19', 'covid19', 'health', 'hospital', 'access-management', 'employee-management']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO pandemik --
# ['simulator', 'pandemic', 'epidemiology', 'behavior', 'economics', 'modelling', 'covid-19', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO SignPrinterApp --
# ['brother', 'printers', 'signs', 'sign-printer', 'coronavirus', 'covid', 'covid-19', 'covid19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO ucimlhack2021 --
# ['pandemic', 'uciml', 'nlp', 'coronavirus', 'covid19', 'covidlies']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO OxyGrant --
# ['covid-19', 'healthcare', 'oxygen', 'android', 'kotlin', 'mvvm', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO impftermin_finder --
# ['python', 'covid-19', 'impftermin', 'impfterminservice', 'bot', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Coswara-Data --
# ['cough', 'covid-19', 'coronavirus', 'machine-learning']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO respyrator --
# ['respyrator', 'ventilator', 'health', 'covid-19', 'coronavirus', 'python']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO ShopSafe --
# ['covid-19', 'coronavirus', 'waittimes']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO ShopSafe-Admin --
# ['covid-19', 'covid19', 'waittimes', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO impfung-niedersachsen-tool --
# ['greasemonkey', 'impfung', 'impftermin', 'covid-19', 'coronavirus', 'vaccine-availability', 'niedersachsen', 'bot', 'corona', 'vaccination', 'impfportal-niedersachsen', 'bookmarklets', 'booking']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO go-cowin --
# ['coronavirus', 'cowin', 'cowin-api', 'go', 'golang', 'sdk', 'mygovbc', 'india']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO coronika --
# ['corona', 'covid-19', 'react-native', 'android', 'ios', 'javascript', 'diary', 'health', 'coronavirus', 'coronavirus-daily-report']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO grocery-delivery --
# ['amazon', 'automation', 'beautifulsoup', 'selenium', 'whole-foods', 'coronavirus', 'covid-19', 'chrome', 'python', 'webdriver', 'cart', 'notification', 'grocery-delivery', 'amazon-fresh', 'foods-delivery', 'delivery-slot', 'delivery-window-finder']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO ConsumeLocal --
# ['covid19', 'covid-19', 'business', 'directory', 'mexico', 'coronavirus', 'helper-tool', 'help', 'restaurant', 'restaurants', 'local-business', 'groceries', 'localization', 'directorio', 'negocio', 'ayuda', 'negocios', 'local', 'personas', 'mapa']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO pepp-pt-documentation --
# ['documentation', 'contact-tracing', 'covid-19', 'coronavirus', 'pepp-pt']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Interactive-SIRmodel-UI --
# ['sir-model', 'covid-19', 'pygame-application', 'coronavirus', 'seir-model', 'herd-immunity', 'python', 'epidemic-simulations', 'pandemic-simulator']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Microbiology --
# ['microbiology', 'norovirus', 'coronavirus', 'infectious-diseases']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO ios --
# ['ios', 'swift', 'beacon', 'covid-19', 'coronavirus', 'co-living', 'community', 'share-house', 'guest-house', 'realtime', 'realtime-counter', 'kitchen-counter', 'utility', 'utilities', 'new', 'swiftui', 'swift-learning', 'bluetooth', 'bluetooth-low-energy', 'ibeacon']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Social-Distancing-Detector --
# ['python', 'opencv', 'yolov3', 'computer-vision', 'convolutional-neural-networks', 'deep-learning', 'social-distancing', 'social-distancing-detection', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Voice-distinguisher --
# ['audio-analysis', 'audio-processing', 'librosa', 'machine-learning', 'scikit-learn', 'pandas-python', 'coronavirus', 'coronavirus-tracking', 'knn-classification', 'knn-algorithm', 'knn-classifier', 'knn-python', 'voice-distinguisher', 'feature-extractor', 'classifier', 'voice', 'voice-classfication', 'voice-classifier', 'audio-classification', 'ml-sound-classifier']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO collecting-images --
# ['covid-19', 'dataset', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO contagio-pandemia --
# ['javascript', 'coronavirus', 'distributed-systems', 'simulation']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Automated-Social-Distancing-Monitoring --
# ['computer-vision', 'covid-19', 'social-distancing', 'social-distance-monitoring', 'coronavirus-tracking', 'object-detection', 'deep-learning', 'yolov3', 'coronavirus', 'detector', 'distance', 'camera']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Rehoboam-UI --
# ['reheboam', 'westworld', 'divergence', 'ui', 'ai', 'javascript', 'react', 'svg', 'canvas', 'interface', 'coronavirus', 'critical', 'events']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Amazon-Fresh-Whole-Foods-delivery-slot-finder-Multi-OS --
# ['coronavirus', 'grocery-delivery', 'amazon-fresh', 'amazon-fresh-services', 'food-delivery', 'wholefoods', 'delivery-slots', 'amazon', 'whole-foods', 'automation', 'script', 'windows', 'microsoft', 'apple', 'mac', 'delivery-window-finder', 'notification', 'cart', 'firefox-script', 'chrome']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO emergency-ventilator --
# ['covid-19', 'emergency-ventilator', 'ventilator', 'coronavirus', 'ambu-bag']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Quarantine4Kids --
# ['kids', 'quarantine', 'coronavirus', 'education', 'pandemic', 'art', 'crafts', 'reading', 'college']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO May-LeetCoding-Challenge --
# ['leetcode', 'may-leetcoding-challenge', 'coding-challenge', 'leetcoding', 'leetcode-cpp', 'leetcode-solutions', 'covid-19', 'covid', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO May-LeetCoding-Challenge --
# ['leetcode', 'leetcode-golang', 'leetcode-solutions', 'leetcode-practice', 'cpp', 'golang', 'mayleetcodechallenge', 'may-leetcoding-challenge', '30-days-of-code', '30dayscodechallenge', 'coding-challenge', 'leetcoding', 'covid-19', 'covid', 'coronavirus', 'leetcode-questions', 'lockdown', 'daily-coding-challenge']
# Esperando 0,5 segundos...
#  -- OBTENIENDO TOPICS DEL REPOSITORIO 6-ft-apart --
# ['greenfoot', 'java', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO M5Stack_Healthy_code_tracer --
# ['m5stack', 'micropython', 'arduino', 'onenet', 'uiflow', 'maixpy', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO OKorona --
# ['coronavirus', 'javascript', 'nodejs', 'mapbox-gl', 'api', 'covid19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO ProximityApp --
# ['coronavirus', 'mobile']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO not-busy-backend --
# ['covid', 'covid-19', 'coronavirus', 'express', 'node', 'typescript']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO not-busy-frontend --
# ['covid-19', 'covid19', 'coronavirus', 'businesses', 'popularity', 'wait-times']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO software-donation --
# ['covid-19', 'coronavirus', 'remote', 'remote-work', 'donating', 'donation', 'donations-list-website', 'covid-virus', 'covid-data', 'remote-working']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO 599c-kepler --
# ['coronavirus', 'hongkong', 'kepler-gl', 'visualization']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO LiveTwitterSentimentAnalysis --
# ['tweets', 'twitter-api', 'twitter-sentiment-analysis', 'textblob-sentiment-analysis', 'vader-sentiment-analysis', 'kafka', 'apache-kafka', 'kafka-streams', 'spark-streaming', 'kafka-producer-consumer', 'elasticsearch', 'zookeeper', 'kibana', 'kibana-visualization', 'big-data-analytics', 'live-tweets', 'sentiment-analysis', 'kafka-topic', 'trump-tweets', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO rkisteckbrief_versions --
# ['coronavirus', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO OWL-to-AIML --
# ['aiml', 'aiml-bots', 'owl', 'rdf', 'pandora', 'swrl', 'sparql', 'sparql-query', 'aiml-interpreter', 'aiml-parser', 'aiml-chatbot', 'aiml-converter', 'aiml-java-interpreter', 'aiml-files', 'aiml2', 'protege', 'protege-owl-editor', 'ontology', 'coronavirus', 'twinkle']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO CORD19-Geolocation-Pipeline --
# ['geolocation', 'covid19', 'cord19', 'elasticsearch', 'bert', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO WWDC2020 --
# ['swift', 'ios', 'apple', 'swift-playgrounds', 'wwdc', 'wwdc-scholarship', 'swift-student-challenge', 'wwdc20', 'coronavirus', 'simulation']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO cycling_to_work --
# ['coronavirus', 'cycling', 'transport', 'shareddataunit']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO swiss_counter_data --
# ['scraper', 'python3', 'zurich', 'switzerland', 'coronavirus-tracking', 'covid19-data', 'coronavirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO sistema-cofre --
# ['hacking', 'hacking-rio', 'hacking-help', 'cluster', 'logistica', 'segundo-lugar', 'segundo', 'competicao', 'covid-19', 'covid', 'coronavirus', 'coronavirus-logistica']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO c19_research --
# ['r', 'coronavirus', 'rmarkdown']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO biomath --
# ['coronavirus', 'mathematical-modelling', 'ode', 'abm', 'python', 'julia']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO WashHandsReminder --
# ['reminder-application', 'reminder', 'alarmmanager', 'livedata', 'viewmodel', 'coronavirus', 'wash', 'alarm', 'alarm-manager']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Social-Distance-Using-TensorFlow-API-Object --
# ['tensorflow', 'coronavirus', 'coronavirus-tracking', 'social-distance', 'python']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Simulaciones-de-epidemias --
# ['shiny-r', 'app', 'r', 'simulations', 'epidemia', 'epidemics', 'agent-based-simulation', 'population-dynamics', 'population-epidemics', 'biological-simulations', 'randomness', 'simulaciones-de-epidemias', 'pandemic', 'homogenous-mix', 'machine-learning', 'biological-simulation', 'population', 'covid', 'population-model', 'agentes']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Tidal-Bot --
# ['bot', 'discord', 'python', 'discordpy', 'music', 'stats', 'feedback', 'utility', 'information', 'covid', 'matplotlib']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO endofworld --
# ['earth', 'echarts', 'webgl', 'web-gl', 'echarts4', 'covid-19', 'covid-data', 'flu', 'influenza', 'covid', 'google-earth', 'echarts-gl', 'wuhan', 'globe', 'incident', 'global', 'war', 'doomsday']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO CMDC.jl --
# ['covid-19', 'data', 'api', 'api-client', 'covid19', 'covid', 'covid-data', 'covid19-data']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO TCC-EngBio2020 --
# ['ia', 'django', 'models', 'brats', 'cnn', 'unet', 'lndb', 'covid']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Maldito2020 --
# ['netflix', 'idea', 'html', 'css', 'javascript', 'serie', 'inspiration', 'covid']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO SWFT --
# ['covid', 'covid-19', 'labplanning', 'scheduling']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO codeforacause --
# ['covid', 'challenge', 'website', 'expressjs']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO data-scientist-examples --
# ['pandas', 'csv', 'xlsx', 'covid', 'sisa', 'urllib3', 'numpy', 'matplotlib', 'matplotlib-pyplot']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO exposure-keys --
# ['tek', 'temporary', 'exposure', 'keys', 'google', 'apple', 'corona', 'covid', 'covid19', 'covid-19', 'typescript', 'exposure-keys']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO en-i13n --
# ['exposure-notification', 'frida', 'covid-19', 'exposure-notifications', 'covid']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO resop --
# ['ngo', 'symfony', 'redcross', 'nonprofit', 'emergency-response', 'covid19', 'covid']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO simple-cvd19-monitor --
# ['bot', 'covid', 'covid-19-bot', 'telegram-bot']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO connecting-the-village --
# ['kids', 'covid', 'co-op', 'familes', 'social', 'friends', 'child', 'children', 'parents', 'communication', 'honest', 'framework']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO APIs --
# ['api', 'rest-api', 'flask', 'python3', 'covid', 'wiki', 'api-service']
# ...
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO CatInABox --
# ['flutter', 'transport', 'cats', 'covid-19', 'euvsvirus']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO ToVaccineOrNotToVaccine --
# ['nlp', 'covid-19', 'vaccine', 'tweets', 'zindi', 'pytorch', 'huggingface-transformers']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO springer-free-textbooks-downloader --
# ['ebook', 'free-download', 'springer', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO exp-notif-crypto --
# ['golang', 'contact-tracing', 'crypto', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO tohuwabohu --
# ['typescript', 'react', 'meteor', 'styled-components', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO public --
# ['covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO stay_home_polls_app --
# ['flutter', 'firebase', 'firestore', 'covid-19', 'stay-home', 'voted-polls']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Venta-max-ventilator --
# ['ventilator', 'arduino', 'avr', 'cad', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO flatten-the-curve --
# ['simulation', 'curve', 'covid-19', 'social-distancing', 'clojure', 'python']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Support-Notes-For-Frontliners-GUI --
# ['covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO traceprivately-server --
# ['swift', 'ios', 'apple', 'vapor-4', 'vapor', 'vapor-swift', 'covid-19', 'contact-tracing']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO spinger_free --
# ['scrapy', 'python', 'asyncio', 'covid-19', 'springer-book', 'freebooks']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO FoldingInTheCloud --
# ['foldingathome', 'pulumi', 'aws', 'aws-lambda', 'spot-instances', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO RainbowMaker --
# ['graphics-programming', 'processing', 'learn-to-code', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO MaskTrackingForTurkey --
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO tutorials --
# ['python', 'tutorials', 'codewars', 'arduino', 'stepik', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO AttendanceBot --
# ['selenium', 'bot', 'attendance', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Sobre-o-Hackathon --
# ['covid-19', 'health', 'hackathon', 'unb', '2020', 'hackathon-unb-fga-2020', 'solucoes', 'technology']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO tribute.page --
# ['tribute', 'tribute-page', 'html5', 'css', 'covid-19', 'warriors']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO connectedharmony --
# ['music', 'choir', 'virtualchoir', 'multi-track', 'multi-track-audio', 'recording', 'recording-app', 'corona', 'covid-19', 'webapp']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO greenpoint-face-shields --
# ['brooklyn', '3d-printing', 'diy', 'face-shields', 'covid-19', 'greenpoint', 'new-york', 'nyc']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO VirtQueue --
# ['social-distancing', 'queueing', 'virtual-queue', 'virtualqueue', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Cerberus-Multivent --
# ['ventilation', 'medicine', 'medical-device', 'covid-19', 'toronto']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO CCCSL-Codes --
# ['non-pharmaceutical-interventions', 'complexity-science-hub', 'npi', 'covid-19', 'codes', 'visualization', 'clustering', 'heatmap', 'cccsl']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO exposure-notifications-android --
# ['android', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Toilet-Paper-Calculator --
# ['toiletpaper-calculator', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO kemenu --
# ['angular', 'spring-boot', 'mongodb', 'java14', 'covid-19', 'menubar', 'menu', 'webapp']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO room-similarity --
# ['covid-19', 'buildings', 'architecture', 'similarity-measures']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO ospapr --
# ['covid-19', 'papr-respirator', 'papr', 'ppe']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Parcha --
# ['covid-19', 'social-distancing', 'token-system', 'flutter-app', 'nodejs-server-api', 'market', 'grocery-shops']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO FANNY-geolocation-simulator --
# ['vuejs', 'nuxtjs', 'leaflet', 'openstreetmap', 'vuetify', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO SDE-SIS-Model --
# ['modelling', 'epidemiology', 'stochastic-differential-equations', 'covid-19', 'south-africa']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO IQ-Home --
# ['flutter', 'covid-19', 'codeforiraq']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO dicom-analyzer --
# ['dicom', 'python', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO meet --
# ['fintech', 'dashboard', 'expense-tracker', 'covid-19', 'marqeta-python-sdk', 'marqeta', 'marqeta-hackathon', 'python', 'flask', 'bootstrap', 'website', '1st-place']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO sonification-bela --
# ['air-pollution-levels', 'belaplatform', 'covid-19', 'sonification', 'bach']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO iiitm_student_tracker --
# ['covid-19', 'covid19-studend-tracker', 'visulaization', 'india-map']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO SMK-Coding-Project_2 --
# ['covid-19', 'android-studio', 'kotlin-android', 'mpchart', 'retrofit2', 'shimmer-android', 'smk-coding', 'firebase-auth', 'firebase-realtime-database', 'room-persistence-library']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO cohack2 --
# ['covid-19', 'cohack', 'fly2']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO workdico-peoplecounter --
# ['computer-vision', 'covid-19', 'jupyter-notebook', 'python', 'opencv']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Project-Euler --
# ['golang', 'algorithms', 'math', 'covid-19', 'isolation', 'quarantine-project', 'python', 'java']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO vsc-web-technology --
# ['covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO CHIME-2 --
# ['covid-19', 'flask', 'data-science', 'code-for-philly']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO ShopinTine --
# ['ibm', 'ibm-watson', 'covid-19', 'hackathon']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Electricity-Data-Pipeline --
# ['electricity', 'elexon', 'bmrs', 'api', 'covid-19', 'energy', 'britain', 'electricity-systems']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO tenancy-renewal-app --
# ['hdb', 'covid-19', 'covid-19-idea-sprint', 'govtech', 'flask']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Back2Work --
# ['powerapps', 'powerautomate', 'covid-19', 'coronavirus-tracking', 'powerplatform', 'sharepoint-online']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO comoTH --
# ['mathematical', 'modelling', 'covid-19', 'thailand']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO apoiarsaude --
# ['covid-19', 'psychotherapy']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO web-app-v2 --
# ['angular', 'firebase', 'covid-19', 'iisc']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO project-tracer --
# ['esp32', 'esp-idf', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO villa-maria-verde --
# ['geodata', 'rstats', 'visualization', 'covid-19', 'argentina']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO DataMap --
# ['datamaps', 'python', 'excel', 'excelmap', 'covid-19', 'worlddata']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Kaggle-Projects --
# ['eda', 'dataset', 'covid-19', 'folium', 'geopy', 'regression-models']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO NVIDIA_nano_AI --
# ['ai', 'covid-19', 'jetson-nano', 'tensorflow-examples', 'tensorflow-models', 'opencv-python', 'python', 'object-detection', 'humandetection']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO web-travel-cautions --
# ['travel', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO EpiMod --
# ['covid-19', 'inference', 'simulation', 'bayesian-inference', 'epidemiology']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO hello-deno --
# ['deno', 'typescript', 'covid-19', 'ci-cd']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO webcam-glass --
# ['webcam-streaming', 'webcam-capture', 'tool', 'video-streaming', 'video-recording', 'video-conferencing', 'screen-recorder', 'screen-capture', 'electron', 'electron-app', 'p5js', 'awesome-electron', 'javascript', 'virtual-classroom', 'covid-19', 'vidrio', 'meetings', 'webcam-viewer', 'frameless', 'video']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Google-Girls-2020 --
# ['website', 'covid-19', 'nodejs']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO VisitContactTrace --
# ['covid-19', 'contact-tracing-app', 'contact-trace', 'infectious-diseases', 'nurse', 'essential-w', 'home-healthcare', 'visit-staff', 'staff-members', 'visitcontacttrace-application', 'patients', 'disease']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO esop --
# ['machine-learning', 'covid-19', 'lockdown', 'bayesian-optimization', 'optimal-control', 'epidemiological-predictions']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO GAEN_Explorer --
# ['exposure-notification', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Fabric --
# ['education', 'socketio', 'flask', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Tentor-Task-Day9 --
# ['javascript', 'covid-19', 'api', 'jquery']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Social-Distancing-Detector --
# ['arduino-uno', 'tinkercad', 'social-distancing-detection', 'covid-19', 'ultrasonic-sensor', 'buzzer', 'buzzertune']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO RyujinBot --
# ['discord', 'bot', 'moderation', 'anime', 'discordbot', 'discordjs', 'logging', 'fun', 'music-player', 'games', 'api', 'github', 'npm', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Lives-de-Ciencia --
# ['lives-de-ciencia', 'ciencia', 'science-vlogs-brasil', 'covid-19', 'paleontologia', 'psicologia', 'youtube', 'biologia', 'astronomia', 'economia', 'fake-news', 'geografia', 'meio-ambiente']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Mask-Wearing-Identification --
# ['yolo', 'yolov3', 'mfc', 'darknet53', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO geo-heatmap-android --
# ['worldmap', 'heatmap', 'android-application', 'covid-19', 'kotlin-android', 'data-visualization', 'map-heatmap-android', 'geo-heatmap']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO REMOTE-EDUCATION-APP---EMAGISTER --
# ['android', 'android-application', 'online-classroom', 'video-conferencing', 'covid-19', 'classroom', 'online-invigilator', 'secure-examination-environment', 'chat', 'chat-room-android', 'assignment-submission-system', 'appointment-management-system', 'appointment-scheduling', 'education', 'teachers', 'video', 'invigilate-students', 'blocking-students']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Data-Analysis-Projects --
# ['data-visualization', 'data-analysis', 'covid-19', 'text-analysis', 'seaborn', 'matplo', 'plotly', 'cufflinks', 'python']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO indus-web --
# ['covid-19', 'digital-transformation', 'industry-40', 'serverless', 'firebase', 'react']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Chem-Faiss --
# ['deep-learning', 'neural-network', 'machine-learning', 'cheminformatics', 'bioinformatics', 'covid-19', 'faiss', 'facebook', 'rdkit']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO immuni-backend-common --
# ['python', 'sanic', 'celery', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO immuni-backend-otp --
# ['python', 'webserver', 'sanic', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO immuni-backend-exposure-ingestion --
# ['python', 'webserver', 'sanic', 'celery', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO immuni-backend-exposure-reporting --
# ['python', 'webserver', 'sanic', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO rare-tijden --
# ['browser-extension', 'covid-19', 'funny', 'humor']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO should-i-wear-a-mask.github.io --
# ['covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Using-real-world-contact-networks-to-quantify-the-effectiveness-of-digital-contact-tracing --
# ['covid-19', 'digital-contact-tracing', 'social-network-analysis', 'contact-tracing', 'contact-tracing-app', 'coronavirus-tracking', 'exposure-notification', 'sars-cov-2']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO indus-mobile --
# ['covid-19', 'react-native', 'serverless', 'firebase', 'digital-transformation', 'industry-40']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO FHIR2Dataset --
# ['fhir', 'ai', 'machine-learning', 'covid-19', 'sql']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO MozillaOpenLab --
# ['mozilla-open-lab', 'website', 'flask-application', 'machine-learning', 'full-stack-web-development', 'python3', 'naive-bayes-classifier', 'naive-bayes-classification', 'donations-list-website', 'donation-api', 'covid-19', 'nltk-python', 'nlp', 'beautifulsoup4', 'javascript', 'bootstrap', 'css', 'twitter-api', 'sklearn', 'pandas']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO hetcheckgesprek --
# ['covid-19', 'checkgesprek', 'gezondheidscheck', 'rivm', 'privacy-protection']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO project-thea-website --
# ['covid-19', 'project-thea']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Kotlin30Days --
# ['kotlin30days', 'android', 'covid-19', 'coroutines']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO meteor-emails --
# ['meteor', 'sendgrid', 'cold-emails', 'nodejs', 'sales', 'covid-19', 'statistics', 'bootstrap4', 'salesflare']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO Annona --
# ['nasa', 'spaceapps', 'esa', 'jaxa', 'cnes', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO pikobar-donasi-api --
# ['covid-19', 'pikobar']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO iot-contact-tracer --
# ['contact-tracing', 'covid-19', 'iot', 'smartphone']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO jupyter --
# ['jupyterlab', 'jupyterhub', 'covid-19']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO OpenWeatherMap-concat-histories --
# ['eosc', 'eosc-secretariat', 'openweathermap-api', 'openweathermap-cities', 'belgium', 'covid-19', 'universite-libre-de-bruxelles']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO frontend --
# ['covid-19', 'qrcode', 'frontend']
# Esperando 0,5 segundos...
#
#
#  -- OBTENIENDO TOPICS DEL REPOSITORIO backend --
# ['covid-19', 'qrcode', 'rust', 'backend', 'covid-journal']
# Esperando 0,5 segundos...

# %%
df_topics
# Out:
#                id                                             topics
# 79      229502804  [datavisualization, python3, covid-19, dashbor...
# 140     141635301  [iot, water-monitoring, jquery, javascript, ar...
# 157     237388368  [red-cross, github-pages, coronavirus, covid-1...
# 458     170732312  [limnoria, irc, ascii-art, jeopardy, uno, inte...
# 842     155705971  [mongodb, nodejs, api, apirest, javascript, gr...
# ...           ...                                                ...
# 178062  268856502       [contact-tracing, covid-19, iot, smartphone]
# 178063  269479371                 [jupyterlab, jupyterhub, covid-19]
# 178065  269527538  [eosc, eosc-secretariat, openweathermap-api, o...
# 178068  270013759                       [covid-19, qrcode, frontend]
# 178069  270006438   [covid-19, qrcode, rust, backend, covid-journal]
#
# [1347 rows x 2 columns]

# %% [markdown]
# Exportamos el resultado a CSV:

# %%
df_topics.to_csv(r'repositorios_restantes_con_topics.csv', index = False, encoding="utf-8-sig")

# %% [markdown]
# Lo leemos:

# %%
df_topics = pd.read_csv('repositorios_restantes_con_topics.csv')
df_topics
# Out:
#                id                                             topics
# 0     229502804.0  ['datavisualization', 'python3', 'covid-19', '...
# 1     141635301.0  ['iot', 'water-monitoring', 'jquery', 'javascr...
# 2     237388368.0  ['red-cross', 'github-pages', 'coronavirus', '...
# 3     170732312.0  ['limnoria', 'irc', 'ascii-art', 'jeopardy', '...
# 4     155705971.0  ['mongodb', 'nodejs', 'api', 'apirest', 'javas...
# ...           ...                                                ...
# 1342  268856502.0  ['contact-tracing', 'covid-19', 'iot', 'smartp...
# 1343  269479371.0           ['jupyterlab', 'jupyterhub', 'covid-19']
# 1344  269527538.0  ['eosc', 'eosc-secretariat', 'openweathermap-a...
# 1345  270013759.0                 ['covid-19', 'qrcode', 'frontend']
# 1346  270006438.0  ['covid-19', 'qrcode', 'rust', 'backend', 'cov...
#
# [1347 rows x 2 columns]

# %% [markdown]
# El campo *id* se ha guardado como *float*. Lo convertimos a *int*:

# %%
df_topics.id = df_topics.id.astype(int)
df_topics
# Out:
#              id                                             topics
# 0     229502804  ['datavisualization', 'python3', 'covid-19', '...
# 1     141635301  ['iot', 'water-monitoring', 'jquery', 'javascr...
# 2     237388368  ['red-cross', 'github-pages', 'coronavirus', '...
# 3     170732312  ['limnoria', 'irc', 'ascii-art', 'jeopardy', '...
# 4     155705971  ['mongodb', 'nodejs', 'api', 'apirest', 'javas...
# ...         ...                                                ...
# 1342  268856502  ['contact-tracing', 'covid-19', 'iot', 'smartp...
# 1343  269479371           ['jupyterlab', 'jupyterhub', 'covid-19']
# 1344  269527538  ['eosc', 'eosc-secretariat', 'openweathermap-a...
# 1345  270013759                 ['covid-19', 'qrcode', 'frontend']
# 1346  270006438  ['covid-19', 'qrcode', 'rust', 'backend', 'cov...
#
# [1347 rows x 2 columns]

# %% [markdown]
# Repositorios que no tienen *topics*:

# %%
df_topics.topics.isnull().sum()
# Out:
# 4

# %% [markdown]
# Unimos este dataframe con el que tiene todo el contenido de los repositorios:

# %%
df_not_in_description_new = df_not_in_description.join(df_topics.set_index('id'), on='id')
df_not_in_description_new
# Out:
#                id                             name  \
# 79      229502804       data-visualisation-scripts
# 140     141635301          Water-Monitoring-System
# 157     237388368                        red-cross
# 458     170732312                 limnoria-plugins
# 842     155705971                  alm-api-backend
# ...           ...                              ...
# 178062  268856502               iot-contact-tracer
# 178063  269479371                          jupyter
# 178065  269527538  OpenWeatherMap-concat-histories
# 178068  270013759                         frontend
# 178069  270006438                          backend
#
#                                      full_name  \
# 79       Perishleaf/data-visualisation-scripts
# 140       vinitshahdeo/Water-Monitoring-System
# 157                       WeileiZeng/red-cross
# 458                   oddluck/limnoria-plugins
# 842                     Beor18/alm-api-backend
# ...                                        ...
# 178062                 fwcd/iot-contact-tracer
# 178063                           kclhi/jupyter
# 178065  ALT-F1/OpenWeatherMap-concat-histories
# 178068                        Tackode/frontend
# 178069                         Tackode/backend
#
#                                               description  \
# 79      Collection of scripts for data visualisation a...
# 140     Water Monitoring System is an IOT based Liquid...
# 157                                              官方公示数据概览
# 458                   Limnoria plugins I wrote or forked.
# 842     Comenzo como desafio almundo.com y ahora estoy...
# ...                                                   ...
# 178062  Decentralized contact tracing system supportin...
# 178063           :whale2: JupyterHub Docker configuration
# 178065  Concatenate histories weather data collected b...
# 178068                               Frontend for Tackode
# 178069                                Backend for Tackode
#
#                                          contributors_url  archived  disabled  \
# 79      https://api.github.com/repos/Perishleaf/data-v...     False     False
# 140     https://api.github.com/repos/vinitshahdeo/Wate...     False     False
# 157     https://api.github.com/repos/WeileiZeng/red-cr...     False     False
# 458     https://api.github.com/repos/oddluck/limnoria-...     False     False
# 842     https://api.github.com/repos/Beor18/alm-api-ba...     False     False
# ...                                                   ...       ...       ...
# 178062  https://api.github.com/repos/fwcd/iot-contact-...     False     False
# 178063  https://api.github.com/repos/kclhi/jupyter/con...     False     False
# 178065  https://api.github.com/repos/ALT-F1/OpenWeathe...     False     False
# 178068  https://api.github.com/repos/Tackode/frontend/...     False     False
# 178069  https://api.github.com/repos/Tackode/backend/c...     False     False
#
#         stargazers_count  watchers_count  forks_count  ...  has_wiki  \
# 79                    80              80           90  ...      True
# 140                  128             128          245  ...      True
# 157                   19              19            4  ...      True
# 458                   33              33            8  ...      True
# 842                   11              11            2  ...      True
# ...                  ...             ...          ...  ...       ...
# 178062                 1               1            0  ...      True
# 178063                 2               2            0  ...      True
# 178065                 1               1            0  ...      True
# 178068                 0               0            0  ...      True
# 178069                 0               0            0  ...      True
#
#                                                  homepage  \
# 79                                                    NaN
# 140     https://vinitshahdeo.github.io/Water-Monitorin...
# 157               https://weileizeng.github.io/red-cross/
# 458                                                   NaN
# 842     https://almundo-examen.herokuapp.com/api/v1/ho...
# ...                                                   ...
# 178062                                                NaN
# 178063                                  https://kclhi.org
# 178065                               http://www.alt-f1.be
# 178068                                https://tackode.com
# 178069                                https://tackode.com
#
#                                                  html_url          language  \
# 79      https://github.com/Perishleaf/data-visualisati...  Jupyter Notebook
# 140     https://github.com/vinitshahdeo/Water-Monitori...              HTML
# 157               https://github.com/WeileiZeng/red-cross            Python
# 458           https://github.com/oddluck/limnoria-plugins            Python
# 842             https://github.com/Beor18/alm-api-backend        JavaScript
# ...                                                   ...               ...
# 178062         https://github.com/fwcd/iot-contact-tracer              Dart
# 178063                   https://github.com/kclhi/jupyter            Python
# 178065  https://github.com/ALT-F1/OpenWeatherMap-conca...            Python
# 178068                https://github.com/Tackode/frontend               Vue
# 178069                 https://github.com/Tackode/backend              Rust
#
#                   created_at             pushed_at            updated_at  \
# 79      2019-12-22T01:12:45Z  2020-08-06T12:06:03Z  2021-06-10T12:17:53Z
# 140     2018-07-19T22:06:05Z  2021-06-09T18:42:30Z  2021-08-06T15:01:36Z
# 157     2020-01-31T08:22:45Z  2021-07-13T07:01:42Z  2020-05-27T05:59:00Z
# 458     2019-02-14T17:40:29Z  2021-06-23T19:44:25Z  2021-08-14T00:12:47Z
# 842     2018-11-01T11:37:25Z  2020-07-13T22:22:44Z  2020-09-20T03:56:50Z
# ...                      ...                   ...                   ...
# 178062  2020-06-02T16:46:15Z  2020-09-04T13:14:05Z  2020-09-04T15:03:54Z
# 178063  2020-06-04T22:35:16Z  2021-06-11T18:23:39Z  2021-08-14T14:32:53Z
# 178065  2020-06-05T04:04:46Z  2021-08-12T13:30:11Z  2020-06-08T12:44:27Z
# 178068  2020-06-06T14:57:50Z  2021-08-12T04:05:02Z  2021-01-11T08:38:35Z
# 178069  2020-06-06T14:30:13Z  2021-08-13T04:03:31Z  2021-05-26T08:44:01Z
#
#                                                   svn_url   owner.login  \
# 79      https://github.com/Perishleaf/data-visualisati...    Perishleaf
# 140     https://github.com/vinitshahdeo/Water-Monitori...  vinitshahdeo
# 157               https://github.com/WeileiZeng/red-cross    WeileiZeng
# 458           https://github.com/oddluck/limnoria-plugins       oddluck
# 842             https://github.com/Beor18/alm-api-backend        Beor18
# ...                                                   ...           ...
# 178062         https://github.com/fwcd/iot-contact-tracer          fwcd
# 178063                   https://github.com/kclhi/jupyter         kclhi
# 178065  https://github.com/ALT-F1/OpenWeatherMap-conca...        ALT-F1
# 178068                https://github.com/Tackode/frontend       Tackode
# 178069                 https://github.com/Tackode/backend       Tackode
#
#                                                    topics
# 79      ['datavisualization', 'python3', 'covid-19', '...
# 140     ['iot', 'water-monitoring', 'jquery', 'javascr...
# 157     ['red-cross', 'github-pages', 'coronavirus', '...
# 458     ['limnoria', 'irc', 'ascii-art', 'jeopardy', '...
# 842     ['mongodb', 'nodejs', 'api', 'apirest', 'javas...
# ...                                                   ...
# 178062  ['contact-tracing', 'covid-19', 'iot', 'smartp...
# 178063           ['jupyterlab', 'jupyterhub', 'covid-19']
# 178065  ['eosc', 'eosc-secretariat', 'openweathermap-a...
# 178068                 ['covid-19', 'qrcode', 'frontend']
# 178069  ['covid-19', 'qrcode', 'rust', 'backend', 'cov...
#
# [1347 rows x 24 columns]

# %%
df_not_in_description_new.topics.isnull().sum()
# Out:
# 4

# %%
show(df_not_in_description_new)
# Out:
# PandasGUI INFO — pandasgui.gui — Opening PandasGUI

# %% [markdown]
# Lo exportamos a CSV:

# %%
df_not_in_description_new.to_csv(r'repositorios_restantes_con_topics_filtrado.csv', index = False, encoding="utf-8-sig")

# %%
df_not_in_description_new = pd.read_csv('repositorios_restantes_con_topics_filtrado.csv')
df_not_in_description_new
# Out:
#              id                             name  \
# 0     229502804       data-visualisation-scripts
# 1     141635301          Water-Monitoring-System
# 2     237388368                        red-cross
# 3     170732312                 limnoria-plugins
# 4     155705971                  alm-api-backend
# ...         ...                              ...
# 1342  268856502               iot-contact-tracer
# 1343  269479371                          jupyter
# 1344  269527538  OpenWeatherMap-concat-histories
# 1345  270013759                         frontend
# 1346  270006438                          backend
#
#                                    full_name  \
# 0      Perishleaf/data-visualisation-scripts
# 1       vinitshahdeo/Water-Monitoring-System
# 2                       WeileiZeng/red-cross
# 3                   oddluck/limnoria-plugins
# 4                     Beor18/alm-api-backend
# ...                                      ...
# 1342                 fwcd/iot-contact-tracer
# 1343                           kclhi/jupyter
# 1344  ALT-F1/OpenWeatherMap-concat-histories
# 1345                        Tackode/frontend
# 1346                         Tackode/backend
#
#                                             description  \
# 0     Collection of scripts for data visualisation a...
# 1     Water Monitoring System is an IOT based Liquid...
# 2                                              官方公示数据概览
# 3                   Limnoria plugins I wrote or forked.
# 4     Comenzo como desafio almundo.com y ahora estoy...
# ...                                                 ...
# 1342  Decentralized contact tracing system supportin...
# 1343           :whale2: JupyterHub Docker configuration
# 1344  Concatenate histories weather data collected b...
# 1345                               Frontend for Tackode
# 1346                                Backend for Tackode
#
#                                        contributors_url  archived  disabled  \
# 0     https://api.github.com/repos/Perishleaf/data-v...     False     False
# 1     https://api.github.com/repos/vinitshahdeo/Wate...     False     False
# 2     https://api.github.com/repos/WeileiZeng/red-cr...     False     False
# 3     https://api.github.com/repos/oddluck/limnoria-...     False     False
# 4     https://api.github.com/repos/Beor18/alm-api-ba...     False     False
# ...                                                 ...       ...       ...
# 1342  https://api.github.com/repos/fwcd/iot-contact-...     False     False
# 1343  https://api.github.com/repos/kclhi/jupyter/con...     False     False
# 1344  https://api.github.com/repos/ALT-F1/OpenWeathe...     False     False
# 1345  https://api.github.com/repos/Tackode/frontend/...     False     False
# 1346  https://api.github.com/repos/Tackode/backend/c...     False     False
#
#       stargazers_count  watchers_count  forks_count  ...  has_wiki  \
# 0                   80              80           90  ...      True
# 1                  128             128          245  ...      True
# 2                   19              19            4  ...      True
# 3                   33              33            8  ...      True
# 4                   11              11            2  ...      True
# ...                ...             ...          ...  ...       ...
# 1342                 1               1            0  ...      True
# 1343                 2               2            0  ...      True
# 1344                 1               1            0  ...      True
# 1345                 0               0            0  ...      True
# 1346                 0               0            0  ...      True
#
#                                                homepage  \
# 0                                                   NaN
# 1     https://vinitshahdeo.github.io/Water-Monitorin...
# 2               https://weileizeng.github.io/red-cross/
# 3                                                   NaN
# 4     https://almundo-examen.herokuapp.com/api/v1/ho...
# ...                                                 ...
# 1342                                                NaN
# 1343                                  https://kclhi.org
# 1344                               http://www.alt-f1.be
# 1345                                https://tackode.com
# 1346                                https://tackode.com
#
#                                                html_url          language  \
# 0     https://github.com/Perishleaf/data-visualisati...  Jupyter Notebook
# 1     https://github.com/vinitshahdeo/Water-Monitori...              HTML
# 2               https://github.com/WeileiZeng/red-cross            Python
# 3           https://github.com/oddluck/limnoria-plugins            Python
# 4             https://github.com/Beor18/alm-api-backend        JavaScript
# ...                                                 ...               ...
# 1342         https://github.com/fwcd/iot-contact-tracer              Dart
# 1343                   https://github.com/kclhi/jupyter            Python
# 1344  https://github.com/ALT-F1/OpenWeatherMap-conca...            Python
# 1345                https://github.com/Tackode/frontend               Vue
# 1346                 https://github.com/Tackode/backend              Rust
#
#                 created_at             pushed_at            updated_at  \
# 0     2019-12-22T01:12:45Z  2020-08-06T12:06:03Z  2021-06-10T12:17:53Z
# 1     2018-07-19T22:06:05Z  2021-06-09T18:42:30Z  2021-08-06T15:01:36Z
# 2     2020-01-31T08:22:45Z  2021-07-13T07:01:42Z  2020-05-27T05:59:00Z
# 3     2019-02-14T17:40:29Z  2021-06-23T19:44:25Z  2021-08-14T00:12:47Z
# 4     2018-11-01T11:37:25Z  2020-07-13T22:22:44Z  2020-09-20T03:56:50Z
# ...                    ...                   ...                   ...
# 1342  2020-06-02T16:46:15Z  2020-09-04T13:14:05Z  2020-09-04T15:03:54Z
# 1343  2020-06-04T22:35:16Z  2021-06-11T18:23:39Z  2021-08-14T14:32:53Z
# 1344  2020-06-05T04:04:46Z  2021-08-12T13:30:11Z  2020-06-08T12:44:27Z
# 1345  2020-06-06T14:57:50Z  2021-08-12T04:05:02Z  2021-01-11T08:38:35Z
# 1346  2020-06-06T14:30:13Z  2021-08-13T04:03:31Z  2021-05-26T08:44:01Z
#
#                                                 svn_url   owner.login  \
# 0     https://github.com/Perishleaf/data-visualisati...    Perishleaf
# 1     https://github.com/vinitshahdeo/Water-Monitori...  vinitshahdeo
# 2               https://github.com/WeileiZeng/red-cross    WeileiZeng
# 3           https://github.com/oddluck/limnoria-plugins       oddluck
# 4             https://github.com/Beor18/alm-api-backend        Beor18
# ...                                                 ...           ...
# 1342         https://github.com/fwcd/iot-contact-tracer          fwcd
# 1343                   https://github.com/kclhi/jupyter         kclhi
# 1344  https://github.com/ALT-F1/OpenWeatherMap-conca...        ALT-F1
# 1345                https://github.com/Tackode/frontend       Tackode
# 1346                 https://github.com/Tackode/backend       Tackode
#
#                                                  topics
# 0     ['datavisualization', 'python3', 'covid-19', '...
# 1     ['iot', 'water-monitoring', 'jquery', 'javascr...
# 2     ['red-cross', 'github-pages', 'coronavirus', '...
# 3     ['limnoria', 'irc', 'ascii-art', 'jeopardy', '...
# 4     ['mongodb', 'nodejs', 'api', 'apirest', 'javas...
# ...                                                 ...
# 1342  ['contact-tracing', 'covid-19', 'iot', 'smartp...
# 1343           ['jupyterlab', 'jupyterhub', 'covid-19']
# 1344  ['eosc', 'eosc-secretariat', 'openweathermap-a...
# 1345                 ['covid-19', 'qrcode', 'frontend']
# 1346  ['covid-19', 'qrcode', 'rust', 'backend', 'cov...
#
# [1347 rows x 24 columns]

# %% [markdown]
# Comprobamos cuántos repositorios tienen en sus topics palabras relacionadas:

# %%
df_not_in_description_new_boolean = df_not_in_description_new.topics.str.contains(pattern_description)
df_not_in_description_new_boolean
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1342    True
# 1343    True
# 1344    True
# 1345    True
# 1346    True
# Name: topics, Length: 1347, dtype: object

# %% [markdown]
# Vemos cuántos son:

# %%
df_not_in_description_new_boolean.sum()
# Out:
# 1343

# %%
df_not_in_description_new_filtrado = df_not_in_description_new[df_not_in_description_new_boolean.fillna(False)]
df_not_in_description_new_filtrado.shape[0]
# Out:
# 1343

# %%
df_not_in_description_new_filtrado
# Out:
#              id                             name  \
# 0     229502804       data-visualisation-scripts
# 1     141635301          Water-Monitoring-System
# 2     237388368                        red-cross
# 3     170732312                 limnoria-plugins
# 4     155705971                  alm-api-backend
# ...         ...                              ...
# 1342  268856502               iot-contact-tracer
# 1343  269479371                          jupyter
# 1344  269527538  OpenWeatherMap-concat-histories
# 1345  270013759                         frontend
# 1346  270006438                          backend
#
#                                    full_name  \
# 0      Perishleaf/data-visualisation-scripts
# 1       vinitshahdeo/Water-Monitoring-System
# 2                       WeileiZeng/red-cross
# 3                   oddluck/limnoria-plugins
# 4                     Beor18/alm-api-backend
# ...                                      ...
# 1342                 fwcd/iot-contact-tracer
# 1343                           kclhi/jupyter
# 1344  ALT-F1/OpenWeatherMap-concat-histories
# 1345                        Tackode/frontend
# 1346                         Tackode/backend
#
#                                             description  \
# 0     Collection of scripts for data visualisation a...
# 1     Water Monitoring System is an IOT based Liquid...
# 2                                              官方公示数据概览
# 3                   Limnoria plugins I wrote or forked.
# 4     Comenzo como desafio almundo.com y ahora estoy...
# ...                                                 ...
# 1342  Decentralized contact tracing system supportin...
# 1343           :whale2: JupyterHub Docker configuration
# 1344  Concatenate histories weather data collected b...
# 1345                               Frontend for Tackode
# 1346                                Backend for Tackode
#
#                                        contributors_url  archived  disabled  \
# 0     https://api.github.com/repos/Perishleaf/data-v...     False     False
# 1     https://api.github.com/repos/vinitshahdeo/Wate...     False     False
# 2     https://api.github.com/repos/WeileiZeng/red-cr...     False     False
# 3     https://api.github.com/repos/oddluck/limnoria-...     False     False
# 4     https://api.github.com/repos/Beor18/alm-api-ba...     False     False
# ...                                                 ...       ...       ...
# 1342  https://api.github.com/repos/fwcd/iot-contact-...     False     False
# 1343  https://api.github.com/repos/kclhi/jupyter/con...     False     False
# 1344  https://api.github.com/repos/ALT-F1/OpenWeathe...     False     False
# 1345  https://api.github.com/repos/Tackode/frontend/...     False     False
# 1346  https://api.github.com/repos/Tackode/backend/c...     False     False
#
#       stargazers_count  watchers_count  forks_count  ...  has_wiki  \
# 0                   80              80           90  ...      True
# 1                  128             128          245  ...      True
# 2                   19              19            4  ...      True
# 3                   33              33            8  ...      True
# 4                   11              11            2  ...      True
# ...                ...             ...          ...  ...       ...
# 1342                 1               1            0  ...      True
# 1343                 2               2            0  ...      True
# 1344                 1               1            0  ...      True
# 1345                 0               0            0  ...      True
# 1346                 0               0            0  ...      True
#
#                                                homepage  \
# 0                                                   NaN
# 1     https://vinitshahdeo.github.io/Water-Monitorin...
# 2               https://weileizeng.github.io/red-cross/
# 3                                                   NaN
# 4     https://almundo-examen.herokuapp.com/api/v1/ho...
# ...                                                 ...
# 1342                                                NaN
# 1343                                  https://kclhi.org
# 1344                               http://www.alt-f1.be
# 1345                                https://tackode.com
# 1346                                https://tackode.com
#
#                                                html_url          language  \
# 0     https://github.com/Perishleaf/data-visualisati...  Jupyter Notebook
# 1     https://github.com/vinitshahdeo/Water-Monitori...              HTML
# 2               https://github.com/WeileiZeng/red-cross            Python
# 3           https://github.com/oddluck/limnoria-plugins            Python
# 4             https://github.com/Beor18/alm-api-backend        JavaScript
# ...                                                 ...               ...
# 1342         https://github.com/fwcd/iot-contact-tracer              Dart
# 1343                   https://github.com/kclhi/jupyter            Python
# 1344  https://github.com/ALT-F1/OpenWeatherMap-conca...            Python
# 1345                https://github.com/Tackode/frontend               Vue
# 1346                 https://github.com/Tackode/backend              Rust
#
#                 created_at             pushed_at            updated_at  \
# 0     2019-12-22T01:12:45Z  2020-08-06T12:06:03Z  2021-06-10T12:17:53Z
# 1     2018-07-19T22:06:05Z  2021-06-09T18:42:30Z  2021-08-06T15:01:36Z
# 2     2020-01-31T08:22:45Z  2021-07-13T07:01:42Z  2020-05-27T05:59:00Z
# 3     2019-02-14T17:40:29Z  2021-06-23T19:44:25Z  2021-08-14T00:12:47Z
# 4     2018-11-01T11:37:25Z  2020-07-13T22:22:44Z  2020-09-20T03:56:50Z
# ...                    ...                   ...                   ...
# 1342  2020-06-02T16:46:15Z  2020-09-04T13:14:05Z  2020-09-04T15:03:54Z
# 1343  2020-06-04T22:35:16Z  2021-06-11T18:23:39Z  2021-08-14T14:32:53Z
# 1344  2020-06-05T04:04:46Z  2021-08-12T13:30:11Z  2020-06-08T12:44:27Z
# 1345  2020-06-06T14:57:50Z  2021-08-12T04:05:02Z  2021-01-11T08:38:35Z
# 1346  2020-06-06T14:30:13Z  2021-08-13T04:03:31Z  2021-05-26T08:44:01Z
#
#                                                 svn_url   owner.login  \
# 0     https://github.com/Perishleaf/data-visualisati...    Perishleaf
# 1     https://github.com/vinitshahdeo/Water-Monitori...  vinitshahdeo
# 2               https://github.com/WeileiZeng/red-cross    WeileiZeng
# 3           https://github.com/oddluck/limnoria-plugins       oddluck
# 4             https://github.com/Beor18/alm-api-backend        Beor18
# ...                                                 ...           ...
# 1342         https://github.com/fwcd/iot-contact-tracer          fwcd
# 1343                   https://github.com/kclhi/jupyter         kclhi
# 1344  https://github.com/ALT-F1/OpenWeatherMap-conca...        ALT-F1
# 1345                https://github.com/Tackode/frontend       Tackode
# 1346                 https://github.com/Tackode/backend       Tackode
#
#                                                  topics
# 0     ['datavisualization', 'python3', 'covid-19', '...
# 1     ['iot', 'water-monitoring', 'jquery', 'javascr...
# 2     ['red-cross', 'github-pages', 'coronavirus', '...
# 3     ['limnoria', 'irc', 'ascii-art', 'jeopardy', '...
# 4     ['mongodb', 'nodejs', 'api', 'apirest', 'javas...
# ...                                                 ...
# 1342  ['contact-tracing', 'covid-19', 'iot', 'smartp...
# 1343           ['jupyterlab', 'jupyterhub', 'covid-19']
# 1344  ['eosc', 'eosc-secretariat', 'openweathermap-a...
# 1345                 ['covid-19', 'qrcode', 'frontend']
# 1346  ['covid-19', 'qrcode', 'rust', 'backend', 'cov...
#
# [1343 rows x 24 columns]

# %% [markdown]
# Como vemos, todos los repositorios que no tenían palabras claves en el nombre ni en la descripción, tienen topics relacionados con la COVID-19.

# %% [markdown]
# ---

# %%
df_res_final
# Out:
#                id                          name  \
# 0       238316428                      COVID-19
# 1       235374822                      COVID-19
# 2       239777191                   coronavirus
# 3       237129709                   coronavirus
# 4       234936988                          ncov
# ...           ...                           ...
# 178037  267352452                steam-lockdown
# 178047  267575087            Smart-Food-Storage
# 178050  246130172                     Airplanes
# 178051  267858096  face_mask_detection_openvino
# 178067  269906994           face-mask-detection
#
#                                    full_name  \
# 0                    CSSEGISandData/COVID-19
# 1                     midas-network/COVID-19
# 2                    RamiKrispin/coronavirus
# 3                  FoldingAtHome/coronavirus
# 4                            nextstrain/ncov
# ...                                      ...
# 178037      digital-wellbeing/steam-lockdown
# 178047         m-boutaleb/Smart-Food-Storage
# 178050                   cgettings/Airplanes
# 178051  mmphego/face_mask_detection_openvino
# 178067    jahnavi-prasad/face-mask-detection
#
#                                               description  \
# 0       Novel Coronavirus (COVID-19) Cases, provided b...
# 1                       2019 novel coronavirus repository
# 2                                 The coronavirus dataset
# 3                           Folding@home COVID-19 efforts
# 4       Nextstrain build for novel coronavirus SARS-CoV-2
# ...                                                   ...
# 178037  How has gaming changed during lockdown? Analys...
# 178047  An intelligent application (very useful during...
# 178050  Visualizing flights into LGA at the start of t...
# 178051  Detect faces and determine whether people are ...
# 178067  Simple project to detect if a person is wearin...
#
#                                          contributors_url  archived  disabled  \
# 0       https://api.github.com/repos/CSSEGISandData/CO...     False     False
# 1       https://api.github.com/repos/midas-network/COV...     False     False
# 2       https://api.github.com/repos/RamiKrispin/coron...     False     False
# 3       https://api.github.com/repos/FoldingAtHome/cor...     False     False
# 4       https://api.github.com/repos/nextstrain/ncov/c...     False     False
# ...                                                   ...       ...       ...
# 178037  https://api.github.com/repos/digital-wellbeing...     False     False
# 178047  https://api.github.com/repos/m-boutaleb/Smart-...     False     False
# 178050  https://api.github.com/repos/cgettings/Airplan...     False     False
# 178051  https://api.github.com/repos/mmphego/face_mask...     False     False
# 178067  https://api.github.com/repos/jahnavi-prasad/fa...     False     False
#
#         stargazers_count  watchers_count  forks_count  ...  has_projects  \
# 0                  27211           27211        17432  ...          True
# 1                    642             642          221  ...          True
# 2                    394             394          175  ...          True
# 3                   1115            1115           87  ...          True
# 4                   1208            1208          343  ...          True
# ...                  ...             ...          ...  ...           ...
# 178037                 0               0            0  ...          True
# 178047                 0               0            0  ...          True
# 178050                 0               0            0  ...          True
# 178051                35              35           11  ...          True
# 178067                 6               6            7  ...          True
#
#         has_wiki                                           homepage  \
# 0           True  https://systems.jhu.edu/research/public-health...
# 1           True                                                NaN
# 2           True         https://ramikrispin.github.io/coronavirus/
# 3           True                          https://foldingathome.org
# 4           True                        https://nextstrain.org/ncov
# ...          ...                                                ...
# 178037      True  https://digital-wellbeing.github.io/steam-lock...
# 178047      True                                                NaN
# 178050     False                                                NaN
# 178051      True  https://blog.mphomphego.co.za/blog/2020/06/02/...
# 178067      True                                                NaN
#
#                                                  html_url  language  \
# 0              https://github.com/CSSEGISandData/COVID-19       NaN
# 1               https://github.com/midas-network/COVID-19       TeX
# 2              https://github.com/RamiKrispin/coronavirus         R
# 3            https://github.com/FoldingAtHome/coronavirus    Python
# 4                      https://github.com/nextstrain/ncov    Python
# ...                                                   ...       ...
# 178037  https://github.com/digital-wellbeing/steam-loc...      HTML
# 178047   https://github.com/m-boutaleb/Smart-Food-Storage      Java
# 178050             https://github.com/cgettings/Airplanes      HTML
# 178051  https://github.com/mmphego/face_mask_detection...    Python
# 178067  https://github.com/jahnavi-prasad/face-mask-de...    Python
#
#                   created_at             pushed_at            updated_at  \
# 0       2020-02-04T22:03:53Z  2021-08-14T11:35:08Z  2021-08-14T11:56:01Z
# 1       2020-01-21T15:27:23Z  2021-08-12T20:15:14Z  2021-08-12T20:15:21Z
# 2       2020-02-11T14:08:06Z  2021-08-14T08:19:49Z  2021-08-14T08:19:52Z
# 3       2020-01-30T03:12:19Z  2020-10-27T03:29:18Z  2021-08-09T21:17:36Z
# 4       2020-01-19T17:23:17Z  2021-08-13T12:36:06Z  2021-08-13T12:36:10Z
# ...                      ...                   ...                   ...
# 178037  2020-05-27T15:10:55Z  2021-02-10T14:26:15Z  2021-02-16T13:48:34Z
# 178047  2020-05-28T11:45:23Z  2020-10-04T15:25:00Z  2021-03-23T08:43:26Z
# 178050  2020-03-09T20:01:16Z  2020-08-10T19:11:27Z  2020-08-10T19:11:31Z
# 178051  2020-05-29T12:56:47Z  2021-02-16T12:18:40Z  2021-05-25T21:53:17Z
# 178067  2020-06-06T07:39:31Z  2020-06-06T07:46:00Z  2021-05-03T13:00:00Z
#
#                                                   svn_url        owner.login
# 0              https://github.com/CSSEGISandData/COVID-19     CSSEGISandData
# 1               https://github.com/midas-network/COVID-19      midas-network
# 2              https://github.com/RamiKrispin/coronavirus        RamiKrispin
# 3            https://github.com/FoldingAtHome/coronavirus      FoldingAtHome
# 4                      https://github.com/nextstrain/ncov         nextstrain
# ...                                                   ...                ...
# 178037  https://github.com/digital-wellbeing/steam-loc...  digital-wellbeing
# 178047   https://github.com/m-boutaleb/Smart-Food-Storage         m-boutaleb
# 178050             https://github.com/cgettings/Airplanes          cgettings
# 178051  https://github.com/mmphego/face_mask_detection...            mmphego
# 178067  https://github.com/jahnavi-prasad/face-mask-de...     jahnavi-prasad
#
# [176723 rows x 23 columns]

# %% [markdown]
# Finalmente, volvemos a actualizar *df_res_final* con los 1.343 repositorios anteriores:

# %%
df_res_final = df_res_final.append(df_not_in_description_new_filtrado.drop(columns=['topics']))
df_res_final
# Out:
#                id                             name  \
# 0       238316428                         COVID-19
# 1       235374822                         COVID-19
# 2       239777191                      coronavirus
# 3       237129709                      coronavirus
# 4       234936988                             ncov
# ...           ...                              ...
# 178062  268856502               iot-contact-tracer
# 178063  269479371                          jupyter
# 178065  269527538  OpenWeatherMap-concat-histories
# 178068  270013759                         frontend
# 178069  270006438                          backend
#
#                                      full_name  \
# 0                      CSSEGISandData/COVID-19
# 1                       midas-network/COVID-19
# 2                      RamiKrispin/coronavirus
# 3                    FoldingAtHome/coronavirus
# 4                              nextstrain/ncov
# ...                                        ...
# 178062                 fwcd/iot-contact-tracer
# 178063                           kclhi/jupyter
# 178065  ALT-F1/OpenWeatherMap-concat-histories
# 178068                        Tackode/frontend
# 178069                         Tackode/backend
#
#                                               description  \
# 0       Novel Coronavirus (COVID-19) Cases, provided b...
# 1                       2019 novel coronavirus repository
# 2                                 The coronavirus dataset
# 3                           Folding@home COVID-19 efforts
# 4       Nextstrain build for novel coronavirus SARS-CoV-2
# ...                                                   ...
# 178062  Decentralized contact tracing system supportin...
# 178063           :whale2: JupyterHub Docker configuration
# 178065  Concatenate histories weather data collected b...
# 178068                               Frontend for Tackode
# 178069                                Backend for Tackode
#
#                                          contributors_url  archived  disabled  \
# 0       https://api.github.com/repos/CSSEGISandData/CO...     False     False
# 1       https://api.github.com/repos/midas-network/COV...     False     False
# 2       https://api.github.com/repos/RamiKrispin/coron...     False     False
# 3       https://api.github.com/repos/FoldingAtHome/cor...     False     False
# 4       https://api.github.com/repos/nextstrain/ncov/c...     False     False
# ...                                                   ...       ...       ...
# 178062  https://api.github.com/repos/fwcd/iot-contact-...     False     False
# 178063  https://api.github.com/repos/kclhi/jupyter/con...     False     False
# 178065  https://api.github.com/repos/ALT-F1/OpenWeathe...     False     False
# 178068  https://api.github.com/repos/Tackode/frontend/...     False     False
# 178069  https://api.github.com/repos/Tackode/backend/c...     False     False
#
#         stargazers_count  watchers_count  forks_count  ...  has_projects  \
# 0                  27211           27211        17432  ...          True
# 1                    642             642          221  ...          True
# 2                    394             394          175  ...          True
# 3                   1115            1115           87  ...          True
# 4                   1208            1208          343  ...          True
# ...                  ...             ...          ...  ...           ...
# 178062                 1               1            0  ...          True
# 178063                 2               2            0  ...          True
# 178065                 1               1            0  ...          True
# 178068                 0               0            0  ...          True
# 178069                 0               0            0  ...          True
#
#         has_wiki                                           homepage  \
# 0           True  https://systems.jhu.edu/research/public-health...
# 1           True                                                NaN
# 2           True         https://ramikrispin.github.io/coronavirus/
# 3           True                          https://foldingathome.org
# 4           True                        https://nextstrain.org/ncov
# ...          ...                                                ...
# 178062      True                                                NaN
# 178063      True                                  https://kclhi.org
# 178065      True                               http://www.alt-f1.be
# 178068      True                                https://tackode.com
# 178069      True                                https://tackode.com
#
#                                                  html_url  language  \
# 0              https://github.com/CSSEGISandData/COVID-19       NaN
# 1               https://github.com/midas-network/COVID-19       TeX
# 2              https://github.com/RamiKrispin/coronavirus         R
# 3            https://github.com/FoldingAtHome/coronavirus    Python
# 4                      https://github.com/nextstrain/ncov    Python
# ...                                                   ...       ...
# 178062         https://github.com/fwcd/iot-contact-tracer      Dart
# 178063                   https://github.com/kclhi/jupyter    Python
# 178065  https://github.com/ALT-F1/OpenWeatherMap-conca...    Python
# 178068                https://github.com/Tackode/frontend       Vue
# 178069                 https://github.com/Tackode/backend      Rust
#
#                   created_at             pushed_at            updated_at  \
# 0       2020-02-04T22:03:53Z  2021-08-14T11:35:08Z  2021-08-14T11:56:01Z
# 1       2020-01-21T15:27:23Z  2021-08-12T20:15:14Z  2021-08-12T20:15:21Z
# 2       2020-02-11T14:08:06Z  2021-08-14T08:19:49Z  2021-08-14T08:19:52Z
# 3       2020-01-30T03:12:19Z  2020-10-27T03:29:18Z  2021-08-09T21:17:36Z
# 4       2020-01-19T17:23:17Z  2021-08-13T12:36:06Z  2021-08-13T12:36:10Z
# ...                      ...                   ...                   ...
# 178062  2020-06-02T16:46:15Z  2020-09-04T13:14:05Z  2020-09-04T15:03:54Z
# 178063  2020-06-04T22:35:16Z  2021-06-11T18:23:39Z  2021-08-14T14:32:53Z
# 178065  2020-06-05T04:04:46Z  2021-08-12T13:30:11Z  2020-06-08T12:44:27Z
# 178068  2020-06-06T14:57:50Z  2021-08-12T04:05:02Z  2021-01-11T08:38:35Z
# 178069  2020-06-06T14:30:13Z  2021-08-13T04:03:31Z  2021-05-26T08:44:01Z
#
#                                                   svn_url     owner.login
# 0              https://github.com/CSSEGISandData/COVID-19  CSSEGISandData
# 1               https://github.com/midas-network/COVID-19   midas-network
# 2              https://github.com/RamiKrispin/coronavirus     RamiKrispin
# 3            https://github.com/FoldingAtHome/coronavirus   FoldingAtHome
# 4                      https://github.com/nextstrain/ncov      nextstrain
# ...                                                   ...             ...
# 178062         https://github.com/fwcd/iot-contact-tracer            fwcd
# 178063                   https://github.com/kclhi/jupyter           kclhi
# 178065  https://github.com/ALT-F1/OpenWeatherMap-conca...          ALT-F1
# 178068                https://github.com/Tackode/frontend         Tackode
# 178069                 https://github.com/Tackode/backend         Tackode
#
# [178066 rows x 23 columns]

# %% [markdown]
# Y lo exportamos a CSV:

# %%
df_res_final.to_csv(r'dataset_repositorios_filtrados.csv', index=False, encoding="utf-8-sig")

# %% [markdown]
# --------

# %% [markdown]
# ### Repositorios con keywords relacionadas creados antes de 2020

# %% [markdown]
# Como se vio en el análisis manual del Notebook de Visualizaciones en la sección "Repositorios creados antes de declararse pandemia", la lista de repositorios no relacionados con creación previa a enero de 2020 es la siguiente:

# %%
invalidos = [2618529, 7797677, 34158241, 42319556, 42321742, 46790113, 63896251, 64085813, 106683801, 105979787, 
             183196269, 196332961, 225646868, 195876578,  209656058, 231134405, 216056228, 140326771, 172798234, 
             229122289, 21244714, 93610140, 175701328, 194225243, 150090997, 197573508, 213540232]

# %%
df = pd.read_csv('dataset_repositorios_filtrados.csv')

# %%
df_sin_invalidos = df[~df['id'].isin(invalidos)]
df_sin_invalidos
# Out:
#                id                             name  \
# 0       238316428                         COVID-19
# 1       235374822                         COVID-19
# 2       239777191                      coronavirus
# 3       237129709                      coronavirus
# 4       234936988                             ncov
# ...           ...                              ...
# 178061  268856502               iot-contact-tracer
# 178062  269479371                          jupyter
# 178063  269527538  OpenWeatherMap-concat-histories
# 178064  270013759                         frontend
# 178065  270006438                          backend
#
#                                      full_name  \
# 0                      CSSEGISandData/COVID-19
# 1                       midas-network/COVID-19
# 2                      RamiKrispin/coronavirus
# 3                    FoldingAtHome/coronavirus
# 4                              nextstrain/ncov
# ...                                        ...
# 178061                 fwcd/iot-contact-tracer
# 178062                           kclhi/jupyter
# 178063  ALT-F1/OpenWeatherMap-concat-histories
# 178064                        Tackode/frontend
# 178065                         Tackode/backend
#
#                                               description  \
# 0       Novel Coronavirus (COVID-19) Cases, provided b...
# 1                       2019 novel coronavirus repository
# 2                                 The coronavirus dataset
# 3                           Folding@home COVID-19 efforts
# 4       Nextstrain build for novel coronavirus SARS-CoV-2
# ...                                                   ...
# 178061  Decentralized contact tracing system supportin...
# 178062           :whale2: JupyterHub Docker configuration
# 178063  Concatenate histories weather data collected b...
# 178064                               Frontend for Tackode
# 178065                                Backend for Tackode
#
#                                          contributors_url  archived  disabled  \
# 0       https://api.github.com/repos/CSSEGISandData/CO...     False     False
# 1       https://api.github.com/repos/midas-network/COV...     False     False
# 2       https://api.github.com/repos/RamiKrispin/coron...     False     False
# 3       https://api.github.com/repos/FoldingAtHome/cor...     False     False
# 4       https://api.github.com/repos/nextstrain/ncov/c...     False     False
# ...                                                   ...       ...       ...
# 178061  https://api.github.com/repos/fwcd/iot-contact-...     False     False
# 178062  https://api.github.com/repos/kclhi/jupyter/con...     False     False
# 178063  https://api.github.com/repos/ALT-F1/OpenWeathe...     False     False
# 178064  https://api.github.com/repos/Tackode/frontend/...     False     False
# 178065  https://api.github.com/repos/Tackode/backend/c...     False     False
#
#         stargazers_count  watchers_count  forks_count  ...  has_projects  \
# 0                  27211           27211        17432  ...          True
# 1                    642             642          221  ...          True
# 2                    394             394          175  ...          True
# 3                   1115            1115           87  ...          True
# 4                   1208            1208          343  ...          True
# ...                  ...             ...          ...  ...           ...
# 178061                 1               1            0  ...          True
# 178062                 2               2            0  ...          True
# 178063                 1               1            0  ...          True
# 178064                 0               0            0  ...          True
# 178065                 0               0            0  ...          True
#
#         has_wiki                                           homepage  \
# 0           True  https://systems.jhu.edu/research/public-health...
# 1           True                                                NaN
# 2           True         https://ramikrispin.github.io/coronavirus/
# 3           True                          https://foldingathome.org
# 4           True                        https://nextstrain.org/ncov
# ...          ...                                                ...
# 178061      True                                                NaN
# 178062      True                                  https://kclhi.org
# 178063      True                               http://www.alt-f1.be
# 178064      True                                https://tackode.com
# 178065      True                                https://tackode.com
#
#                                                  html_url  language  \
# 0              https://github.com/CSSEGISandData/COVID-19       NaN
# 1               https://github.com/midas-network/COVID-19       TeX
# 2              https://github.com/RamiKrispin/coronavirus         R
# 3            https://github.com/FoldingAtHome/coronavirus    Python
# 4                      https://github.com/nextstrain/ncov    Python
# ...                                                   ...       ...
# 178061         https://github.com/fwcd/iot-contact-tracer      Dart
# 178062                   https://github.com/kclhi/jupyter    Python
# 178063  https://github.com/ALT-F1/OpenWeatherMap-conca...    Python
# 178064                https://github.com/Tackode/frontend       Vue
# 178065                 https://github.com/Tackode/backend      Rust
#
#                   created_at             pushed_at            updated_at  \
# 0       2020-02-04T22:03:53Z  2021-08-14T11:35:08Z  2021-08-14T11:56:01Z
# 1       2020-01-21T15:27:23Z  2021-08-12T20:15:14Z  2021-08-12T20:15:21Z
# 2       2020-02-11T14:08:06Z  2021-08-14T08:19:49Z  2021-08-14T08:19:52Z
# 3       2020-01-30T03:12:19Z  2020-10-27T03:29:18Z  2021-08-09T21:17:36Z
# 4       2020-01-19T17:23:17Z  2021-08-13T12:36:06Z  2021-08-13T12:36:10Z
# ...                      ...                   ...                   ...
# 178061  2020-06-02T16:46:15Z  2020-09-04T13:14:05Z  2020-09-04T15:03:54Z
# 178062  2020-06-04T22:35:16Z  2021-06-11T18:23:39Z  2021-08-14T14:32:53Z
# 178063  2020-06-05T04:04:46Z  2021-08-12T13:30:11Z  2020-06-08T12:44:27Z
# 178064  2020-06-06T14:57:50Z  2021-08-12T04:05:02Z  2021-01-11T08:38:35Z
# 178065  2020-06-06T14:30:13Z  2021-08-13T04:03:31Z  2021-05-26T08:44:01Z
#
#                                                   svn_url     owner.login
# 0              https://github.com/CSSEGISandData/COVID-19  CSSEGISandData
# 1               https://github.com/midas-network/COVID-19   midas-network
# 2              https://github.com/RamiKrispin/coronavirus     RamiKrispin
# 3            https://github.com/FoldingAtHome/coronavirus   FoldingAtHome
# 4                      https://github.com/nextstrain/ncov      nextstrain
# ...                                                   ...             ...
# 178061         https://github.com/fwcd/iot-contact-tracer            fwcd
# 178062                   https://github.com/kclhi/jupyter           kclhi
# 178063  https://github.com/ALT-F1/OpenWeatherMap-conca...          ALT-F1
# 178064                https://github.com/Tackode/frontend         Tackode
# 178065                 https://github.com/Tackode/backend         Tackode
#
# [178039 rows x 23 columns]

# %% [markdown]
# Exportamos con el dataset actualizado:

# %%
df_sin_invalidos.to_csv(r'dataset_repositorios_filtrados_final.csv', index = False, encoding="utf-8-sig")
